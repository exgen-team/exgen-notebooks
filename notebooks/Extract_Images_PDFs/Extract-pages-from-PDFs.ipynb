# %%
import subprocess, shutil
PDFIMAGES = shutil.which("pdfimages") or r"C:\Program Files\poppler-24.08.0\Library\bin\pdfimages.exe"
print("pdfimages:", PDFIMAGES)
print(subprocess.run([PDFIMAGES, "-v"], capture_output=True, text=True).stderr)
# Out:
# pdfimages: C:\Users\Julian.Diaz\AppData\Local\anaconda3\envs\py311\Library\bin\pdfimages.EXE
# pdfimages version 24.09.0
# Copyright 2005-2024 The Poppler Developers - http://poppler.freedesktop.org
# Copyright 1996-2011, 2022 Glyph & Cog, LLC

# %%
# pip/conda: pymupdf
#   conda install -c conda-forge pymupdf   (or)   pip install pymupdf

import fitz  # PyMuPDF
import pathlib, csv
from concurrent.futures import ThreadPoolExecutor, as_completed

# --- CONFIG ---
PDF_DIR      = pathlib.Path(r"C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\04_eXgen\B\__type___pdf")
OUT_DIR      = pathlib.Path(r"C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\04_eXgen\B\__type___pdf_images-ext")
DPI          = 300
MAX_WORKERS  = 4

# Heuristics (tune as needed)
MIN_VECTOR_OPS       = 100    # select pages with >= this many vector ops
TEXT_CHAR_MAX        = 200    # de-prioritise "texty" pages (still select if vector is very high)
VERY_HIGH_VECTOR_OPS = 400    # always select if >= this (even if lots of text)

# ----------------
OUT_DIR.mkdir(parents=True, exist_ok=True)
zoom = DPI / 72.0
MAT  = fitz.Matrix(zoom, zoom)

def page_metrics(page: fitz.Page):
    """
    Return a dict with vector_ops, text_chars, image_count.
    vector_ops ~ total number of low-level drawing items on the page.
    """
    drawings = page.get_drawings() or []
    # Sum items across drawings (each drawing has an 'items' list of primitives)
    vector_ops = sum(len(d.get("items", ())) for d in drawings)
    text = page.get_text("text") or ""
    text_chars = len(text)
    image_count = len(page.get_images(full=True))
    return {"vector_ops": vector_ops, "text_chars": text_chars, "image_count": image_count}

def should_render(metrics):
    v = metrics["vector_ops"]
    t = metrics["text_chars"]
    # Always render if extremely vector-heavy
    if v >= VERY_HIGH_VECTOR_OPS:
        return True, f"vector_ops={v} (>= {VERY_HIGH_VECTOR_OPS})"
    # Render if vector-heavy and not too texty
    if v >= MIN_VECTOR_OPS and t <= TEXT_CHAR_MAX:
        return True, f"vector_ops={v} & text_chars={t}"
    # Otherwise skip
    return False, f"skip (vector_ops={v}, text_chars={t})"

def render_selected_pages(pdf_path: pathlib.Path):
    rows = []
    rendered = 0
    try:
        doc = fitz.open(pdf_path)
    except Exception as e:
        return f"FAIL open {pdf_path.name}: {e}", rows

    out_sub = OUT_DIR / pdf_path.stem
    out_sub.mkdir(parents=True, exist_ok=True)

    for i in range(len(doc)):
        page = doc.load_page(i)
        m = page_metrics(page)
        ok, reason = should_render(m)
        if not ok:
            continue
        try:
            pix = page.get_pixmap(matrix=MAT)
            out_png = out_sub / f"page-{i+1:04d}.png"
            pix.save(out_png)
            rendered += 1
            rows.append({
                "pdf_stem": pdf_path.stem,
                "pdf_path": str(pdf_path),
                "page": i + 1,
                "dpi": DPI,
                "vector_ops": m["vector_ops"],
                "text_chars": m["text_chars"],
                "image_count": m["image_count"],
                "image_path": str(out_png),
                "reason": reason,
            })
        except Exception as e:
            rows.append({
                "pdf_stem": pdf_path.stem,
                "pdf_path": str(pdf_path),
                "page": i + 1,
                "dpi": DPI,
                "vector_ops": m["vector_ops"],
                "text_chars": m["text_chars"],
                "image_count": m["image_count"],
                "image_path": "",
                "reason": f"ERROR: {e}",
            })

    status = f"OK   {pdf_path.name}: {rendered} vector pages"
    if rendered == 0:
        status = f"SKIP {pdf_path.name}: no vector-heavy pages"
    return status, rows

pdfs = list(PDF_DIR.rglob("*.pdf"))
print("Found PDFs:", len(pdfs))

all_rows = []
with ThreadPoolExecutor(max_workers=MAX_WORKERS) as ex:
    futures = {ex.submit(render_selected_pages, pdf): pdf for pdf in pdfs}
    for fut in as_completed(futures):
        status, rows = fut.result()
        print(status)
        all_rows.extend(rows)

# Write index
INDEX_CSV = OUT_DIR / "page_index_vector.csv"
if all_rows:
    with INDEX_CSV.open("w", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=list(all_rows[0].keys()))
        w.writeheader(); w.writerows(all_rows)
    print(f"\nIndexed {len(all_rows)} rendered pages → {INDEX_CSV}")
else:
    print("\nNo pages rendered. Consider lowering MIN_VECTOR_OPS or raising VERY_HIGH_VECTOR_OPS.")
# Out:
# Found PDFs: 242
# SKIP APPENDIX_1_-_ALTERATION_LEGEND.pdf: no vector-heavy pages
# SKIP 2004_ANNUAL_REPORT.pdf: no vector-heavy pages
# OK   ANNUAL_REPORT_ATTACHMENT.pdf: 1 vector pages
# SKIP APPENDIX_1_-_LITHOLOGY_LEGEND.pdf: no vector-heavy pages
# SKIP APPENDIX_1_-_REPROCESSED_REGIONAL_MAGNETIC_IMAGERY__1.pdf: no vector-heavy pages
# SKIP APPENDIX_1_-_REPROCESSED_REGIONAL_MAGNETIC_IMAGERY.pdf: no vector-heavy pages
# SKIP APPENDIX_1_-_REPROCESSED_REGIONAL_MAGNETIC_IMAGERY__2.pdf: no vector-heavy pages
# OK   APPENDIX_1_-_PHASE_ONE_GRAVITY_SURVEY_REPORT.pdf: 1 vector pages
# SKIP APPENDIX_1_-_REPROCESSED_REGIONAL_MAGNETIC_IMAGERY__3.pdf: no vector-heavy pages
# OK   APPENDIX_2_-_ANALYSIS_SPECIFICATIONS.pdf: 1 vector pages
# SKIP APPENDIX_2_-_PHASE_TWO_GRAVITY_SURVEY_REPORT.pdf: no vector-heavy pages
# SKIP APPENDIX_2_-_REPROCESSED_GRAVITY_IMAGERY.pdf: no vector-heavy pages
# OK   APPENDIX_2_-_GEOPHYSICS_-_EM.pdf: 4 vector pages
# SKIP APPENDIX_2_-_REPROCESSED_REGIONAL_GRAVITY_IMAGERY.pdf: no vector-heavy pages
# SKIP APPENDIX_2_-_REPROCESSED_REGIONAL_GRAVITY_IMAGERY__2.pdf: no vector-heavy pages
# SKIP APPENDIX_2_-_REPROCESSED_REGIONAL_GRAVITY_IMAGERY__1.pdf: no vector-heavy pages
# SKIP APPENDIX_2_-_WATER_BORES.pdf: no vector-heavy pages
# SKIP APPENDIX_3_-_COMPOSITE_IMAGES_OF_THE_RTP_MAGNETICS_AND_BOUGUER_GRAVITY.pdf: no vector-heavy pages
# SKIP APPENDIX_3_-_COMPOSITE_IMAGES_OF_THE_RTP_MAGNETICS_AND_MIM_BOUGUER_GRAVITY.pdf: no vector-heavy pages
# SKIP APPENDIX_3_-_COMPOSITE_IMAGES_OF_THE_RTP_MAGNETICS_AND_MIM_BOUGUER_GRAVITY__1.pdf: no vector-heavy pages
# SKIP APPENDIX_3_-_COMPOSITE_OF_THE_RTP_MAGNETICS_AND_MIM_BOUGUER_GRAVITY.pdf: no vector-heavy pages
# SKIP APPENDIX_3_-_DRILLING_SECTION.pdf: no vector-heavy pages
# SKIP APPENDIX_3_-_MERGED_DATA_FIGURES.pdf: no vector-heavy pages
# OK   APPENDIX_3_-_DRILLING_SECTIONS.pdf: 1 vector pages
# SKIP APPENDIX_4_-_GEOPHYISCAL_INTERPRETATION_REPORT.pdf: no vector-heavy pages
# SKIP APPENDIX_5_-_CORE_PHOTOGRAPHY.pdf: no vector-heavy pages
# OK   APPENDIX_4_-_PUNJAUB_GEOPHYSICAL_IMAGES.pdf: 3 vector pages
# OK   APPENDIX_5_-_DRILL_HOLE_DD02TT03.pdf: 4 vector pages
# OK   APPENDIX_5_-_DRILL_HOLE_DD02TT04.pdf: 5 vector pages
# OK   APPENDIX_5_-_DRILL_HOLE_DD02TT01.pdf: 5 vector pages
# OK   APPENDIX_5_-_DRILL_HOLE_DD02TT05.pdf: 4 vector pages
# OK   APPENDIX_5_-_DRILL_HOLE_DD02TT06.pdf: 3 vector pages
# OK   APPENDIX_5_-_DRILL_HOLE_DD02TT08.pdf: 3 vector pages
# OK   APPENDIX_6_-_ANALYSIS_SPECIFICATIONS.pdf: 1 vector pages
# OK   APPENDIX_5_-_MIMDAS_SURVEY_REPORT.pdf: 2 vector pages
# OK   APPENDIX_6_-_EPIDOTE_DATING.pdf: 2 vector pages
# OK   APPENDIX_6_-_SAMPLING_PROCEDURES.pdf: 1 vector pages
# SKIP APPENDIX_7_-_HONOURS_THESIS_ABSTRACT_-_CONTENTS.pdf: no vector-heavy pages
# OK   APPENDIX_6_-_SOIL_CARD_DECODES.pdf: 1 vector pages
# OK   APPENDIX_8_-_UNMODIFIED_GEOCHEMISTRY_FROM_THESIS.pdf: 1 vector pages
# SKIP APPENDIX_9_-_BRIEF_PETROLOGICAL_DESCRIPTIONS_OF_TUFFACEOUS_SAMPLES_FOR_SHRIMP_U-PB_ZIRCON_AGE_DATING_BLUEBUSH_PROSPECT.pdf: no vector-heavy pages
# OK   APPENDIX_5_-_DRILL_HOLE_DD02TT09.pdf: 3 vector pages
# SKIP APPENDIX_9_-_PLATE_1_-_SAMPLE_BLBD31_-_436.55M.pdf: no vector-heavy pages
# SKIP APPENDIX_9_-_PLATE_2_-_SAMPLE_BLBD35_-_756.85M.pdf: no vector-heavy pages
# OK   APPENDIX_8_-_LITHOGEOCHEMISTRY_PLOTS.pdf: 8 vector pages
# SKIP APPENDIX_9_-_PLATE_4_-_SAMPLE_BLBD23_-_516.70M.pdf: no vector-heavy pages
# SKIP APPENDIX_9_-_PLATE_3_-_SAMPLE_BLBD35_-_641.40M.pdf: no vector-heavy pages
# SKIP APPENDIX_9_-_PLATE_5_-_SAMPLE_BLBD35_-_641.40M.pdf: no vector-heavy pages
# SKIP BODY_OF_REPORT.pdf: no vector-heavy pages
# OK   ATTACHMENT_-_TECHNICAL_SUMMARY_REPORT.pdf: 1 vector pages
# SKIP BODY_OF_REPORT__1.pdf: no vector-heavy pages
# SKIP BODY_OF_REPORT__2.pdf: no vector-heavy pages
# OK   BODY_OF_REPORT__10.pdf: 1 vector pages
# SKIP BODY_OF_REPORT__3.pdf: no vector-heavy pages
# SKIP BODY_OF_REPORT__4.pdf: no vector-heavy pages
# OK   BODY_OF_REPORT__5.pdf: 1 vector pages
# SKIP BODY_OF_REPORT__7.pdf: no vector-heavy pages
# SKIP BODY_OF_REPORT__6.pdf: no vector-heavy pages
# OK   BODY_OF_REPORT__8.pdf: 1 vector pages
# SKIP BODY_OF_REPORT__9.pdf: no vector-heavy pages
# OK   BOUGER_GRAVITY_MAP.pdf: 1 vector pages
# SKIP CAMOOWEAL_SHEET_SE54-13_1253_440_4_MILE_GEOLOGICAL_SERIES_MAP_-_FIRST_EDITION_1961..pdf: no vector-heavy pages
# SKIP CAMOOWEAL_SHEET_SE54-13_FIRST_EDITION_1961.pdf: no vector-heavy pages
# SKIP CDI_PROPOSAL_REPORT_GREGORY_PROJECT.pdf: no vector-heavy pages
# SKIP CEI0308_Final_Report.pdf: no vector-heavy pages
# SKIP COLOUR_FIGURES_1-6_FROM_BODY_OF_RECONNAISSANCE_SURVEY.pdf: no vector-heavy pages
# OK   CAMOOWEAL_SE_54-13_1250000_MINERAL_OCCURRENCE_MAP.pdf: 1 vector pages
# SKIP CORE_PHOTOGRAPHY_-_PART_2.pdf: no vector-heavy pages
# SKIP CORE_PHOTOGRAPHY_-_PART_1.pdf: no vector-heavy pages
# SKIP CORE_PHOTOGRAPHY_-_PART_3.pdf: no vector-heavy pages
# SKIP DIAMOND_DRILLING.pdf: no vector-heavy pages
# SKIP DOBBYN_1250000_GEOLOGICAL_SERIES_-_EXPLANATORY_NOTES.pdf: no vector-heavy pages
# SKIP CORE_PHOTOGRAPHY_-_PART_4.pdf: no vector-heavy pages
# SKIP DOBBYN_SHEET_SE54-14_FIRST_EDITION_1958.pdf: no vector-heavy pages
# SKIP DONORS_HILL_1250000_GEOLOGICAL_SERIES_-_EXPLANATORY_NOTES.pdf: no vector-heavy pages
# SKIP EMIT_MODELLING_OF_MLEM_SQUID_SURVEY.pdf: no vector-heavy pages
# SKIP EPM26438_Final_Appendix1_Magnetics.pdf: no vector-heavy pages
# OK   DRILL_HOLE_LOCATION_PLAN.pdf: 1 vector pages
# SKIP EPM26438_Final_Appendix2_Gravity.pdf: no vector-heavy pages
# SKIP EPM26438_Final_Appendix4_Solve.pdf: no vector-heavy pages
# SKIP EPM26438_Final_Report_2021.pdf: no vector-heavy pages
# SKIP EPM26441_Final_Appendix1_Magnetics.pdf: no vector-heavy pages
# SKIP EPM26441_Final_Appendix4_Solve.pdf: no vector-heavy pages
# SKIP EPM26441_Final_Appendix2_Gravity.pdf: no vector-heavy pages
# SKIP EPM26441_Final_Report_2021.pdf: no vector-heavy pages
# SKIP EPM26463_Annual_Report_2020.pdf: no vector-heavy pages
# SKIP EPM28446_Final_Exploration_Report.pdf: no vector-heavy pages
# SKIP EPM28448_Final_Exploration_Report.pdf: no vector-heavy pages
# SKIP EPM28447_Final_Exploration_Report.pdf: no vector-heavy pages
# OK   EPM_13293_13299_NORTH_GORDON_ANNUAL_REPORT_FOR_PERIOD_ENDED_25603.pdf: 2 vector pages
# SKIP EPM_18644_CDI_PROPOSAL_REPORT.pdf: no vector-heavy pages
# SKIP EPM_18644_GREGORY_PROJECT_ANNUAL_REPORT_FOR_SECOND_YEAR_PERIOD_1452014_TO_1352015.pdf: no vector-heavy pages
# SKIP EPM_18644_PROPOSED_WORK_PROGRAMME.pdf: no vector-heavy pages
# SKIP EPM_18645_GREGORY_PROJECT_ANNUAL_REPORT_FOR_PERIOD_ENDING_2542015.pdf: no vector-heavy pages
# SKIP EPM_26406_Millar_Creek_Final_Report_for_Period_Ended_July_23_2021.pdf: no vector-heavy pages
# SKIP EPM_8453_TAGASSA_FINAL_REPORT.pdf: no vector-heavy pages
# SKIP EPM_8453_TAGASSA_PARTIAL_RELINQUISHMENT_REPORT_FOR_PERIOD_ENDING_101102.pdf: no vector-heavy pages
# OK   EPM_13264_FIERY_CREEK_ANNUALFINAL_REPORT_FOR_THE_PERIOD_6802_TO_4803.pdf: 5 vector pages
# SKIP FIGURES_1_2_3__4_COALIFICATION.pdf: no vector-heavy pages
# SKIP FIGURESREFLECTIVITY_DATA_WHERE_AVAILABLE.pdf: no vector-heavy pages
# SKIP FIGURE_10_-_CONDUCTIVITY_SECTIONS_-_SHEET_4.pdf: no vector-heavy pages
# SKIP FIGURE_11_-_CONDUCTIVITY_SECTIONS_-_SHEET_5.pdf: no vector-heavy pages
# OK   FIGURE_12-_CONDUCTIVITY_SECTIONS_-_SHEET_6.pdf: 1 vector pages
# SKIP FIGURE_14_-_SECTION_7885500N.pdf: no vector-heavy pages
# SKIP FIGURE_15_-_SECTION_7887500N.pdf: no vector-heavy pages
# SKIP FIGURE_16_-_SECTION_7889000N.pdf: no vector-heavy pages
# SKIP FIGURE_17_-_SECTION_7889500N.pdf: no vector-heavy pages
# SKIP FIGURE_18_-_SECTION_364600E.pdf: no vector-heavy pages
# OK   FIGURE_1_-_LAWN_HILL_PROJECT_TENEMENT_LOCATION__TOPOGRAPHY.pdf: 1 vector pages
# OK   FIGURE_13_-_SOIL_SAMPLES_AND_GEOLOGY.pdf: 1 vector pages
# OK   FIGURE_1_-_LOCATION_MAP.pdf: 1 vector pages
# OK   FIGURE_2_-_LAWN_HILL_DRILL_HOLE_LOCATIONS.pdf: 1 vector pages
# OK   FIGURE_3_-_REGIONAL_GEOLOGY.pdf: 1 vector pages
# OK   FIGURE_4_-_LOCATION_OF_GEOPHYSICAL_SURVEYS.pdf: 1 vector pages
# OK   APPENDIX_1_-_SEEBASE_STUDY_AND_GIS_GEOPHYSICS_FROGTECH_GEOSCIENCE.pdf: 174 vector pages
# OK   FIGURE_5_-_BOUGER_GRAVITY.pdf: 1 vector pages
# OK   FIGURE_2_-_RELINQUISHED_SUB-BLOCKS_MAP.pdf: 3 vector pages
# SKIP FIGURE_5_-_SECTION_7885500N.pdf: no vector-heavy pages
# OK   FIGURE_5_-_LAWN_HILL_SOIL_SAMPLE_LOCATIONS.pdf: 1 vector pages
# SKIP FIGURE_6_-_SECTION_7887500N.pdf: no vector-heavy pages
# SKIP FIGURE_7_-_SECTION_7889000N.pdf: no vector-heavy pages
# SKIP FIGURE_7_-_CONDUCTIVITY_SECTIONS_-_SHEET_1.pdf: no vector-heavy pages
# OK   FIGURE_6_-_RTP_AEROMAGNETICS.pdf: 1 vector pages
# SKIP FIGURE_8_-_CONDUCTIVITY_SECTIONS_-_SHEET_2.pdf: no vector-heavy pages
# SKIP FIGURE_8_-_SECTION_7889500N.pdf: no vector-heavy pages
# SKIP FIGURE_9_-_CONDUCTIVITY_SECTIONS_-_SHEET_3.pdf: no vector-heavy pages
# SKIP FIGURE_9_-_SECTION_364600E.pdf: no vector-heavy pages
# OK   FIGURE_8_-_LAWN_HILL_PROJECT_NATIVE_TITLE_PLAN.pdf: 1 vector pages
# OK   FINAL_REPORT_TO_8604.pdf: 1 vector pages
# SKIP GEM_GEOPHYSICS_LOGISTICAL_REPORT.pdf: no vector-heavy pages
# SKIP LAWN_HILL_-_GEOLOGICAL_SERIES_1250000_SHEET_SE_54-9_SECOND_EDITION_1983.pdf: no vector-heavy pages
# OK   IP_SURVEYS.pdf: 1 vector pages
# SKIP LAWN_HILL_1250000_4_MILE_GEOLOGICAL_SERIES_-_EXPLANATORY_NOTES.pdf: no vector-heavy pages
# OK   LAWN_HILL_PROJECT_COMBINED_ANNUAL_REPORT_FOR_PERIOD_ENDING_101102.pdf: 1 vector pages
# OK   LOCATION_OF_GEOPHYSICAL_SURVEYS.pdf: 1 vector pages
# OK   GEOLOGY_PLAN.pdf: 1 vector pages
# SKIP MIRA_GEOSCIENCE_MODELLING_OF_EM_AND_MAG.pdf: no vector-heavy pages
# SKIP MT_SURVEY_SPECIFICATIONS.pdf: no vector-heavy pages
# OK   NARDOO_ANNUAL_REPORT.pdf: 1 vector pages
# SKIP PARTIAL_RELINQUISHMENT_REPORT_FOR_145_SUB-BLOCKS_DROPPED_9704.pdf: no vector-heavy pages
# SKIP PHOTOGEOLOGIC_EVALUATION_MAP__SHEET_1.pdf: no vector-heavy pages
# SKIP PHOTOGEOLOGIC_EVALUATION_MAP__SHEET_2.pdf: no vector-heavy pages
# SKIP PHOTOGEOLOGIC_EVALUATION_MAP__SHEET_3.pdf: no vector-heavy pages
# OK   MINERAL_OCCURRENCE_MAP__1.pdf: 1 vector pages
# SKIP PHOTOGEOLOGIC_EVALUATION_MAP__SHEET_4.pdf: no vector-heavy pages
# SKIP PLATE_2__GEOLOGY__PLATE_3__STRATIGRAPHIC_COLUMN.pdf: no vector-heavy pages
# SKIP PROPOSED_WORK_PROGRAM_FOR_GREGORY_PROJECT.pdf: no vector-heavy pages
# OK   MINERAL_OCCURRENCE_MAP.pdf: 1 vector pages
# OK   REPORT_ATTACHMENT_SUMMARY.pdf: 1 vector pages
# SKIP REPORT_BODY.pdf: no vector-heavy pages
# SKIP PLATE_FIGURES_ABBREVIATIONS_IN_PLATE_FIGURES_AC_-_ARGYLE_CREEK-1_DC_-_DESERT_CREEK-1_EG_-_EGILABRIA._EXPLANATION_TO_PLATE_FIGURES_FIGURES_1_-_35.pdf: no vector-heavy pages
# OK   BODY_OF_REPORT_FROGTECH_GEOSCIENCE.pdf: 153 vector pages
# SKIP REPORT_BODY__4.pdf: no vector-heavy pages
# OK   REPORT_BODY__3.pdf: 4 vector pages
# SKIP REPORT_BODY__6.pdf: no vector-heavy pages
# OK   REPORT_BODY__5.pdf: 3 vector pages
# OK   REPORT_BODY__2.pdf: 7 vector pages
# SKIP SAMPLE_NUMBER_26824_ANALYSIS_REPORT_BY_SANTOS_BOREHOLE_NUMBER_3142_THIN_SECTION_DESCRIPTION.pdf: no vector-heavy pages
# SKIP SAMPLE_NUMBER_26824_ANALYSIS_REPORT_BY_SANTOS_BOREHOLE_NUMBER_3180_THIN_SECTION_DESCRIPTION.pdf: no vector-heavy pages
# OK   RTP_AEROMAGNETICS.pdf: 1 vector pages
# SKIP SAMPLE_NUMBER_26824_REPORT_ANALYSIS_BOREHOLE_NUMBER_3141_FROM_SANTOS_THIN_SECTION_DESCRIPTION.pdf: no vector-heavy pages
# OK   SAMPLE_NUMBER_26824_ANALYSIS_REPORT_BY_SANTOS_BOREHOLE_NUMBER_3142_TOTAL_ORGANIC_CARBON_PROGRAMMED_PYROLYSIS_DATA_RECON_SHALE_SAMPLES_111014.pdf: 7 vector pages
# OK   SAMPLE_NUMBER_26824_ANALYSIS_REPORT_BY_SANTOS_BOREHOLE_NUMBER_3180_TOTAL_ORGANIC_CARBON_PROGRAMMED_PYROLYSIS_DATA_RECON_SHALE_SAMPLES_111014..pdf: 7 vector pages
# OK   SECTION_10_-_GEOLOGY_AND_MAGMATIC-HYDROTHERMAL_TEMPORAL_SEQUENCE_OF_SN-W-MO-AU_METALLOGENY.pdf: 2 vector pages
# OK   SAMPLE_NUMBER_26824_REPORT_ANALYSIS_BOREHOLE_NUMBER_3141_FROM_SANTOS_TOTAL_ORGANIC_CARBON_PROGRAMMED_PYROLYSIS_DATA_RECON_SHALE_SAMPLES_111014..pdf: 7 vector pages
# SKIP SECTION_11_-_WATERSHED_W_DEPOSIT.pdf: no vector-heavy pages
# OK   SECTION_12_-_WOLFRAM_CAMP_MINE.pdf: 1 vector pages
# SKIP SECTION_1_-_NORTHERN_BOWEN_BASIN_METALLOGENY.pdf: no vector-heavy pages
# SKIP SECTION_2_-_MT_CARLTON_DEPOSIT.pdf: no vector-heavy pages
# OK   REPORT_BODY__1.pdf: 11 vector pages
# SKIP SECTION_4_-_TOWNSVILLE_MACKAY_FERTILITY.pdf: no vector-heavy pages
# SKIP SECTION_6_-_ZIRCON_TRACE_ELEMENT.pdf: no vector-heavy pages
# SKIP SECTION_3_-_MT_CARLTON_STRUCTURE.pdf: no vector-heavy pages
# SKIP SECTION_5_-_REGIONAL_MAGMA_FERTILITY.pdf: no vector-heavy pages
# OK   SUMMARY_ATTACHMENT.pdf: 1 vector pages
# SKIP SECTION_7_-_CHILLAGOE_DISTRICT.pdf: no vector-heavy pages
# SKIP SUMMARY_NE_QLD_PROJECT_SECTIONS_1_TO_12.pdf: no vector-heavy pages
# SKIP SECTION_9_-_MT_CARBINE_W_DEPOSIT.pdf: no vector-heavy pages
# OK   TEM_SURVEYS.pdf: 2 vector pages
# OK   TENEMENT_LOCATION_PLAN.pdf: 1 vector pages
# SKIP SECTION_8_-_HERBERTON_MT_GARNET_DEPOSITS.pdf: no vector-heavy pages
# SKIP WARNING_INFORMATION_REGARDING_USE_OF_APPENDIX_1_GRAVITY_SURVEY_DATA.pdf: no vector-heavy pages
# OK   TENEMENT_RELINQUISHMENT_PLAN.pdf: 1 vector pages
# SKIP WHOLE_OF_REPORT.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__1.pdf: no vector-heavy pages
# OK   WHOLE_REPORT__11.pdf: 1 vector pages
# SKIP WHOLE_REPORT__12.pdf: no vector-heavy pages
# OK   WHOLE_REPORT__10.pdf: 1 vector pages
# SKIP WHOLE_REPORT__13.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__15.pdf: no vector-heavy pages
# OK   WHOLE_REPORT__14.pdf: 3 vector pages
# OK   WHOLE_REPORT__17.pdf: 2 vector pages
# SKIP WHOLE_REPORT__18.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__16.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__19.pdf: no vector-heavy pages
# OK   WHOLE_REPORT__20.pdf: 1 vector pages
# OK   WHOLE_REPORT__2.pdf: 1 vector pages
# OK   WHOLE_REPORT__21.pdf: 1 vector pages
# OK   WHOLE_BODY_OF_REPORT_FOR_EPM_13264_FIERY_CREEK_ANNUAL_REPORT_FOR_THE_PERIOD_6801_TO_5802INCLUDES_FIGURES_1-4.pdf: 4 vector pages
# SKIP WHOLE_REPORT__24.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__22.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__23.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__25.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__27.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__29.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__28.pdf: no vector-heavy pages
# OK   WHOLE_REPORT__26.pdf: 1 vector pages
# SKIP WHOLE_REPORT__30.pdf: no vector-heavy pages
# OK   WHOLE_REPORT__3.pdf: 1 vector pages
# SKIP WHOLE_REPORT__32.pdf: no vector-heavy pages
# OK   WHOLE_REPORT__31.pdf: 1 vector pages
# SKIP WHOLE_REPORT__33.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__35.pdf: no vector-heavy pages
# OK   WHOLE_REPORT__36.pdf: 1 vector pages
# SKIP WHOLE_REPORT__34.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__37.pdf: no vector-heavy pages
# OK   WHOLE_REPORT__38.pdf: 1 vector pages
# SKIP WHOLE_REPORT__40.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__39.pdf: no vector-heavy pages
# OK   WHOLE_REPORT__4.pdf: 1 vector pages
# SKIP WHOLE_REPORT__42.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__45.pdf: no vector-heavy pages
# OK   WHOLE_REPORT__43.pdf: 1 vector pages
# SKIP WHOLE_REPORT__44.pdf: no vector-heavy pages
# OK   WHOLE_REPORT__46.pdf: 1 vector pages
# SKIP WHOLE_REPORT__49.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__48.pdf: no vector-heavy pages
# OK   WHOLE_REPORT__41.pdf: 18 vector pages
# SKIP WHOLE_REPORT__51.pdf: no vector-heavy pages
# OK   WHOLE_REPORT__5.pdf: 2 vector pages
# SKIP WHOLE_REPORT__52.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__50.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__53.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__54.pdf: no vector-heavy pages
# SKIP WHOLE_REPORT__6.pdf: no vector-heavy pages
# OK   WHOLE_REPORT__55.pdf: 1 vector pages
# OK   WHOLE_REPORT__7.pdf: 1 vector pages
# SKIP WHOLE_REPORT__8.pdf: no vector-heavy pages
# SKIP ZONGE_MT_REPORT.pdf: no vector-heavy pages
# OK   WHOLE_REPORT__9.pdf: 8 vector pages
# OK   WHOLE_REPORT__47.pdf: 10 vector pages
#
# Indexed 535 rendered pages → C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\04_eXgen\B\__type___pdf_images-ext\page_index_vector.csv

# %%
import pathlib, shutil

# --- CONFIG ---
SRC_DIR = pathlib.Path(r"C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\04_eXgen\B\__type___pdf_images-ext")  # parent folder with many subfolders
DST_DIR = pathlib.Path(r"C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\04_eXgen\B\__type___pdf_images-ext\Summary")            # single destination folder
# --------------

DST_DIR.mkdir(parents=True, exist_ok=True)

count = 0
for sub in SRC_DIR.iterdir():
    if not sub.is_dir():
        continue
    stem = sub.name
    for img in sub.glob("*.png"):
        new_name = f"{stem}_{img.name}"
        dst = DST_DIR / new_name
        shutil.move(str(img), dst)   # move instead of copy
        count += 1

print(f"Moved {count} PNGs → {DST_DIR}")
# Out:
# Moved 1003 PNGs → C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\04_eXgen\B\__type___pdf_images-ext\Summary
