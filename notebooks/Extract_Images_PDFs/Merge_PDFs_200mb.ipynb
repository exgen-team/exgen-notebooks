# %%
import os
from PyPDF2 import PdfMerger

# =========================
# Settings
# =========================

SOURCE_FOLDER = r"C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\04_eXgen\B\__type___pdf"
DEST_FOLDER = r"C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\04_eXgen\B\__type___pdf\B-for-NotebookLM-pdf"

MAX_BATCH_MB = 200  # Max size per merged PDF (approximate)
MAX_BATCH_BYTES = MAX_BATCH_MB * 1024 * 1024


# =========================
# Helpers
# =========================

def get_pdf_files_with_sizes(folder):
    """Return list of (full_path, size_bytes) for all PDFs in folder."""
    pdfs = []
    for name in os.listdir(folder):
        if not name.lower().endswith(".pdf"):
            continue
        full_path = os.path.join(folder, name)
        if not os.path.isfile(full_path):
            continue
        size_bytes = os.path.getsize(full_path)
        pdfs.append((full_path, size_bytes))

    # Sort by file name for deterministic ordering
    pdfs.sort(key=lambda x: os.path.basename(x[0]).lower())
    return pdfs


def make_batches(pdfs, max_bytes):
    """
    Group PDFs into batches such that the sum of sizes in each batch
    is <= max_bytes (approximate limit).
    """
    batches = []
    current_batch = []
    current_size = 0

    for path, size in pdfs:
        # If a single file is larger than the limit, put it in its own batch
        # and warn (NotebookLM may still reject it).
        if size > max_bytes:
            print(
                f"WARNING: '{path}' is larger than {MAX_BATCH_MB} MB by itself "
                f"({size / (1024**2):.1f} MB). Placing alone in its own batch."
            )
            if current_batch:
                batches.append(current_batch)
                current_batch = []
                current_size = 0
            batches.append([(path, size)])
            continue

        # If adding this file would exceed the limit, start a new batch
        if current_batch and current_size + size > max_bytes:
            batches.append(current_batch)
            current_batch = []
            current_size = 0

        current_batch.append((path, size))
        current_size += size

    if current_batch:
        batches.append(current_batch)

    return batches


def merge_batch(batch, output_path):
    """Merge a batch of PDFs into a single PDF at output_path."""
    merger = PdfMerger()
    try:
        for path, _ in batch:
            merger.append(path)
        with open(output_path, "wb") as f_out:
            merger.write(f_out)
    finally:
        merger.close()


# =========================
# Main
# =========================

def main():
    print(f"Looking for PDFs in:\n{SOURCE_FOLDER}\n")

    pdfs = get_pdf_files_with_sizes(SOURCE_FOLDER)
    if not pdfs:
        print("No PDF files found. Exiting.")
        return

    print("Found the following PDF files:")
    for path, size in pdfs:
        print(f" - {os.path.basename(path)} ({size / (1024**2):.2f} MB)")
    print()

    os.makedirs(DEST_FOLDER, exist_ok=True)

    batches = make_batches(pdfs, MAX_BATCH_BYTES)
    print(f"Planned {len(batches)} batch(es) (approx ≤ {MAX_BATCH_MB} MB each).\n")

    for i, batch in enumerate(batches, start=1):
        batch_size_bytes = sum(size for _, size in batch)
        out_name = f"NotebookLM_batch_{i:03d}.pdf"
        out_path = os.path.join(DEST_FOLDER, out_name)

        print(
            f"Creating {out_name}: "
            f"{len(batch)} file(s), approx {batch_size_bytes / (1024**2):.2f} MB"
        )
        merge_batch(batch, out_path)

    print("\nDone!")
    print(f"Merged PDFs saved in:\n{DEST_FOLDER}")
    print("Original PDFs were not modified.")


if __name__ == "__main__":
    main()
# Out:
# Looking for PDFs in:
# C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\04_eXgen\B\__type___pdf
#
# Found the following PDF files:
#  - 2004_ANNUAL_REPORT.pdf (0.37 MB)
#  - ANNUAL_REPORT_ATTACHMENT.pdf (0.01 MB)
#  - APPENDIX_1_-_ALTERATION_LEGEND.pdf (0.01 MB)
#  - APPENDIX_1_-_LITHOLOGY_LEGEND.pdf (0.01 MB)
#  - APPENDIX_1_-_PHASE_ONE_GRAVITY_SURVEY_REPORT.pdf (0.51 MB)
#  - APPENDIX_1_-_REPROCESSED_REGIONAL_MAGNETIC_IMAGERY.pdf (7.02 MB)
#  - APPENDIX_1_-_REPROCESSED_REGIONAL_MAGNETIC_IMAGERY__1.pdf (6.33 MB)
#  - APPENDIX_1_-_REPROCESSED_REGIONAL_MAGNETIC_IMAGERY__2.pdf (7.39 MB)
#  - APPENDIX_1_-_REPROCESSED_REGIONAL_MAGNETIC_IMAGERY__3.pdf (6.53 MB)
#  - APPENDIX_1_-_SEEBASE_STUDY_AND_GIS_GEOPHYSICS_FROGTECH_GEOSCIENCE.pdf (60.98 MB)
#  - APPENDIX_2_-_ANALYSIS_SPECIFICATIONS.pdf (0.15 MB)
#  - APPENDIX_2_-_GEOPHYSICS_-_EM.pdf (0.07 MB)
#  - APPENDIX_2_-_PHASE_TWO_GRAVITY_SURVEY_REPORT.pdf (12.60 MB)
#  - APPENDIX_2_-_REPROCESSED_GRAVITY_IMAGERY.pdf (28.40 MB)
#  - APPENDIX_2_-_REPROCESSED_REGIONAL_GRAVITY_IMAGERY.pdf (26.40 MB)
#  - APPENDIX_2_-_REPROCESSED_REGIONAL_GRAVITY_IMAGERY__1.pdf (28.65 MB)
#  - APPENDIX_2_-_REPROCESSED_REGIONAL_GRAVITY_IMAGERY__2.pdf (28.82 MB)
#  - APPENDIX_2_-_WATER_BORES.pdf (0.05 MB)
#  - APPENDIX_3_-_COMPOSITE_IMAGES_OF_THE_RTP_MAGNETICS_AND_BOUGUER_GRAVITY.pdf (19.98 MB)
#  - APPENDIX_3_-_COMPOSITE_IMAGES_OF_THE_RTP_MAGNETICS_AND_MIM_BOUGUER_GRAVITY.pdf (22.50 MB)
#  - APPENDIX_3_-_COMPOSITE_IMAGES_OF_THE_RTP_MAGNETICS_AND_MIM_BOUGUER_GRAVITY__1.pdf (20.73 MB)
#  - APPENDIX_3_-_COMPOSITE_OF_THE_RTP_MAGNETICS_AND_MIM_BOUGUER_GRAVITY.pdf (18.95 MB)
#  - APPENDIX_3_-_DRILLING_SECTION.pdf (0.01 MB)
#  - APPENDIX_3_-_DRILLING_SECTIONS.pdf (0.02 MB)
#  - APPENDIX_3_-_MERGED_DATA_FIGURES.pdf (1.36 MB)
#  - APPENDIX_4_-_GEOPHYISCAL_INTERPRETATION_REPORT.pdf (0.44 MB)
#  - APPENDIX_4_-_PUNJAUB_GEOPHYSICAL_IMAGES.pdf (2.66 MB)
#  - APPENDIX_5_-_CORE_PHOTOGRAPHY.pdf (65.47 MB)
#  - APPENDIX_5_-_DRILL_HOLE_DD02TT01.pdf (2.81 MB)
#  - APPENDIX_5_-_DRILL_HOLE_DD02TT03.pdf (1.62 MB)
#  - APPENDIX_5_-_DRILL_HOLE_DD02TT04.pdf (2.90 MB)
#  - APPENDIX_5_-_DRILL_HOLE_DD02TT05.pdf (2.21 MB)
#  - APPENDIX_5_-_DRILL_HOLE_DD02TT06.pdf (1.77 MB)
#  - APPENDIX_5_-_DRILL_HOLE_DD02TT08.pdf (2.28 MB)
#  - APPENDIX_5_-_DRILL_HOLE_DD02TT09.pdf (2.28 MB)
#  - APPENDIX_5_-_MIMDAS_SURVEY_REPORT.pdf (0.27 MB)
#  - APPENDIX_6_-_ANALYSIS_SPECIFICATIONS.pdf (0.15 MB)
#  - APPENDIX_6_-_EPIDOTE_DATING.pdf (0.38 MB)
#  - APPENDIX_6_-_SAMPLING_PROCEDURES.pdf (0.10 MB)
#  - APPENDIX_6_-_SOIL_CARD_DECODES.pdf (0.15 MB)
#  - APPENDIX_7_-_HONOURS_THESIS_ABSTRACT_-_CONTENTS.pdf (0.10 MB)
#  - APPENDIX_8_-_LITHOGEOCHEMISTRY_PLOTS.pdf (0.15 MB)
#  - APPENDIX_8_-_UNMODIFIED_GEOCHEMISTRY_FROM_THESIS.pdf (0.17 MB)
#  - APPENDIX_9_-_BRIEF_PETROLOGICAL_DESCRIPTIONS_OF_TUFFACEOUS_SAMPLES_FOR_SHRIMP_U-PB_ZIRCON_AGE_DATING_BLUEBUSH_PROSPECT.pdf (0.04 MB)
#  - APPENDIX_9_-_PLATE_1_-_SAMPLE_BLBD31_-_436.55M.pdf (11.07 MB)
#  - APPENDIX_9_-_PLATE_2_-_SAMPLE_BLBD35_-_756.85M.pdf (11.98 MB)
#  - APPENDIX_9_-_PLATE_3_-_SAMPLE_BLBD35_-_641.40M.pdf (11.58 MB)
#  - APPENDIX_9_-_PLATE_4_-_SAMPLE_BLBD23_-_516.70M.pdf (11.54 MB)
#  - APPENDIX_9_-_PLATE_5_-_SAMPLE_BLBD35_-_641.40M.pdf (11.98 MB)
#  - ATTACHMENT_-_TECHNICAL_SUMMARY_REPORT.pdf (0.02 MB)
#  - BODY_OF_REPORT.pdf (2.95 MB)
#  - BODY_OF_REPORT__1.pdf (3.19 MB)
#  - BODY_OF_REPORT__10.pdf (1.53 MB)
#  - BODY_OF_REPORT__2.pdf (3.28 MB)
#  - BODY_OF_REPORT__3.pdf (0.84 MB)
#  - BODY_OF_REPORT__4.pdf (0.73 MB)
#  - BODY_OF_REPORT__5.pdf (1.49 MB)
#  - BODY_OF_REPORT__6.pdf (2.25 MB)
#  - BODY_OF_REPORT__7.pdf (0.84 MB)
#  - BODY_OF_REPORT__8.pdf (1.29 MB)
#  - BODY_OF_REPORT__9.pdf (5.91 MB)
#  - BODY_OF_REPORT_FROGTECH_GEOSCIENCE.pdf (58.18 MB)
#  - BOUGER_GRAVITY_MAP.pdf (0.15 MB)
#  - CAMOOWEAL_SE_54-13_1250000_MINERAL_OCCURRENCE_MAP.pdf (2.30 MB)
#  - CAMOOWEAL_SHEET_SE54-13_1253_440_4_MILE_GEOLOGICAL_SERIES_MAP_-_FIRST_EDITION_1961..pdf (9.06 MB)
#  - CAMOOWEAL_SHEET_SE54-13_FIRST_EDITION_1961.pdf (13.03 MB)
#  - CDI_PROPOSAL_REPORT_GREGORY_PROJECT.pdf (3.68 MB)
#  - CEI0308_Final_Report.pdf (13.79 MB)
#  - COLOUR_FIGURES_1-6_FROM_BODY_OF_RECONNAISSANCE_SURVEY.pdf (4.15 MB)
#  - CORE_PHOTOGRAPHY_-_PART_1.pdf (88.91 MB)
#  - CORE_PHOTOGRAPHY_-_PART_2.pdf (65.75 MB)
#  - CORE_PHOTOGRAPHY_-_PART_3.pdf (33.20 MB)
#  - CORE_PHOTOGRAPHY_-_PART_4.pdf (47.73 MB)
#  - DIAMOND_DRILLING.pdf (5.72 MB)
#  - DOBBYN_1250000_GEOLOGICAL_SERIES_-_EXPLANATORY_NOTES.pdf (3.90 MB)
#  - DOBBYN_SHEET_SE54-14_FIRST_EDITION_1958.pdf (10.68 MB)
#  - DONORS_HILL_1250000_GEOLOGICAL_SERIES_-_EXPLANATORY_NOTES.pdf (0.64 MB)
#  - DRILL_HOLE_LOCATION_PLAN.pdf (0.15 MB)
#  - EMIT_MODELLING_OF_MLEM_SQUID_SURVEY.pdf (0.65 MB)
#  - EPM26438_Final_Appendix1_Magnetics.pdf (6.33 MB)
#  - EPM26438_Final_Appendix2_Gravity.pdf (28.40 MB)
#  - EPM26438_Final_Appendix4_Solve.pdf (19.98 MB)
#  - EPM26438_Final_Report_2021.pdf (3.14 MB)
#  - EPM26441_Final_Appendix1_Magnetics.pdf (6.53 MB)
#  - EPM26441_Final_Appendix2_Gravity.pdf (28.82 MB)
#  - EPM26441_Final_Appendix4_Solve.pdf (20.73 MB)
#  - EPM26441_Final_Report_2021.pdf (5.93 MB)
#  - EPM26463_Annual_Report_2020.pdf (2.94 MB)
#  - EPM28446_Final_Exploration_Report.pdf (1.19 MB)
#  - EPM28447_Final_Exploration_Report.pdf (1.19 MB)
#  - EPM28448_Final_Exploration_Report.pdf (1.19 MB)
#  - EPM_13264_FIERY_CREEK_ANNUALFINAL_REPORT_FOR_THE_PERIOD_6802_TO_4803.pdf (0.75 MB)
#  - EPM_13293_13299_NORTH_GORDON_ANNUAL_REPORT_FOR_PERIOD_ENDED_25603.pdf (0.39 MB)
#  - EPM_18644_CDI_PROPOSAL_REPORT.pdf (3.68 MB)
#  - EPM_18644_GREGORY_PROJECT_ANNUAL_REPORT_FOR_SECOND_YEAR_PERIOD_1452014_TO_1352015.pdf (2.29 MB)
#  - EPM_18644_PROPOSED_WORK_PROGRAMME.pdf (0.84 MB)
#  - EPM_18645_GREGORY_PROJECT_ANNUAL_REPORT_FOR_PERIOD_ENDING_2542015.pdf (2.92 MB)
#  - EPM_26406_Millar_Creek_Final_Report_for_Period_Ended_July_23_2021.pdf (0.40 MB)
#  - EPM_8453_TAGASSA_FINAL_REPORT.pdf (0.25 MB)
#  - EPM_8453_TAGASSA_PARTIAL_RELINQUISHMENT_REPORT_FOR_PERIOD_ENDING_101102.pdf (0.17 MB)
#  - FIGURE_10_-_CONDUCTIVITY_SECTIONS_-_SHEET_4.pdf (1.67 MB)
#  - FIGURE_11_-_CONDUCTIVITY_SECTIONS_-_SHEET_5.pdf (1.60 MB)
#  - FIGURE_12-_CONDUCTIVITY_SECTIONS_-_SHEET_6.pdf (1.85 MB)
#  - FIGURE_13_-_SOIL_SAMPLES_AND_GEOLOGY.pdf (0.58 MB)
#  - FIGURE_14_-_SECTION_7885500N.pdf (2.35 MB)
#  - FIGURE_15_-_SECTION_7887500N.pdf (4.54 MB)
#  - FIGURE_16_-_SECTION_7889000N.pdf (4.00 MB)
#  - FIGURE_17_-_SECTION_7889500N.pdf (6.50 MB)
#  - FIGURE_18_-_SECTION_364600E.pdf (2.37 MB)
#  - FIGURE_1_-_LAWN_HILL_PROJECT_TENEMENT_LOCATION__TOPOGRAPHY.pdf (0.05 MB)
#  - FIGURE_1_-_LOCATION_MAP.pdf (0.13 MB)
#  - FIGURE_2_-_LAWN_HILL_DRILL_HOLE_LOCATIONS.pdf (0.04 MB)
#  - FIGURE_2_-_RELINQUISHED_SUB-BLOCKS_MAP.pdf (0.40 MB)
#  - FIGURE_3_-_REGIONAL_GEOLOGY.pdf (0.14 MB)
#  - FIGURE_4_-_LOCATION_OF_GEOPHYSICAL_SURVEYS.pdf (0.11 MB)
#  - FIGURE_5_-_BOUGER_GRAVITY.pdf (0.09 MB)
#  - FIGURE_5_-_LAWN_HILL_SOIL_SAMPLE_LOCATIONS.pdf (0.05 MB)
#  - FIGURE_5_-_SECTION_7885500N.pdf (2.35 MB)
#  - FIGURE_6_-_RTP_AEROMAGNETICS.pdf (0.13 MB)
#  - FIGURE_6_-_SECTION_7887500N.pdf (4.54 MB)
#  - FIGURE_7_-_CONDUCTIVITY_SECTIONS_-_SHEET_1.pdf (2.63 MB)
#  - FIGURE_7_-_SECTION_7889000N.pdf (4.00 MB)
#  - FIGURE_8_-_CONDUCTIVITY_SECTIONS_-_SHEET_2.pdf (2.73 MB)
#  - FIGURE_8_-_LAWN_HILL_PROJECT_NATIVE_TITLE_PLAN.pdf (0.09 MB)
#  - FIGURE_8_-_SECTION_7889500N.pdf (6.50 MB)
#  - FIGURE_9_-_CONDUCTIVITY_SECTIONS_-_SHEET_3.pdf (2.63 MB)
#  - FIGURE_9_-_SECTION_364600E.pdf (2.36 MB)
#  - FIGURES_1_2_3__4_COALIFICATION.pdf (0.15 MB)
#  - FIGURESREFLECTIVITY_DATA_WHERE_AVAILABLE.pdf (1.54 MB)
#  - FINAL_REPORT_TO_8604.pdf (0.22 MB)
#  - GEM_GEOPHYSICS_LOGISTICAL_REPORT.pdf (0.24 MB)
#  - GEOLOGY_PLAN.pdf (0.20 MB)
#  - IP_SURVEYS.pdf (0.39 MB)
#  - LAWN_HILL_-_GEOLOGICAL_SERIES_1250000_SHEET_SE_54-9_SECOND_EDITION_1983.pdf (25.64 MB)
#  - LAWN_HILL_1250000_4_MILE_GEOLOGICAL_SERIES_-_EXPLANATORY_NOTES.pdf (1.14 MB)
#  - LAWN_HILL_PROJECT_COMBINED_ANNUAL_REPORT_FOR_PERIOD_ENDING_101102.pdf (1.44 MB)
#  - LOCATION_OF_GEOPHYSICAL_SURVEYS.pdf (0.15 MB)
#  - MINERAL_OCCURRENCE_MAP.pdf (2.44 MB)
#  - MINERAL_OCCURRENCE_MAP__1.pdf (1.91 MB)
#  - MIRA_GEOSCIENCE_MODELLING_OF_EM_AND_MAG.pdf (0.59 MB)
#  - MT_SURVEY_SPECIFICATIONS.pdf (0.41 MB)
#  - NARDOO_ANNUAL_REPORT.pdf (1.89 MB)
#  - PARTIAL_RELINQUISHMENT_REPORT_FOR_145_SUB-BLOCKS_DROPPED_9704.pdf (0.40 MB)
#  - PHOTOGEOLOGIC_EVALUATION_MAP__SHEET_1.pdf (5.03 MB)
#  - PHOTOGEOLOGIC_EVALUATION_MAP__SHEET_2.pdf (4.59 MB)
#  - PHOTOGEOLOGIC_EVALUATION_MAP__SHEET_3.pdf (1.44 MB)
#  - PHOTOGEOLOGIC_EVALUATION_MAP__SHEET_4.pdf (3.34 MB)
#  - PLATE_2__GEOLOGY__PLATE_3__STRATIGRAPHIC_COLUMN.pdf (1.97 MB)
#  - PLATE_FIGURES_ABBREVIATIONS_IN_PLATE_FIGURES_AC_-_ARGYLE_CREEK-1_DC_-_DESERT_CREEK-1_EG_-_EGILABRIA._EXPLANATION_TO_PLATE_FIGURES_FIGURES_1_-_35.pdf (1.24 MB)
#  - PROPOSED_WORK_PROGRAM_FOR_GREGORY_PROJECT.pdf (0.84 MB)
#  - REPORT_ATTACHMENT_SUMMARY.pdf (0.02 MB)
#  - REPORT_BODY.pdf (7.52 MB)
#  - REPORT_BODY__1.pdf (38.21 MB)
#  - REPORT_BODY__2.pdf (5.99 MB)
#  - REPORT_BODY__3.pdf (2.29 MB)
#  - REPORT_BODY__4.pdf (3.97 MB)
#  - REPORT_BODY__5.pdf (1.83 MB)
#  - REPORT_BODY__6.pdf (1.12 MB)
#  - RTP_AEROMAGNETICS.pdf (0.15 MB)
#  - SAMPLE_NUMBER_26824_ANALYSIS_REPORT_BY_SANTOS_BOREHOLE_NUMBER_3142_THIN_SECTION_DESCRIPTION.pdf (0.04 MB)
#  - SAMPLE_NUMBER_26824_ANALYSIS_REPORT_BY_SANTOS_BOREHOLE_NUMBER_3142_TOTAL_ORGANIC_CARBON_PROGRAMMED_PYROLYSIS_DATA_RECON_SHALE_SAMPLES_111014.pdf (0.57 MB)
#  - SAMPLE_NUMBER_26824_ANALYSIS_REPORT_BY_SANTOS_BOREHOLE_NUMBER_3180_THIN_SECTION_DESCRIPTION.pdf (0.04 MB)
#  - SAMPLE_NUMBER_26824_ANALYSIS_REPORT_BY_SANTOS_BOREHOLE_NUMBER_3180_TOTAL_ORGANIC_CARBON_PROGRAMMED_PYROLYSIS_DATA_RECON_SHALE_SAMPLES_111014..pdf (0.57 MB)
#  - SAMPLE_NUMBER_26824_REPORT_ANALYSIS_BOREHOLE_NUMBER_3141_FROM_SANTOS_THIN_SECTION_DESCRIPTION.pdf (0.01 MB)
#  - SAMPLE_NUMBER_26824_REPORT_ANALYSIS_BOREHOLE_NUMBER_3141_FROM_SANTOS_TOTAL_ORGANIC_CARBON_PROGRAMMED_PYROLYSIS_DATA_RECON_SHALE_SAMPLES_111014..pdf (0.57 MB)
#  - SECTION_10_-_GEOLOGY_AND_MAGMATIC-HYDROTHERMAL_TEMPORAL_SEQUENCE_OF_SN-W-MO-AU_METALLOGENY.pdf (4.23 MB)
#  - SECTION_11_-_WATERSHED_W_DEPOSIT.pdf (4.17 MB)
#  - SECTION_12_-_WOLFRAM_CAMP_MINE.pdf (3.19 MB)
#  - SECTION_1_-_NORTHERN_BOWEN_BASIN_METALLOGENY.pdf (6.57 MB)
#  - SECTION_2_-_MT_CARLTON_DEPOSIT.pdf (9.45 MB)
#  - SECTION_3_-_MT_CARLTON_STRUCTURE.pdf (19.08 MB)
#  - SECTION_4_-_TOWNSVILLE_MACKAY_FERTILITY.pdf (5.15 MB)
#  - SECTION_5_-_REGIONAL_MAGMA_FERTILITY.pdf (7.05 MB)
#  - SECTION_6_-_ZIRCON_TRACE_ELEMENT.pdf (0.63 MB)
#  - SECTION_7_-_CHILLAGOE_DISTRICT.pdf (9.54 MB)
#  - SECTION_8_-_HERBERTON_MT_GARNET_DEPOSITS.pdf (19.72 MB)
#  - SECTION_9_-_MT_CARBINE_W_DEPOSIT.pdf (3.00 MB)
#  - SUMMARY_ATTACHMENT.pdf (0.02 MB)
#  - SUMMARY_NE_QLD_PROJECT_SECTIONS_1_TO_12.pdf (1.55 MB)
#  - TEM_SURVEYS.pdf (0.03 MB)
#  - TENEMENT_LOCATION_PLAN.pdf (0.05 MB)
#  - TENEMENT_RELINQUISHMENT_PLAN.pdf (0.13 MB)
#  - WARNING_INFORMATION_REGARDING_USE_OF_APPENDIX_1_GRAVITY_SURVEY_DATA.pdf (0.24 MB)
#  - WHOLE_BODY_OF_REPORT_FOR_EPM_13264_FIERY_CREEK_ANNUAL_REPORT_FOR_THE_PERIOD_6801_TO_5802INCLUDES_FIGURES_1-4.pdf (0.97 MB)
#  - WHOLE_OF_REPORT.pdf (30.55 MB)
#  - WHOLE_REPORT.pdf (3.86 MB)
#  - WHOLE_REPORT__1.pdf (3.86 MB)
#  - WHOLE_REPORT__10.pdf (2.32 MB)
#  - WHOLE_REPORT__11.pdf (1.62 MB)
#  - WHOLE_REPORT__12.pdf (6.14 MB)
#  - WHOLE_REPORT__13.pdf (1.87 MB)
#  - WHOLE_REPORT__14.pdf (4.14 MB)
#  - WHOLE_REPORT__15.pdf (0.82 MB)
#  - WHOLE_REPORT__16.pdf (3.35 MB)
#  - WHOLE_REPORT__17.pdf (2.31 MB)
#  - WHOLE_REPORT__18.pdf (2.15 MB)
#  - WHOLE_REPORT__19.pdf (2.26 MB)
#  - WHOLE_REPORT__2.pdf (1.40 MB)
#  - WHOLE_REPORT__20.pdf (4.13 MB)
#  - WHOLE_REPORT__21.pdf (0.77 MB)
#  - WHOLE_REPORT__22.pdf (2.91 MB)
#  - WHOLE_REPORT__23.pdf (6.10 MB)
#  - WHOLE_REPORT__24.pdf (0.59 MB)
#  - WHOLE_REPORT__25.pdf (3.85 MB)
#  - WHOLE_REPORT__26.pdf (3.12 MB)
#  - WHOLE_REPORT__27.pdf (2.91 MB)
#  - WHOLE_REPORT__28.pdf (3.31 MB)
#  - WHOLE_REPORT__29.pdf (2.11 MB)
#  - WHOLE_REPORT__3.pdf (1.50 MB)
#  - WHOLE_REPORT__30.pdf (0.98 MB)
#  - WHOLE_REPORT__31.pdf (3.73 MB)
#  - WHOLE_REPORT__32.pdf (0.45 MB)
#  - WHOLE_REPORT__33.pdf (2.23 MB)
#  - WHOLE_REPORT__34.pdf (3.68 MB)
#  - WHOLE_REPORT__35.pdf (2.05 MB)
#  - WHOLE_REPORT__36.pdf (0.94 MB)
#  - WHOLE_REPORT__37.pdf (2.91 MB)
#  - WHOLE_REPORT__38.pdf (2.24 MB)
#  - WHOLE_REPORT__39.pdf (2.32 MB)
#  - WHOLE_REPORT__4.pdf (2.21 MB)
#  - WHOLE_REPORT__40.pdf (2.25 MB)
#  - WHOLE_REPORT__41.pdf (1.37 MB)
#  - WHOLE_REPORT__42.pdf (2.36 MB)
#  - WHOLE_REPORT__43.pdf (3.24 MB)
#  - WHOLE_REPORT__44.pdf (3.86 MB)
#  - WHOLE_REPORT__45.pdf (1.83 MB)
#  - WHOLE_REPORT__46.pdf (2.24 MB)
#  - WHOLE_REPORT__47.pdf (14.04 MB)
#  - WHOLE_REPORT__48.pdf (1.18 MB)
#  - WHOLE_REPORT__49.pdf (0.83 MB)
#  - WHOLE_REPORT__5.pdf (2.29 MB)
#  - WHOLE_REPORT__50.pdf (3.80 MB)
#  - WHOLE_REPORT__51.pdf (2.29 MB)
#  - WHOLE_REPORT__52.pdf (0.62 MB)
#  - WHOLE_REPORT__53.pdf (2.31 MB)
#  - WHOLE_REPORT__54.pdf (0.85 MB)
#  - WHOLE_REPORT__55.pdf (2.21 MB)
#  - WHOLE_REPORT__6.pdf (23.06 MB)
#  - WHOLE_REPORT__7.pdf (3.70 MB)
#  - WHOLE_REPORT__8.pdf (2.91 MB)
#  - WHOLE_REPORT__9.pdf (1.50 MB)
#  - ZONGE_MT_REPORT.pdf (30.97 MB)
#
# Planned 8 batch(es) (approx ≤ 200 MB each).
#
# Creating NotebookLM_batch_001.pdf: 16 file(s), approx 185.45 MB
# Creating NotebookLM_batch_002.pdf: 28 file(s), approx 198.35 MB
# Creating NotebookLM_batch_003.pdf: 25 file(s), approx 186.79 MB
# Creating NotebookLM_batch_004.pdf: 3 file(s), approx 187.85 MB
# Creating NotebookLM_batch_005.pdf: 21 file(s), approx 196.97 MB
# Creating NotebookLM_batch_006.pdf: 75 file(s), approx 196.68 MB
# Creating NotebookLM_batch_007.pdf: 49 file(s), approx 198.10 MB
# Invalid stream (index 0) within object 89 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 65 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 66 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 67 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 68 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 69 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 70 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 71 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 72 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 73 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 74 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 75 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 76 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 77 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 78 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 79 0: Stream has ended unexpectedly
# Creating NotebookLM_batch_008.pdf: 25 file(s), approx 116.47 MB
#
# Done!
# Merged PDFs saved in:
# C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\04_eXgen\B\__type___pdf\B-for-NotebookLM-pdf
# Original PDFs were not modified.
