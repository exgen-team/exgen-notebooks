# %% [markdown]
# # Workflow to Organise Data Downloaded from GSQ
# ## Step 0: Select the source folder

# %%
from pathlib import Path
import os
import shutil
import zipfile

BASE_FOLDER = Path(
    r"C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\00_Projects\96_NT-Gold-CaseStudy\Reports-Tenements2"
).expanduser().resolve()

TYPE_DIR_PREFIX = "__type__"
RAW_FOLDER_NAME = "__raw__"
NOTEBOOKLM_FOLDER_NAME = "___For_NotebookLM"
SHP_FOLDER_NAME = "__shp__"

RAW_FOLDER = BASE_FOLDER / RAW_FOLDER_NAME
NOTEBOOKLM_ROOT = BASE_FOLDER / NOTEBOOKLM_FOLDER_NAME
SHP_FOLDER = BASE_FOLDER / SHP_FOLDER_NAME

# Hard limit for all merged outputs
MAX_BATCH_MB = 190
MAX_BATCH_BYTES = MAX_BATCH_MB * 1024 * 1024

# Hard limit for merged text outputs (NotebookLM char limit)
MAX_BATCH_CHARS = 490_000

# %% [markdown]
# ## Step 1: Extract ZIP Files

# %%
def run_step0_unzip_all(root: Path):
    """
    Step 0:
      - Walk the tree under 'root'
      - For every .zip file, extract it into <stem>__unzipped next to it
      - If that folder already exists and is non-empty, skip

    Run this BEFORE Step 2 on a new dataset.
    Safe to re-run: it will just skip already-extracted zips.
    """
    root = Path(root)
    if not root.exists() or not root.is_dir():
        print(f"Invalid root for unzip step: {root}")
        return

    total_zips = 0
    extracted = 0

    for dirpath, dirnames, filenames in os.walk(root, topdown=True):
        dirpath = Path(dirpath)

        # Do not recurse into our special folders
        dirnames[:] = [
            d for d in dirnames
            if not d.startswith(TYPE_DIR_PREFIX)
            and d not in {RAW_FOLDER_NAME, SHP_FOLDER_NAME, NOTEBOOKLM_FOLDER_NAME}
        ]

        for name in filenames:
            if not name.lower().endswith(".zip"):
                continue

            total_zips += 1
            zip_path = dirpath / name
            extract_dir = dirpath / f"{zip_path.stem}__unzipped"

            # If already extracted, skip
            if extract_dir.exists() and any(extract_dir.iterdir()):
                print(f"Skipping already-extracted: {zip_path} -> {extract_dir}")
                continue

            print(f"Extracting: {zip_path} -> {extract_dir}")
            extract_dir.mkdir(parents=True, exist_ok=True)
            try:
                with zipfile.ZipFile(zip_path, "r") as zf:
                    zf.extractall(extract_dir)
                extracted += 1
            except Exception as e:
                print(f"  ERROR extracting {zip_path}: {e}")

    print(f"Step 0 complete – found {total_zips} zip(s), extracted {extracted} new folder(s).")

# %% [markdown]
# ## Step 1.1: collect shapefile families into __shp__ (single folder)

# %%
# Common shapefile-related extensions we want to keep together
SHP_RELATED_EXTS = {
    ".shp", ".dbf", ".shx", ".prj", ".cpg", ".qpj",
    ".sbn", ".sbx", ".shp.xml", ".dbf.xml"
}

def run_step1_collect_shapefiles(root: Path):
    """
    Step 1:
      - Walk the tree under 'root'
      - For each .shp found (outside our special folders),
        move it and its companion files (.dbf/.shx/.prj/...) into BASE_FOLDER/__shp__

    Result: all shapefile sets live together in one folder, easy to drag into QGIS.
    Safe to re-run: files already in __shp__ are skipped.
    """
    root = Path(root)
    if not root.exists() or not root.is_dir():
        print(f"Invalid root for shapefile step: {root}")
        return

    SHP_FOLDER.mkdir(parents=True, exist_ok=True)
    moved_sets = 0

    for dirpath, dirnames, filenames in os.walk(root, topdown=True):
        dirpath = Path(dirpath)

        # Don’t walk into our special folders
        dirnames[:] = [
            d for d in dirnames
            if not d.startswith(TYPE_DIR_PREFIX)
            and d not in {RAW_FOLDER_NAME, SHP_FOLDER_NAME, NOTEBOOKLM_FOLDER_NAME}
        ]

        # Look for .shp files in this directory
        shp_files = [f for f in filenames if f.lower().endswith(".shp")]
        if not shp_files:
            continue

        for shp_name in shp_files:
            stem = Path(shp_name).stem
            print(f"Collecting shapefile set: {stem} (from {dirpath})")
            moved_sets += 1

            for ext in SHP_RELATED_EXTS:
                candidate = dirpath / f"{stem}{ext}"
                if not candidate.exists():
                    continue

                dest = SHP_FOLDER / candidate.name

                # Avoid overwriting if the same-named file already exists in __shp__
                if dest.exists():
                    base_stem = candidate.stem
                    suffix = candidate.suffix
                    counter = 1
                    while True:
                        new_name = f"{base_stem}__{counter}{suffix}"
                        new_dest = SHP_FOLDER / new_name
                        if not new_dest.exists():
                            dest = new_dest
                            break
                        counter += 1

                shutil.move(str(candidate), str(dest))

    print(f"Step 1 complete – collected {moved_sets} shapefile set(s) into {SHP_FOLDER}")

# %% [markdown]
# ## Step 2: Separate the files into file-type by folder

# %% [markdown]
# ### 2.1 Backup originals into "__raw__"

# %%
def scan_file_types(root: Path):
    """
    Walk through 'root' and collect:
      - ext_counts: {ext_key: count}
      - files_by_ext: {ext_key: [Path, Path, ...]}
    ext_key is like 'pdf', 'txt', or 'noext' for files with no extension.
    """
    ext_counts = {}
    files_by_ext = {}

    # Walk top-down so we can modify `dirnames` to skip our own type folders and __raw__
    for dirpath, dirnames, filenames in os.walk(root, topdown=True):
        dirpath = Path(dirpath)

        # 👉 THIS is the line we were talking about
        # Skip __type__* folders and the __raw__ backup folder
                # Skip __type__* folders, the __raw__ backup folder, __shp__, and ___For_NotebookLM
        dirnames[:] = [
            d for d in dirnames
            if not d.startswith(TYPE_DIR_PREFIX)
            and d != RAW_FOLDER_NAME
            and d != SHP_FOLDER_NAME
            and d != NOTEBOOKLM_FOLDER_NAME
        ]


        for name in filenames:
            file_path = dirpath / name

            # Get extension (last part, e.g. ".pdf"), normalised to lowercase
            ext = file_path.suffix.lower()
            if ext:
                ext_key = ext.lstrip(".")  # ".pdf" -> "pdf"
            else:
                ext_key = "noext"

            ext_counts[ext_key] = ext_counts.get(ext_key, 0) + 1
            files_by_ext.setdefault(ext_key, []).append(file_path)

    return ext_counts, files_by_ext


def print_summary(root: Path, ext_counts: dict, files_by_ext: dict, max_examples: int = 5):
    """
    Print a human-friendly summary of what was found.
    """
    total_files = sum(ext_counts.values())
    print("\n=== Scan summary ===")
    print(f"Root folder: {root}")
    print(f"Total files found (excluding {TYPE_DIR_PREFIX} folders): {total_files}\n")

    if not ext_counts:
        print("No files found.")
        return

    print("File types detected (sorted by count):")
    for ext_key, count in sorted(ext_counts.items(), key=lambda x: (-x[1], x[0])):
        if ext_key == "noext":
            label = "(no extension)"
        else:
            label = f".{ext_key}"
        print(f"  {label:15} -> {count} file(s)")



def safe_move_file(src: Path, dest_folder: Path):
    """
    Move 'src' into 'dest_folder'. If a file with the same name
    already exists, append __1, __2, ... before the extension.
    """
    dest_folder.mkdir(parents=True, exist_ok=True)

    target = dest_folder / src.name
    if not target.exists():
        shutil.move(str(src), str(target))
        return

    stem = src.stem
    suffix = src.suffix
    counter = 1
    while True:
        new_name = f"{stem}__{counter}{suffix}"
        candidate = dest_folder / new_name
        if not candidate.exists():
            shutil.move(str(src), str(candidate))
            break
        counter += 1


def group_files_by_type(root: Path, files_by_ext: dict):
    """
    Move files into __type___<ext> folders inside 'root'.
    """
    for ext_key, file_list in files_by_ext.items():
        if ext_key == "noext":
            folder_name = f"{TYPE_DIR_PREFIX}_noext"
        else:
            folder_name = f"{TYPE_DIR_PREFIX}_{ext_key}"

        dest_dir = root / folder_name

        for src in file_list:
            safe_move_file(src, dest_dir)

# %%
import fitz  # PyMuPDF
import pathlib, csv
from concurrent.futures import ThreadPoolExecutor, as_completed

# --- CONFIG (hooked to BASE_FOLDER) ---
PDF_DIR = BASE_FOLDER / "__type___pdf"
OUT_DIR = BASE_FOLDER / "__type___pdf_images-ext"
DPI = 300
MAX_WORKERS = 4

# Heuristics (tune as needed)
MIN_VECTOR_OPS       = 100   # select pages with >= this many vector ops
TEXT_CHAR_MAX        = 200   # de-prioritise "texty" pages (still select if vector is very high)
VERY_HIGH_VECTOR_OPS = 400   # always select if >= this (even if lots of text)

OUT_DIR.mkdir(parents=True, exist_ok=True)
zoom = DPI / 72.0
MAT  = fitz.Matrix(zoom, zoom)


def page_metrics(page: fitz.Page):
    """
    Return a dict with vector_ops, text_chars, image_count.
    vector_ops ~ total number of low-level drawing items on the page.
    """
    drawings = page.get_drawings() or []
    vector_ops = sum(len(d.get("items", ())) for d in drawings)
    text = page.get_text("text") or ""
    text_chars = len(text)
    image_count = len(page.get_images(full=True))
    return {"vector_ops": vector_ops, "text_chars": text_chars, "image_count": image_count}


def should_render(metrics):
    v = metrics["vector_ops"]
    t = metrics["text_chars"]
    # Always render if extremely vector-heavy
    if v >= VERY_HIGH_VECTOR_OPS:
        return True, f"vector_ops={v} (>= {VERY_HIGH_VECTOR_OPS})"
    # Render if vector-heavy and not too texty
    if v >= MIN_VECTOR_OPS and t <= TEXT_CHAR_MAX:
        return True, f"vector_ops={v} & text_chars={t}"
    # Otherwise skip
    return False, f"skip (vector_ops={v}, text_chars={t})"


def render_selected_pages(pdf_path: pathlib.Path):
    rows = []
    rendered = 0
    try:
        doc = fitz.open(pdf_path)
    except Exception as e:
        return f"FAIL open {pdf_path.name}: {e}", rows

    out_sub = OUT_DIR / pdf_path.stem
    out_sub.mkdir(parents=True, exist_ok=True)

    for i in range(len(doc)):
        page = doc.load_page(i)
        m = page_metrics(page)
        ok, reason = should_render(m)
        if not ok:
            continue
        try:
            pix = page.get_pixmap(matrix=MAT)
            out_png = out_sub / f"page-{i+1:04d}.png"
            pix.save(out_png)
            rendered += 1
            rows.append({
                "pdf_stem": pdf_path.stem,
                "pdf_path": str(pdf_path),
                "page": i + 1,
                "dpi": DPI,
                "vector_ops": m["vector_ops"],
                "text_chars": m["text_chars"],
                "image_count": m["image_count"],
                "image_path": str(out_png),
                "reason": reason,
            })
        except Exception as e:
            rows.append({
                "pdf_stem": pdf_path.stem,
                "pdf_path": str(pdf_path),
                "page": i + 1,
                "dpi": DPI,
                "vector_ops": m["vector_ops"],
                "text_chars": m["text_chars"],
                "image_count": m["image_count"],
                "image_path": "",
                "reason": f"ERROR: {e}",
            })

    status = f"OK   {pdf_path.name}: {rendered} vector pages"
    if rendered == 0:
        status = f"SKIP {pdf_path.name}: no vector-heavy pages"
    return status, rows


def extract_vector_images(pdf_dir: pathlib.Path = PDF_DIR):
    """
    Run vector-heavy page detection + rendering over all PDFs in pdf_dir.
    Writes PNGs into OUT_DIR/<pdf_stem>/ and an index CSV.
    """
    pdfs = list(pdf_dir.rglob("*.pdf"))
    print("Found PDFs:", len(pdfs))

    all_rows = []
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as ex:
        futures = {ex.submit(render_selected_pages, pdf): pdf for pdf in pdfs}
        for fut in as_completed(futures):
            status, rows = fut.result()
            print(status)
            all_rows.extend(rows)

    # Write index
    index_csv = OUT_DIR / "page_index_vector.csv"
    if all_rows:
        with index_csv.open("w", newline="", encoding="utf-8") as f:
            w = csv.DictWriter(f, fieldnames=list(all_rows[0].keys()))
            w.writeheader()
            w.writerows(all_rows)
        print(f"\nIndexed {len(all_rows)} rendered pages → {index_csv}")
    else:
        print("\nNo pages rendered. Consider lowering MIN_VECTOR_OPS or raising VERY_HIGH_VECTOR_OPS.")

# %%
def backup_originals_to_raw(root: Path, files_by_ext: dict):
    """
    Copy all files from 'root' into ROOT/__raw__/... preserving the
    original folder structure. Skips any __raw__ or __type__* folders
    (but __raw__ doesn't exist yet on first run anyway).
    """
    RAW_FOLDER.mkdir(parents=True, exist_ok=True)

    for file_list in files_by_ext.values():
        for src in file_list:
            rel = src.relative_to(root)
            dst = RAW_FOLDER / rel
            dst.parent.mkdir(parents=True, exist_ok=True)
            shutil.copy2(src, dst)

# %% [markdown]
# ### 2.2 Clean up now-empty original folders (outside __raw__ and __type__*)

# %%
def delete_empty_original_folders(root: Path):
    """
    Delete original folders under 'root' that are NOT:
      - __raw__
      - __type__* folders
      - __shp__
      - ___For_NotebookLM

    Assumes files have already been backed up to __raw__ and moved into __type__*.
    """
    root = Path(root)

    # 1) Remove non-special top-level folders wholesale
    for child in root.iterdir():
        if not child.is_dir():
            continue
        name = child.name

        # keep our special folders
        if (
            name == RAW_FOLDER_NAME
            or name == SHP_FOLDER_NAME
            or name == NOTEBOOKLM_FOLDER_NAME
            or name.startswith(TYPE_DIR_PREFIX)
        ):
            continue

        # Remove entire folder tree (original structure)
        shutil.rmtree(child, ignore_errors=True)

    # 2) Sweep for any remaining empty directories deeper down
    for dirpath, dirnames, filenames in os.walk(root, topdown=False):
        dirpath = Path(dirpath)
        name = dirpath.name

        # never delete the root or our special folders
        if dirpath == root:
            continue
        if (
            name == RAW_FOLDER_NAME
            or name == SHP_FOLDER_NAME
            or name == NOTEBOOKLM_FOLDER_NAME
            or name.startswith(TYPE_DIR_PREFIX)
        ):
            continue

        # if directory is empty now, remove it
        try:
            if not any(dirpath.iterdir()):
                dirpath.rmdir()
        except OSError:
            # not empty or cannot remove -> ignore
            pass

# %% [markdown]
# ### 2.3 Orchestrator: no confirmation, just do it

# %%
def run_step2_separate_by_type(root: Path):
    """
    Step 2:
      - scan files
      - print summary
      - backup originals to __raw__
      - move files into __type___<ext> folders
      - delete original top-level folders (outside __raw__ and __type__*)
    """
    if not root.exists() or not root.is_dir():
        print(f"Invalid root: {root}")
        return {}, {}

    ext_counts, files_by_ext = scan_file_types(root)
    print_summary(root, ext_counts, files_by_ext)

    # If there are files, do the backup + grouping
    if ext_counts:
        backup_originals_to_raw(root, files_by_ext)
        group_files_by_type(root, files_by_ext)

    # 🔥 Always run cleanup, even if ext_counts is empty
    delete_empty_original_folders(root)

    return ext_counts, files_by_ext

# %%
ext_counts, files_by_ext = run_step2_separate_by_type(BASE_FOLDER)
# Out:
# === Scan summary ===
# Root folder: C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\00_Projects\96_NT-Gold-CaseStudy\Reports-Tenements2
# Total files found (excluding __type__ folders): 0
#
# No files found.

# %% [markdown]
# ## Step 3: Run OCR on TIF files and merge into single file

# %% [markdown]
# ### 3.1 OCR function (quiet, per-file)

# %%
from PIL import Image
import fitz  # PyMuPDF
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

TIF_FOLDER      = BASE_FOLDER / "__type___tif"
TIF_OCR_FOLDER  = BASE_FOLDER / "__type___tif__OCR___"
TIF_OCR_FOLDER.mkdir(parents=True, exist_ok=True)

def ocr_tif_to_text_single(tif_path: Path, out_txt: Path, lang="eng"):
    """
    Open a TIF that actually contains PDF bytes and run OCR on each page.
    Writes all text to out_txt. No per-page prints.
    Downscales very large page images so Tesseract doesn't choke.
    """
    with open(tif_path, "rb") as f:
        pdf_bytes = f.read()

    doc = fitz.open(stream=pdf_bytes, filetype="pdf")
    all_text_parts = []

    # Base rendering DPI
    zoom = 300 / 72
    mat = fitz.Matrix(zoom, zoom)

    # Hard limit on number of pixels per page image
    MAX_PIXELS = 10_000_000  # ~10 MP

    for page_number in range(len(doc)):
        page = doc[page_number]
        pix = page.get_pixmap(matrix=mat)
        mode = "RGBA" if pix.alpha else "RGB"
        img = Image.frombytes(mode, (pix.width, pix.height), pix.samples)
        gray = img.convert("L")

        # 🔧 Downscale extremely large images before OCR
        w, h = gray.size
        pixels = w * h
        if pixels > MAX_PIXELS:
            scale = (MAX_PIXELS / pixels) ** 0.5
            new_w = max(1, int(w * scale))
            new_h = max(1, int(h * scale))
            # Optional: you can print once per page if you want:
            # print(f"  Downscaling page {page_number+1} from {w}x{h} to {new_w}x{new_h}")
            gray = gray.resize((new_w, new_h), Image.Resampling.LANCZOS)

        try:
            text = pytesseract.image_to_string(gray, lang=lang)
        except pytesseract.TesseractError as e:
            # Fallback: shrink further and try once more
            # (rarely needed, but avoids a hard crash)
            print(f"  Tesseract error on page {page_number+1} of {tif_path.name}: {e}. Retrying at smaller size...")
            smaller = gray.resize(
                (max(1, gray.size[0] // 2), max(1, gray.size[1] // 2)),
                Image.Resampling.LANCZOS,
            )
            text = pytesseract.image_to_string(smaller, lang=lang)

        all_text_parts.append(f"===== PAGE {page_number+1} =====\n{text}\n")

    out_txt.parent.mkdir(parents=True, exist_ok=True)
    with open(out_txt, "w", encoding="utf-8") as f:
        f.write("\n".join(all_text_parts))

# %% [markdown]
# ### 3.2 Run OCR on all .tif with per-file progress

# %%
def run_step3_ocr_tifs():
    """
    Step 3:
      - find all .tif in __type___tif
      - OCR each one -> __type___tif__OCR___/<name>.txt
      - delete the .tif working copy afterwards
    """
    if not TIF_FOLDER.exists():
        print(f"No TIF folder found: {TIF_FOLDER}")
        return

    tif_files = sorted(TIF_FOLDER.glob("*.tif"))
    n = len(tif_files)
    if n == 0:
        print(f"No .tif files found in {TIF_FOLDER}")
        return

    print(f"Found {n} TIF files in {TIF_FOLDER}")
    print(f"OCR text will be saved in: {TIF_OCR_FOLDER}\n")

    for i, tif in enumerate(tif_files, start=1):
        print(f"[{i}/{n}] OCR {tif.name}")
        out_txt = TIF_OCR_FOLDER / f"{tif.stem}_ocr.txt"
        ocr_tif_to_text_single(tif, out_txt, lang="eng")

        # remove working tif (original preserved in __raw__)
        try:
            tif.unlink()
        except Exception as e:
            print(f"  Could not delete {tif}: {e}")

    print("\nStep 3 complete – OCR TIFs → .txt\n")

run_step3_ocr_tifs()
# Out:
# No .tif files found in C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\00_Projects\96_NT-Gold-CaseStudy\Reports-Tenements2\__type___tif

# %% [markdown]
# ### Generic text batching helper (used in Steps 4, 7, 8)

# %%
def batch_merge_text_files(
    source_folder: Path,
    batch_prefix: str,
    dest_root: Path = NOTEBOOKLM_ROOT,
    max_bytes: int = MAX_BATCH_BYTES,  # unused, kept for compatibility
):
    """
    Merge .txt files from source_folder into batches with a hard limit
    on total characters (MAX_BATCH_CHARS).

    Each source file is wrapped with a header marking the boundaries.
    Outputs go to dest_root/<batch_prefix>_batch_XXX.txt
    """
    source_folder = Path(source_folder)
    dest_root.mkdir(parents=True, exist_ok=True)

    txt_files = sorted(source_folder.glob("*.txt"))
    if not txt_files:
        print(f"No .txt files found in {source_folder}")
        return

    # Continue numbering from existing batches, if any
    existing = list(dest_root.glob(f"{batch_prefix}_batch_*.txt"))
    if existing:
        indices = []
        for p in existing:
            stem = p.stem  # e.g. "txt_batch_003"
            parts = stem.split("_")
            try:
                idx = int(parts[-1])
                indices.append(idx)
            except ValueError:
                continue
        batch_index = (max(indices) + 1) if indices else 1
    else:
        batch_index = 1

    print(f"Merging {len(txt_files)} text files from {source_folder}")
    current_chars = 0
    out_path = dest_root / f"{batch_prefix}_batch_{batch_index:03d}.txt"
    fout = open(out_path, "w", encoding="utf-8")
    print(f"  -> Creating {out_path.name}")

    for txt in txt_files:
        # Header marking the start of each file
        header = (
            "\n\n" + "="*80 +
            f"\nFILE: {txt.name}\n" +
            "="*80 + "\n\n"
        )

        # Try UTF-8, fall back to Latin-1
        try:
            with open(txt, "r", encoding="utf-8") as fin:
                content = fin.read()
        except UnicodeDecodeError:
            with open(txt, "r", encoding="latin-1", errors="replace") as fin:
                content = fin.read()

        needed = len(header) + len(content)

        # If this file would overflow the current batch, start a new one
        if current_chars > 0 and current_chars + needed > MAX_BATCH_CHARS:
            fout.close()
            batch_index += 1
            current_chars = 0
            out_path = dest_root / f"{batch_prefix}_batch_{batch_index:03d}.txt"
            fout = open(out_path, "w", encoding="utf-8")
            print(f"  -> Creating {out_path.name}")

        # If even a single file + header is larger than the limit, warn but still write it
        if needed > MAX_BATCH_CHARS and current_chars == 0:
            print(
                f"WARNING: single file {txt.name} (with header) has "
                f"{needed} characters (> {MAX_BATCH_CHARS}). Writing alone in this batch."
            )

        fout.write(header)
        fout.write(content)
        current_chars += needed

    fout.close()
    print(f"Done. Created {batch_index} batch file(s) for prefix '{batch_prefix}'.\n")

# %% [markdown]
# ## Step 4: Merge OCR in 200Mb batches

# %%
def run_step4_merge_tif_ocr_batches():
    """
    Step 4:
      - Merge all .txt in __type___tif__OCR___ into
        ___For_NotebookLM/tif_ocr_batch_XXX.txt
    """
    if not TIF_OCR_FOLDER.exists():
        print(f"No OCR folder found: {TIF_OCR_FOLDER}")
        return

    batch_merge_text_files(
        source_folder=TIF_OCR_FOLDER,
        batch_prefix="tif_ocr",
        dest_root=NOTEBOOKLM_ROOT,
        max_bytes=MAX_BATCH_BYTES,
    )

run_step4_merge_tif_ocr_batches()
# Out:
# Merging 7 text files from C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\00_Projects\96_NT-Gold-CaseStudy\Reports-Tenements2\__type___tif__OCR___
#   -> Creating tif_ocr_batch_001.txt
# Done. Created 1 batch file(s) for prefix 'tif_ocr'.

# %% [markdown]
# ## Step 5: Extract Images from PDFs

# %%
import fitz
import csv
from concurrent.futures import ThreadPoolExecutor, as_completed

PDF_FOLDER        = BASE_FOLDER / "__type___pdf"
PDF_IMAGES_FOLDER = BASE_FOLDER / "__type___pdf___images"
PDF_IMAGES_FOLDER.mkdir(parents=True, exist_ok=True)

DPI = 300
MAX_WORKERS = 4
MIN_VECTOR_OPS       = 100
TEXT_CHAR_MAX        = 200
VERY_HIGH_VECTOR_OPS = 400

zoom = DPI / 72.0
MAT  = fitz.Matrix(zoom, zoom)

def page_metrics(page: fitz.Page):
    drawings = page.get_drawings() or []
    vector_ops = sum(len(d.get("items", ())) for d in drawings)
    text = page.get_text("text") or ""
    text_chars = len(text)
    image_count = len(page.get_images(full=True))
    return {"vector_ops": vector_ops, "text_chars": text_chars, "image_count": image_count}

def should_render(metrics):
    v, t = metrics["vector_ops"], metrics["text_chars"]
    if v >= VERY_HIGH_VECTOR_OPS:
        return True, f"vector_ops={v} (>= {VERY_HIGH_VECTOR_OPS})"
    if v >= MIN_VECTOR_OPS and t <= TEXT_CHAR_MAX:
        return True, f"vector_ops={v} & text_chars={t}"
    return False, f"skip (vector_ops={v}, text_chars={t})"

def render_selected_pages(pdf_path: Path):
    rows = []
    rendered = 0
    try:
        doc = fitz.open(pdf_path)
    except Exception as e:
        return f"FAIL open {pdf_path.name}: {e}", rows

    out_sub = PDF_IMAGES_FOLDER / pdf_path.stem
    out_sub.mkdir(parents=True, exist_ok=True)

    for i in range(len(doc)):
        page = doc.load_page(i)
        m = page_metrics(page)
        ok, reason = should_render(m)
        if not ok:
            continue
        try:
            pix = page.get_pixmap(matrix=MAT)
            out_png = out_sub / f"page-{i+1:04d}.png"
            pix.save(out_png)
            rendered += 1
            rows.append({
                "pdf_stem": pdf_path.stem,
                "pdf_path": str(pdf_path),
                "page": i + 1,
                "dpi": DPI,
                "vector_ops": m["vector_ops"],
                "text_chars": m["text_chars"],
                "image_count": m["image_count"],
                "image_path": str(out_png),
                "reason": reason,
            })
        except Exception as e:
            rows.append({
                "pdf_stem": pdf_path.stem,
                "pdf_path": str(pdf_path),
                "page": i + 1,
                "dpi": DPI,
                "vector_ops": m["vector_ops"],
                "text_chars": m["text_chars"],
                "image_count": m["image_count"],
                "image_path": "",
                "reason": f"ERROR: {e}",
            })

    status = f"OK   {pdf_path.name}: {rendered} vector pages"
    if rendered == 0:
        status = f"SKIP {pdf_path.name}: no vector-heavy pages"
    return status, rows

def run_step5_extract_pdf_images():
    pdfs = list(PDF_FOLDER.glob("*.pdf"))
    print("Found PDFs:", len(pdfs))

    all_rows = []
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as ex:
        futures = {ex.submit(render_selected_pages, pdf): pdf for pdf in pdfs}
        for fut in as_completed(futures):
            status, rows = fut.result()
            print(status)
            all_rows.extend(rows)

    index_csv = PDF_IMAGES_FOLDER / "page_index_vector.csv"
    if all_rows:
        with index_csv.open("w", newline="", encoding="utf-8") as f:
            w = csv.DictWriter(f, fieldnames=list(all_rows[0].keys()))
            w.writeheader()
            w.writerows(all_rows)
        print(f"\nIndexed {len(all_rows)} rendered pages → {index_csv}")
    else:
        print("\nNo pages rendered. Consider tuning thresholds.")

run_step5_extract_pdf_images()
# Out:
# Found PDFs: 5595
# SKIP 01_1990_annual_report_MCC205_208_MCC983_990.pdf: no vector-heavy pages
# SKIP 01_9934Y2A1.pdf: no vector-heavy pages
# SKIP 01_8104Y7AR.pdf: no vector-heavy pages
# SKIP 01_25490_Wonarah.pdf: no vector-heavy pages
# SKIP 01_Annual_report.pdf: no vector-heavy pages
# SKIP 01_Annual_reports_for_MCC316_MCC317_MCC338_MCC339_and_MCC342.pdf: no vector-heavy pages
# SKIP 01_A900_Logistics_Report.pdf: no vector-heavy pages
# SKIP 01_Annual_report_EL8773.pdf: no vector-heavy pages
# SKIP 01_Annual_report_EL9221.pdf: no vector-heavy pages
# OK   01_Annual_Report_EL23726.pdf: 2 vector pages
# SKIP 01_Annual_report_MCC308.pdf: no vector-heavy pages
# SKIP 01_Annual_report_MLC599.pdf: no vector-heavy pages
# OK   01_Annual_Report_EL9978_9-09-04.pdf: 1 vector pages
# SKIP 01_AP1782_1967_Reports.pdf: no vector-heavy pages
# OK   01_Aro-el23400%2cA04.pdf: 4 vector pages
# OK   01_Aro-el23409%2cA04.pdf: 4 vector pages
# OK   01_Combined_Final_Report_2000.pdf: 1 vector pages
# SKIP 01_ComstockGroup_2012_GA_01.pdf: no vector-heavy pages
# OK   01_Aro-el23383%2cA04.pdf: 4 vector pages
# SKIP 01_CR19570018.pdf: no vector-heavy pages
# SKIP 01_CR196500023.pdf: no vector-heavy pages
# SKIP 01_CR19650003.pdf: no vector-heavy pages
# SKIP 01_CR19650006.pdf: no vector-heavy pages
# SKIP 01_CR19650025.pdf: no vector-heavy pages
# SKIP 01_CR19660005.pdf: no vector-heavy pages
# OK   01_Aro_el23401_A04.pdf: 4 vector pages
# SKIP 01_CR19660018.pdf: no vector-heavy pages
# SKIP 01_CR19660045.pdf: no vector-heavy pages
# SKIP 01_CR19670003.pdf: no vector-heavy pages
# OK   01_ATR_EL23738_2004.pdf: 9 vector pages
# SKIP 01_CR19660050.pdf: no vector-heavy pages
# SKIP 01_CR19670042.pdf: no vector-heavy pages
# SKIP 01_CR19670044.pdf: no vector-heavy pages
# SKIP 01_CR19670057.pdf: no vector-heavy pages
# SKIP 01_CR19680005.pdf: no vector-heavy pages
# SKIP 01_CR19670058.pdf: no vector-heavy pages
# SKIP 01_CR19680024.pdf: no vector-heavy pages
# SKIP 01_CR19680016.pdf: no vector-heavy pages
# SKIP 01_CR19680025.pdf: no vector-heavy pages
# SKIP 01_CR19680030.pdf: no vector-heavy pages
# SKIP 01_CR19680031.pdf: no vector-heavy pages
# SKIP 01_CR19680037.pdf: no vector-heavy pages
# SKIP 01_CR19680032.pdf: no vector-heavy pages
# SKIP 01_CR19680040.pdf: no vector-heavy pages
# SKIP 01_CR19680051.pdf: no vector-heavy pages
# SKIP 01_CR19680052.pdf: no vector-heavy pages
# SKIP 01_CR19680057.pdf: no vector-heavy pages
# SKIP 01_CR19680083.pdf: no vector-heavy pages
# SKIP 01_CR19690001.pdf: no vector-heavy pages
# SKIP 01_CR19690020.pdf: no vector-heavy pages
# SKIP 01_CR19690021.pdf: no vector-heavy pages
# SKIP 01_CR19690024.pdf: no vector-heavy pages
# SKIP 01_CR19690022.pdf: no vector-heavy pages
# SKIP 01_CR19690085.pdf: no vector-heavy pages
# SKIP 01_CR19700010.pdf: no vector-heavy pages
# SKIP 01_CR19700007.pdf: no vector-heavy pages
# SKIP 01_CR19700025.pdf: no vector-heavy pages
# SKIP 01_CR19700033.pdf: no vector-heavy pages
# SKIP 01_CR19700032.pdf: no vector-heavy pages
# SKIP 01_CR19700037.pdf: no vector-heavy pages
# SKIP 01_CR19690098.pdf: no vector-heavy pages
# SKIP 01_CR19700038.pdf: no vector-heavy pages
# SKIP 01_CR19700036.pdf: no vector-heavy pages
# SKIP 01_CR19700039.pdf: no vector-heavy pages
# SKIP 01_CR19700040.pdf: no vector-heavy pages
# SKIP 01_CR19700059.pdf: no vector-heavy pages
# SKIP 01_CR19700076.pdf: no vector-heavy pages
# SKIP 01_CR19700078.pdf: no vector-heavy pages
# SKIP 01_CR19700082.pdf: no vector-heavy pages
# SKIP 01_CR19700080.pdf: no vector-heavy pages
# SKIP 01_CR19700079.pdf: no vector-heavy pages
# SKIP 01_CR19700083.pdf: no vector-heavy pages
# SKIP 01_CR19700090.pdf: no vector-heavy pages
# SKIP 01_CR19710012.pdf: no vector-heavy pages
# SKIP 01_CR19710028.pdf: no vector-heavy pages
# SKIP 01_CR19700103.pdf: no vector-heavy pages
# SKIP 01_CR19710038.pdf: no vector-heavy pages
# SKIP 01_CR19710059.pdf: no vector-heavy pages
# SKIP 01_CR19710060.pdf: no vector-heavy pages
# SKIP 01_CR19710041.pdf: no vector-heavy pages
# SKIP 01_CR19710067.pdf: no vector-heavy pages
# SKIP 01_CR19710046.pdf: no vector-heavy pages
# SKIP 01_CR19710070.pdf: no vector-heavy pages
# SKIP 01_CR19710083.pdf: no vector-heavy pages
# SKIP 01_CR19710092.pdf: no vector-heavy pages
# SKIP 01_CR19710076.pdf: no vector-heavy pages
# SKIP 01_CR19710094.pdf: no vector-heavy pages
# SKIP 01_CR19710084.pdf: no vector-heavy pages
# SKIP 01_CR19710139.pdf: no vector-heavy pages
# SKIP 01_CR19710096.pdf: no vector-heavy pages
# SKIP 01_CR19710173.pdf: no vector-heavy pages
# SKIP 01_CR19720002.pdf: no vector-heavy pages
# SKIP 01_CR19710192.pdf: no vector-heavy pages
# SKIP 01_CR19720029.pdf: no vector-heavy pages
# SKIP 01_CR19720007.pdf: no vector-heavy pages
# SKIP 01_CR19720042.pdf: no vector-heavy pages
# SKIP 01_CR19720059.pdf: no vector-heavy pages
# SKIP 01_CR19720061.pdf: no vector-heavy pages
# SKIP 01_CR19720062.pdf: no vector-heavy pages
# SKIP 01_CR19720081.pdf: no vector-heavy pages
# SKIP 01_CR19720034.pdf: no vector-heavy pages
# SKIP 01_CR19730008.pdf: no vector-heavy pages
# SKIP 01_CR19730007.pdf: no vector-heavy pages
# SKIP 01_CR19720129.pdf: no vector-heavy pages
# SKIP 01_CR19730049.pdf: no vector-heavy pages
# SKIP 01_CR19730030.pdf: no vector-heavy pages
# SKIP 01_CR19730050.pdf: no vector-heavy pages
# SKIP 01_CR19730056.pdf: no vector-heavy pages
# SKIP 01_CR19730051.pdf: no vector-heavy pages
# SKIP 01_CR19730057.pdf: no vector-heavy pages
# SKIP 01_CR19720072.pdf: no vector-heavy pages
# SKIP 01_CR19730064.pdf: no vector-heavy pages
# SKIP 01_CR19730062.pdf: no vector-heavy pages
# SKIP 01_CR19730129.pdf: no vector-heavy pages
# SKIP 01_CR19730059.pdf: no vector-heavy pages
# SKIP 01_CR19730069.pdf: no vector-heavy pages
# SKIP 01_CR19730115.pdf: no vector-heavy pages
# SKIP 01_CR19730131.pdf: no vector-heavy pages
# SKIP 01_CR19730157.pdf: no vector-heavy pages
# SKIP 01_CR19730130.pdf: no vector-heavy pages
# SKIP 01_CR19730151.pdf: no vector-heavy pages
# SKIP 01_CR19730152.pdf: no vector-heavy pages
# SKIP 01_CR19730161.pdf: no vector-heavy pages
# SKIP 01_CR19730168.pdf: no vector-heavy pages
# SKIP 01_CR19730165.pdf: no vector-heavy pages
# SKIP 01_CR19730170.pdf: no vector-heavy pages
# SKIP 01_CR19730178.pdf: no vector-heavy pages
# SKIP 01_CR19730174.pdf: no vector-heavy pages
# SKIP 01_CR19730177.pdf: no vector-heavy pages
# SKIP 01_CR19730179.pdf: no vector-heavy pages
# SKIP 01_CR19730180.pdf: no vector-heavy pages
# SKIP 01_CR19730189.pdf: no vector-heavy pages
# SKIP 01_CR19730194.pdf: no vector-heavy pages
# SKIP 01_CR19730188.pdf: no vector-heavy pages
# SKIP 01_CR19730198.pdf: no vector-heavy pages
# SKIP 01_CR19730199.pdf: no vector-heavy pages
# SKIP 01_CR19730206.pdf: no vector-heavy pages
# SKIP 01_CR19730232.pdf: no vector-heavy pages
# SKIP 01_CR19730235.pdf: no vector-heavy pages
# SKIP 01_CR19730233.pdf: no vector-heavy pages
# SKIP 01_CR19730236.pdf: no vector-heavy pages
# SKIP 01_CR19730237.pdf: no vector-heavy pages
# SKIP 01_CR19730197.pdf: no vector-heavy pages
# SKIP 01_CR19730246.pdf: no vector-heavy pages
# SKIP 01_CR19730274.pdf: no vector-heavy pages
# SKIP 01_CR19730257.pdf: no vector-heavy pages
# SKIP 01_CR19740004.pdf: no vector-heavy pages
# SKIP 01_CR19740007.pdf: no vector-heavy pages
# SKIP 01_CR19740011.pdf: no vector-heavy pages
# SKIP 01_CR19730272.pdf: no vector-heavy pages
# SKIP 01_CR19740030.pdf: no vector-heavy pages
# SKIP 01_CR19730277.pdf: no vector-heavy pages
# SKIP 01_CR19740020.pdf: no vector-heavy pages
# SKIP 01_CR19740031.pdf: no vector-heavy pages
# SKIP 01_CR19740012.pdf: no vector-heavy pages
# SKIP 01_CR19740044.pdf: no vector-heavy pages
# SKIP 01_CR19740079.pdf: no vector-heavy pages
# SKIP 01_CR19740086.pdf: no vector-heavy pages
# SKIP 01_CR19740077.pdf: no vector-heavy pages
# SKIP 01_CR19740085.pdf: no vector-heavy pages
# SKIP 01_CR19740100.pdf: no vector-heavy pages
# SKIP 01_CR19740090.pdf: no vector-heavy pages
# SKIP 01_CR19740122.pdf: no vector-heavy pages
# SKIP 01_CR19740124.pdf: no vector-heavy pages
# SKIP 01_CR19740142.pdf: no vector-heavy pages
# SKIP 01_CR19740140.pdf: no vector-heavy pages
# SKIP 01_CR19740125.pdf: no vector-heavy pages
# SKIP 01_CR19740141.pdf: no vector-heavy pages
# SKIP 01_CR19740171.pdf: no vector-heavy pages
# SKIP 01_CR19740170.pdf: no vector-heavy pages
# SKIP 01_CR19740172.pdf: no vector-heavy pages
# SKIP 01_CR19740149.pdf: no vector-heavy pages
# SKIP 01_CR19740176.pdf: no vector-heavy pages
# SKIP 01_CR19740181.pdf: no vector-heavy pages
# SKIP 01_CR19740175.pdf: no vector-heavy pages
# SKIP 01_CR19750007.pdf: no vector-heavy pages
# SKIP 01_CR19750008.pdf: no vector-heavy pages
# SKIP 01_CR19740196.pdf: no vector-heavy pages
# SKIP 01_CR19750009.pdf: no vector-heavy pages
# SKIP 01_CR19750011.pdf: no vector-heavy pages
# SKIP 01_CR19750010.pdf: no vector-heavy pages
# SKIP 01_CR19740197.pdf: no vector-heavy pages
# SKIP 01_CR19750012.pdf: no vector-heavy pages
# SKIP 01_CR19750013.pdf: no vector-heavy pages
# SKIP 01_CR19750022.pdf: no vector-heavy pages
# SKIP 01_CR19750016.pdf: no vector-heavy pages
# SKIP 01_CR19750025.pdf: no vector-heavy pages
# SKIP 01_CR19750014.pdf: no vector-heavy pages
# SKIP 01_CR19750026.pdf: no vector-heavy pages
# SKIP 01_CR19750064.pdf: no vector-heavy pages
# SKIP 01_CR19750031.pdf: no vector-heavy pages
# SKIP 01_CR19750068.pdf: no vector-heavy pages
# SKIP 01_CR19750069.pdf: no vector-heavy pages
# SKIP 01_CR19750065.pdf: no vector-heavy pages
# SKIP 01_CR19750070.pdf: no vector-heavy pages
# SKIP 01_CR19750071.pdf: no vector-heavy pages
# SKIP 01_CR19750072.pdf: no vector-heavy pages
# SKIP 01_CR19750077.pdf: no vector-heavy pages
# SKIP 01_CR19750066.pdf: no vector-heavy pages
# SKIP 01_CR19750079.pdf: no vector-heavy pages
# SKIP 01_CR19750091.pdf: no vector-heavy pages
# SKIP 01_CR19750078.pdf: no vector-heavy pages
# SKIP 01_CR19750090.pdf: no vector-heavy pages
# SKIP 01_CR19750095.pdf: no vector-heavy pages
# SKIP 01_CR19750093.pdf: no vector-heavy pages
# SKIP 01_CR19750094.pdf: no vector-heavy pages
# SKIP 01_CR19750092.pdf: no vector-heavy pages
# SKIP 01_CR19750097.pdf: no vector-heavy pages
# SKIP 01_CR19750096.pdf: no vector-heavy pages
# SKIP 01_CR19750098.pdf: no vector-heavy pages
# SKIP 01_CR19750099.pdf: no vector-heavy pages
# SKIP 01_CR19750100.pdf: no vector-heavy pages
# SKIP 01_CR19750101.pdf: no vector-heavy pages
# SKIP 01_CR19750123.pdf: no vector-heavy pages
# SKIP 01_CR19750140.pdf: no vector-heavy pages
# SKIP 01_CR19750103.pdf: no vector-heavy pages
# SKIP 01_CR19750152.pdf: no vector-heavy pages
# SKIP 01_CR19750157.pdf: no vector-heavy pages
# SKIP 01_CR19750153.pdf: no vector-heavy pages
# SKIP 01_CR19750158.pdf: no vector-heavy pages
# SKIP 01_CR19750159.pdf: no vector-heavy pages
# SKIP 01_CR19750141.pdf: no vector-heavy pages
# SKIP 01_CR19760012.pdf: no vector-heavy pages
# SKIP 01_CR19760007.pdf: no vector-heavy pages
# SKIP 01_CR19760001.pdf: no vector-heavy pages
# SKIP 01_CR19760017.pdf: no vector-heavy pages
# SKIP 01_CR19750164.pdf: no vector-heavy pages
# SKIP 01_CR19760018.pdf: no vector-heavy pages
# SKIP 01_CR19760013.pdf: no vector-heavy pages
# SKIP 01_CR19760019.pdf: no vector-heavy pages
# SKIP 01_CR19760035.pdf: no vector-heavy pages
# SKIP 01_CR19760039.pdf: no vector-heavy pages
# SKIP 01_CR19760036.pdf: no vector-heavy pages
# SKIP 01_CR19760040.pdf: no vector-heavy pages
# SKIP 01_CR19760037.pdf: no vector-heavy pages
# SKIP 01_CR19760041.pdf: no vector-heavy pages
# SKIP 01_CR19760047.pdf: no vector-heavy pages
# SKIP 01_CR19760056.pdf: no vector-heavy pages
# SKIP 01_CR19760057.pdf: no vector-heavy pages
# SKIP 01_CR19760048.pdf: no vector-heavy pages
# SKIP 01_CR19760058.pdf: no vector-heavy pages
# SKIP 01_CR19760061.pdf: no vector-heavy pages
# SKIP 01_CR19760059.pdf: no vector-heavy pages
# SKIP 01_CR19760060.pdf: no vector-heavy pages
# SKIP 01_CR19760074.pdf: no vector-heavy pages
# SKIP 01_CR19760064.pdf: no vector-heavy pages
# SKIP 01_CR19760075.pdf: no vector-heavy pages
# SKIP 01_CR19760076.pdf: no vector-heavy pages
# SKIP 01_CR19760077.pdf: no vector-heavy pages
# SKIP 01_CR19760088.pdf: no vector-heavy pages
# SKIP 01_CR19760096.pdf: no vector-heavy pages
# SKIP 01_CR19760097.pdf: no vector-heavy pages
# SKIP 01_CR19760104.pdf: no vector-heavy pages
# SKIP 01_CR19760089.pdf: no vector-heavy pages
# SKIP 01_CR19760102.pdf: no vector-heavy pages
# SKIP 01_CR19760112.pdf: no vector-heavy pages
# SKIP 01_CR19770011.pdf: no vector-heavy pages
# SKIP 01_CR19770025.pdf: no vector-heavy pages
# SKIP 01_CR19770026.pdf: no vector-heavy pages
# SKIP 01_CR19760113.pdf: no vector-heavy pages
# SKIP 01_CR19770027.pdf: no vector-heavy pages
# SKIP 01_CR19770028.pdf: no vector-heavy pages
# SKIP 01_CR19770037.pdf: no vector-heavy pages
# SKIP 01_CR19770036.pdf: no vector-heavy pages
# SKIP 01_CR19770038.pdf: no vector-heavy pages
# SKIP 01_CR19770040.pdf: no vector-heavy pages
# SKIP 01_CR19770063.pdf: no vector-heavy pages
# SKIP 01_CR19770077.pdf: no vector-heavy pages
# SKIP 01_CR19770085.pdf: no vector-heavy pages
# SKIP 01_CR19770086.pdf: no vector-heavy pages
# SKIP 01_CR19770096.pdf: no vector-heavy pages
# SKIP 01_CR19770112.pdf: no vector-heavy pages
# SKIP 01_CR19770128.pdf: no vector-heavy pages
# SKIP 01_CR19770130.pdf: no vector-heavy pages
# SKIP 01_CR19770131.pdf: no vector-heavy pages
# SKIP 01_CR19770138.pdf: no vector-heavy pages
# SKIP 01_CR19770143.pdf: no vector-heavy pages
# SKIP 01_CR19770144.pdf: no vector-heavy pages
# SKIP 01_CR19770146.pdf: no vector-heavy pages
# SKIP 01_CR19770161.pdf: no vector-heavy pages
# SKIP 01_CR19780001.pdf: no vector-heavy pages
# SKIP 01_CR19780016.pdf: no vector-heavy pages
# SKIP 01_CR19780015.pdf: no vector-heavy pages
# SKIP 01_CR19780018.pdf: no vector-heavy pages
# SKIP 01_CR19780020.pdf: no vector-heavy pages
# SKIP 01_CR19780017.pdf: no vector-heavy pages
# SKIP 01_CR19780040.pdf: no vector-heavy pages
# SKIP 01_CR19780059.pdf: no vector-heavy pages
# SKIP 01_CR19780053.pdf: no vector-heavy pages
# SKIP 01_CR19780084.pdf: no vector-heavy pages
# SKIP 01_CR19780085.pdf: no vector-heavy pages
# SKIP 01_CR19780121.pdf: no vector-heavy pages
# SKIP 01_CR19780122.pdf: no vector-heavy pages
# SKIP 01_CR19780124.pdf: no vector-heavy pages
# SKIP 01_CR19780158.pdf: no vector-heavy pages
# SKIP 01_CR19780123.pdf: no vector-heavy pages
# SKIP 01_CR19780178.pdf: no vector-heavy pages
# SKIP 01_CR19780177.pdf: no vector-heavy pages
# SKIP 01_CR19790003.pdf: no vector-heavy pages
# SKIP 01_CR19790010.pdf: no vector-heavy pages
# SKIP 01_CR19770081_A.pdf: no vector-heavy pages
# SKIP 01_CR19790016.pdf: no vector-heavy pages
# SKIP 01_CR19790017.pdf: no vector-heavy pages
# SKIP 01_CR19790018.pdf: no vector-heavy pages
# SKIP 01_CR19790051.pdf: no vector-heavy pages
# SKIP 01_CR19790034.pdf: no vector-heavy pages
# SKIP 01_CR19790062.pdf: no vector-heavy pages
# SKIP 01_CR19790130.pdf: no vector-heavy pages
# SKIP 01_CR19790132.pdf: no vector-heavy pages
# SKIP 01_CR19790088.pdf: no vector-heavy pages
# SKIP 01_CR19790087.pdf: no vector-heavy pages
# SKIP 01_CR19790155.pdf: no vector-heavy pages
# SKIP 01_CR19790188.pdf: no vector-heavy pages
# SKIP 01_CR19790141.pdf: no vector-heavy pages
# SKIP 01_CR19790187.pdf: no vector-heavy pages
# SKIP 01_CR19790190.pdf: no vector-heavy pages
# SKIP 01_CR19790189.pdf: no vector-heavy pages
# SKIP 01_CR19790196.pdf: no vector-heavy pages
# SKIP 01_CR19800007.pdf: no vector-heavy pages
# SKIP 01_CR19800002.pdf: no vector-heavy pages
# SKIP 01_CR19800014.pdf: no vector-heavy pages
# SKIP 01_CR19790195.pdf: no vector-heavy pages
# SKIP 01_CR19790201.pdf: no vector-heavy pages
# SKIP 01_CR19800015.pdf: no vector-heavy pages
# SKIP 01_CR19800028.pdf: no vector-heavy pages
# SKIP 01_CR19800044.pdf: no vector-heavy pages
# SKIP 01_CR19800070.pdf: no vector-heavy pages
# SKIP 01_CR19800071.pdf: no vector-heavy pages
# SKIP 01_CR19800058.pdf: no vector-heavy pages
# SKIP 01_CR19800115.pdf: no vector-heavy pages
# SKIP 01_CR19800159.pdf: no vector-heavy pages
# SKIP 01_CR19800157.pdf: no vector-heavy pages
# SKIP 01_CR19800161.pdf: no vector-heavy pages
# SKIP 01_CR19800162.pdf: no vector-heavy pages
# SKIP 01_CR19800163.pdf: no vector-heavy pages
# SKIP 01_CR19800164.pdf: no vector-heavy pages
# SKIP 01_CR19800169.pdf: no vector-heavy pages
# SKIP 01_CR19800208.pdf: no vector-heavy pages
# SKIP 01_CR19800206.pdf: no vector-heavy pages
# SKIP 01_CR19800233.pdf: no vector-heavy pages
# SKIP 01_CR19800234.pdf: no vector-heavy pages
# SKIP 01_CR19810001.pdf: no vector-heavy pages
# SKIP 01_CR19800199.pdf: no vector-heavy pages
# SKIP 01_CR19810007.pdf: no vector-heavy pages
# SKIP 01_CR19800235.pdf: no vector-heavy pages
# SKIP 01_CR19810008.pdf: no vector-heavy pages
# SKIP 01_CR19810021.pdf: no vector-heavy pages
# SKIP 01_CR19810020.pdf: no vector-heavy pages
# SKIP 01_CR19810022.pdf: no vector-heavy pages
# SKIP 01_CR19810024.pdf: no vector-heavy pages
# SKIP 01_CR19810034.pdf: no vector-heavy pages
# SKIP 01_CR19810025.pdf: no vector-heavy pages
# SKIP 01_CR19810087.pdf: no vector-heavy pages
# SKIP 01_CR19810146.pdf: no vector-heavy pages
# SKIP 01_CR19810165.pdf: no vector-heavy pages
# SKIP 01_CR19810166.pdf: no vector-heavy pages
# SKIP 01_CR19810125.pdf: no vector-heavy pages
# SKIP 01_CR19810181.pdf: no vector-heavy pages
# SKIP 01_CR19810186.pdf: no vector-heavy pages
# SKIP 01_CR19810116.pdf: no vector-heavy pages
# SKIP 01_CR19810209.pdf: no vector-heavy pages
# SKIP 01_CR19810208.pdf: no vector-heavy pages
# SKIP 01_CR19810207.pdf: no vector-heavy pages
# SKIP 01_CR19810206.pdf: no vector-heavy pages
# SKIP 01_CR19810212.pdf: no vector-heavy pages
# SKIP 01_CR19810210.pdf: no vector-heavy pages
# SKIP 01_CR19810217.pdf: no vector-heavy pages
# SKIP 01_CR19810213.pdf: no vector-heavy pages
# SKIP 01_CR19810218.pdf: no vector-heavy pages
# SKIP 01_CR19810211.pdf: no vector-heavy pages
# SKIP 01_CR19810258.pdf: no vector-heavy pages
# SKIP 01_CR19810239.pdf: no vector-heavy pages
# SKIP 01_CR19810303.pdf: no vector-heavy pages
# SKIP 01_CR19820013.pdf: no vector-heavy pages
# SKIP 01_CR19820012.pdf: no vector-heavy pages
# SKIP 01_CR19820030.pdf: no vector-heavy pages
# SKIP 01_CR19820015.pdf: no vector-heavy pages
# SKIP 01_CR19820031.pdf: no vector-heavy pages
# SKIP 01_CR19820033.pdf: no vector-heavy pages
# SKIP 01_CR19820029.pdf: no vector-heavy pages
# SKIP 01_CR19820051.pdf: no vector-heavy pages
# SKIP 01_CR19820055.pdf: no vector-heavy pages
# SKIP 01_CR19820034.pdf: no vector-heavy pages
# SKIP 01_CR19820054.pdf: no vector-heavy pages
# SKIP 01_CR19820059.pdf: no vector-heavy pages
# SKIP 01_CR19820070.pdf: no vector-heavy pages
# SKIP 01_CR19820072.pdf: no vector-heavy pages
# SKIP 01_CR19820068.pdf: no vector-heavy pages
# SKIP 01_CR19820074.pdf: no vector-heavy pages
# SKIP 01_CR19820071.pdf: no vector-heavy pages
# SKIP 01_CR19820075.pdf: no vector-heavy pages
# SKIP 01_CR19820073.pdf: no vector-heavy pages
# SKIP 01_CR19820077.pdf: no vector-heavy pages
# SKIP 01_CR19820078.pdf: no vector-heavy pages
# SKIP 01_CR19820076.pdf: no vector-heavy pages
# SKIP 01_CR19820079.pdf: no vector-heavy pages
# SKIP 01_CR19820081.pdf: no vector-heavy pages
# SKIP 01_CR19820080.pdf: no vector-heavy pages
# SKIP 01_CR19820082.pdf: no vector-heavy pages
# SKIP 01_CR19820083.pdf: no vector-heavy pages
# SKIP 01_CR19820089.pdf: no vector-heavy pages
# SKIP 01_CR19820084.pdf: no vector-heavy pages
# SKIP 01_CR19820142.pdf: no vector-heavy pages
# SKIP 01_CR19820166.pdf: no vector-heavy pages
# SKIP 01_CR19820094.pdf: no vector-heavy pages
# SKIP 01_CR19820187.pdf: no vector-heavy pages
# SKIP 01_CR19820189.pdf: no vector-heavy pages
# SKIP 01_CR19820214.pdf: no vector-heavy pages
# SKIP 01_CR19820137.pdf: no vector-heavy pages
# SKIP 01_CR19820224.pdf: no vector-heavy pages
# SKIP 01_CR19820229.pdf: no vector-heavy pages
# SKIP 01_CR19820253.pdf: no vector-heavy pages
# SKIP 01_CR19820273.pdf: no vector-heavy pages
# SKIP 01_CR19820257.pdf: no vector-heavy pages
# SKIP 01_CR19820283.pdf: no vector-heavy pages
# SKIP 01_CR19820289.pdf: no vector-heavy pages
# SKIP 01_CR19820314.pdf: no vector-heavy pages
# SKIP 01_CR19820285.pdf: no vector-heavy pages
# SKIP 01_CR19820327.pdf: no vector-heavy pages
# SKIP 01_CR19820374.pdf: no vector-heavy pages
# SKIP 01_CR19820341.pdf: no vector-heavy pages
# SKIP 01_CR19820361.pdf: no vector-heavy pages
# SKIP 01_CR19820385.pdf: no vector-heavy pages
# SKIP 01_CR19820406.pdf: no vector-heavy pages
# SKIP 01_CR19820407.pdf: no vector-heavy pages
# SKIP 01_CR19820303.pdf: no vector-heavy pages
# SKIP 01_CR19830009.pdf: no vector-heavy pages
# SKIP 01_CR19830001.pdf: no vector-heavy pages
# OK   01_CR19820408.pdf: 1 vector pages
# SKIP 01_CR19830072.pdf: no vector-heavy pages
# SKIP 01_CR19830151.pdf: no vector-heavy pages
# SKIP 01_CR19830167.pdf: no vector-heavy pages
# SKIP 01_CR19830213.pdf: no vector-heavy pages
# SKIP 01_CR19830214.pdf: no vector-heavy pages
# SKIP 01_CR19830215.pdf: no vector-heavy pages
# SKIP 01_CR19830168.pdf: no vector-heavy pages
# SKIP 01_CR19830282.pdf: no vector-heavy pages
# SKIP 01_CR19830218.pdf: no vector-heavy pages
# SKIP 01_CR19830253.pdf: no vector-heavy pages
# SKIP 01_CR19830330.pdf: no vector-heavy pages
# SKIP 01_CR19830299.pdf: no vector-heavy pages
# SKIP 01_CR19830336.pdf: no vector-heavy pages
# SKIP 01_CR19830339.pdf: no vector-heavy pages
# SKIP 01_CR19830344.pdf: no vector-heavy pages
# SKIP 01_CR19840027.pdf: no vector-heavy pages
# SKIP 01_CR19840043.pdf: no vector-heavy pages
# SKIP 01_CR19840091.pdf: no vector-heavy pages
# SKIP 01_CR19840086.pdf: no vector-heavy pages
# SKIP 01_CR19840095.pdf: no vector-heavy pages
# SKIP 01_CR19840141.pdf: no vector-heavy pages
# SKIP 01_CR19840116.pdf: no vector-heavy pages
# SKIP 01_CR19840068.pdf: no vector-heavy pages
# SKIP 01_CR19840143.pdf: no vector-heavy pages
# SKIP 01_CR19840146.pdf: no vector-heavy pages
# SKIP 01_CR19840151.pdf: no vector-heavy pages
# SKIP 01_CR19840144.pdf: no vector-heavy pages
# SKIP 01_CR19840152.pdf: no vector-heavy pages
# SKIP 01_CR19840198.pdf: no vector-heavy pages
# SKIP 01_CR19840223.pdf: no vector-heavy pages
# SKIP 01_CR19840150.pdf: no vector-heavy pages
# SKIP 01_CR19840224.pdf: no vector-heavy pages
# SKIP 01_CR19840228.pdf: no vector-heavy pages
# SKIP 01_CR19840226.pdf: no vector-heavy pages
# SKIP 01_CR19840231.pdf: no vector-heavy pages
# SKIP 01_CR19840230.pdf: no vector-heavy pages
# SKIP 01_CR19840232.pdf: no vector-heavy pages
# SKIP 01_CR19840237.pdf: no vector-heavy pages
# SKIP 01_CR19840250.pdf: no vector-heavy pages
# SKIP 01_CR19840234.pdf: no vector-heavy pages
# SKIP 01_CR19840260.pdf: no vector-heavy pages
# SKIP 01_CR19840257.pdf: no vector-heavy pages
# SKIP 01_CR19850006.pdf: no vector-heavy pages
# SKIP 01_CR19850014.pdf: no vector-heavy pages
# SKIP 01_CR19850010.pdf: no vector-heavy pages
# SKIP 01_CR19850022.pdf: no vector-heavy pages
# SKIP 01_CR19850013.pdf: no vector-heavy pages
# SKIP 01_CR19850021.pdf: no vector-heavy pages
# SKIP 01_CR19850023.pdf: no vector-heavy pages
# SKIP 01_CR19850038.pdf: no vector-heavy pages
# SKIP 01_CR19850024.pdf: no vector-heavy pages
# SKIP 01_CR19850039.pdf: no vector-heavy pages
# SKIP 01_CR19850110.pdf: no vector-heavy pages
# SKIP 01_CR19850041.pdf: no vector-heavy pages
# SKIP 01_CR19850130.pdf: no vector-heavy pages
# SKIP 01_CR19850057.pdf: no vector-heavy pages
# SKIP 01_CR19850118.pdf: no vector-heavy pages
# SKIP 01_CR19850142.pdf: no vector-heavy pages
# SKIP 01_CR19850148.pdf: no vector-heavy pages
# SKIP 01_CR19850170.pdf: no vector-heavy pages
# SKIP 01_CR19850172.pdf: no vector-heavy pages
# SKIP 01_CR19850171.pdf: no vector-heavy pages
# SKIP 01_CR19850232.pdf: no vector-heavy pages
# SKIP 01_CR19850235.pdf: no vector-heavy pages
# SKIP 01_CR19850236.pdf: no vector-heavy pages
# SKIP 01_CR19850224.pdf: no vector-heavy pages
# SKIP 01_CR19850272.pdf: no vector-heavy pages
# SKIP 01_CR19850265.pdf: no vector-heavy pages
# SKIP 01_CR19850271.pdf: no vector-heavy pages
# SKIP 01_CR19850284.pdf: no vector-heavy pages
# SKIP 01_CR19850293.pdf: no vector-heavy pages
# SKIP 01_CR19850309.pdf: no vector-heavy pages
# SKIP 01_CR19850291.pdf: no vector-heavy pages
# SKIP 01_CR19850275.pdf: no vector-heavy pages
# SKIP 01_CR19860008.pdf: no vector-heavy pages
# SKIP 01_CR19860002.pdf: no vector-heavy pages
# SKIP 01_CR19860017.pdf: no vector-heavy pages
# SKIP 01_CR19860001.pdf: no vector-heavy pages
# SKIP 01_CR19860019.pdf: no vector-heavy pages
# SKIP 01_CR19860018.pdf: no vector-heavy pages
# SKIP 01_CR19860023.pdf: no vector-heavy pages
# SKIP 01_CR19860021.pdf: no vector-heavy pages
# SKIP 01_CR19860020.pdf: no vector-heavy pages
# SKIP 01_CR19860022.pdf: no vector-heavy pages
# SKIP 01_CR19860025.pdf: no vector-heavy pages
# SKIP 01_CR19860068.pdf: no vector-heavy pages
# SKIP 01_CR19860034.pdf: no vector-heavy pages
# SKIP 01_CR19860070.pdf: no vector-heavy pages
# SKIP 01_CR19860064.pdf: no vector-heavy pages
# SKIP 01_CR19860077.pdf: no vector-heavy pages
# SKIP 01_CR19860071.pdf: no vector-heavy pages
# SKIP 01_CR19860075.pdf: no vector-heavy pages
# SKIP 01_CR19860081.pdf: no vector-heavy pages
# SKIP 01_CR19860084.pdf: no vector-heavy pages
# SKIP 01_CR19860086.pdf: no vector-heavy pages
# SKIP 01_CR19860090.pdf: no vector-heavy pages
# SKIP 01_CR19860091.pdf: no vector-heavy pages
# SKIP 01_CR19860099.pdf: no vector-heavy pages
# SKIP 01_CR19860111.pdf: no vector-heavy pages
# SKIP 01_CR19860100.pdf: no vector-heavy pages
# SKIP 01_CR19860110.pdf: no vector-heavy pages
# SKIP 01_CR19860130.pdf: no vector-heavy pages
# SKIP 01_CR19860116.pdf: no vector-heavy pages
# SKIP 01_CR19860114.pdf: no vector-heavy pages
# SKIP 01_CR19860190.pdf: no vector-heavy pages
# SKIP 01_CR19860188.pdf: no vector-heavy pages
# SKIP 01_CR19860196.pdf: no vector-heavy pages
# SKIP 01_CR19860141.pdf: no vector-heavy pages
# SKIP 01_CR19860213.pdf: no vector-heavy pages
# SKIP 01_CR19860214.pdf: no vector-heavy pages
# SKIP 01_CR19860215.pdf: no vector-heavy pages
# SKIP 01_CR19860236.pdf: no vector-heavy pages
# SKIP 01_CR19860254.pdf: no vector-heavy pages
# SKIP 01_CR19860292.pdf: no vector-heavy pages
# SKIP 01_CR19860288.pdf: no vector-heavy pages
# SKIP 01_CR19860293.pdf: no vector-heavy pages
# SKIP 01_CR19860316.pdf: no vector-heavy pages
# SKIP 01_CR19870007.pdf: no vector-heavy pages
# SKIP 01_CR19860317.pdf: no vector-heavy pages
# SKIP 01_CR19870021.pdf: no vector-heavy pages
# SKIP 01_CR19870019.pdf: no vector-heavy pages
# SKIP 01_CR19860289.pdf: no vector-heavy pages
# SKIP 01_CR19870023.pdf: no vector-heavy pages
# SKIP 01_CR19870022.pdf: no vector-heavy pages
# SKIP 01_CR19870064.pdf: no vector-heavy pages
# SKIP 01_CR19870065.pdf: no vector-heavy pages
# SKIP 01_CR19870038.pdf: no vector-heavy pages
# SKIP 01_CR19870086.pdf: no vector-heavy pages
# SKIP 01_CR19870071.pdf: no vector-heavy pages
# SKIP 01_CR19870088.pdf: no vector-heavy pages
# SKIP 01_CR19870066.pdf: no vector-heavy pages
# SKIP 01_CR19870091.pdf: no vector-heavy pages
# SKIP 01_CR19870115.pdf: no vector-heavy pages
# SKIP 01_CR19870116.pdf: no vector-heavy pages
# SKIP 01_CR19870176.pdf: no vector-heavy pages
# SKIP 01_CR19870151.pdf: no vector-heavy pages
# SKIP 01_CR19870179.pdf: no vector-heavy pages
# SKIP 01_CR19870189.pdf: no vector-heavy pages
# SKIP 01_CR19870177.pdf: no vector-heavy pages
# SKIP 01_CR19870178.pdf: no vector-heavy pages
# SKIP 01_CR19870208.pdf: no vector-heavy pages
# SKIP 01_CR19870236.pdf: no vector-heavy pages
# SKIP 01_CR19870217.pdf: no vector-heavy pages
# SKIP 01_CR19870281.pdf: no vector-heavy pages
# SKIP 01_CR19870243.pdf: no vector-heavy pages
# SKIP 01_CR19870246.pdf: no vector-heavy pages
# SKIP 01_CR19870312.pdf: no vector-heavy pages
# SKIP 01_CR19880002.pdf: no vector-heavy pages
# SKIP 01_CR19870362.pdf: no vector-heavy pages
# SKIP 01_CR19870282.pdf: no vector-heavy pages
# SKIP 01_CR19880018.pdf: no vector-heavy pages
# SKIP 01_CR19880030.pdf: no vector-heavy pages
# SKIP 01_CR19880017.pdf: no vector-heavy pages
# SKIP 01_CR19880031.pdf: no vector-heavy pages
# SKIP 01_CR19880034.pdf: no vector-heavy pages
# SKIP 01_CR19880039.pdf: no vector-heavy pages
# SKIP 01_CR19880040.pdf: no vector-heavy pages
# SKIP 01_CR19880042.pdf: no vector-heavy pages
# SKIP 01_CR19880058.pdf: no vector-heavy pages
# SKIP 01_CR19880041.pdf: no vector-heavy pages
# SKIP 01_CR19880071.pdf: no vector-heavy pages
# SKIP 01_CR19880069.pdf: no vector-heavy pages
# SKIP 01_CR19880077.pdf: no vector-heavy pages
# SKIP 01_CR19880081.pdf: no vector-heavy pages
# SKIP 01_CR19880083.pdf: no vector-heavy pages
# SKIP 01_CR19880076.pdf: no vector-heavy pages
# SKIP 01_CR19880087.pdf: no vector-heavy pages
# SKIP 01_CR19880131.pdf: no vector-heavy pages
# SKIP 01_CR19880135.pdf: no vector-heavy pages
# SKIP 01_CR19880136.pdf: no vector-heavy pages
# SKIP 01_CR19880139.pdf: no vector-heavy pages
# SKIP 01_CR19880158.pdf: no vector-heavy pages
# SKIP 01_CR19880100.pdf: no vector-heavy pages
# SKIP 01_CR19880168.pdf: no vector-heavy pages
# SKIP 01_CR19880174.pdf: no vector-heavy pages
# SKIP 01_CR19880163.pdf: no vector-heavy pages
# SKIP 01_CR19880183.pdf: no vector-heavy pages
# SKIP 01_CR19880186.pdf: no vector-heavy pages
# SKIP 01_CR19880146.pdf: no vector-heavy pages
# SKIP 01_CR19880199.pdf: no vector-heavy pages
# SKIP 01_CR19880231.pdf: no vector-heavy pages
# SKIP 01_CR19880223.pdf: no vector-heavy pages
# SKIP 01_CR19880234.pdf: no vector-heavy pages
# SKIP 01_CR19880239.pdf: no vector-heavy pages
# SKIP 01_CR19880240.pdf: no vector-heavy pages
# SKIP 01_CR19880215.pdf: no vector-heavy pages
# SKIP 01_CR19880267.pdf: no vector-heavy pages
# SKIP 01_CR19880300.pdf: no vector-heavy pages
# SKIP 01_CR19880298.pdf: no vector-heavy pages
# SKIP 01_CR19880310.pdf: no vector-heavy pages
# SKIP 01_CR19880319.pdf: no vector-heavy pages
# SKIP 01_CR19880320.pdf: no vector-heavy pages
# SKIP 01_CR19880291.pdf: no vector-heavy pages
# SKIP 01_CR19880351.pdf: no vector-heavy pages
# SKIP 01_CR19880322.pdf: no vector-heavy pages
# SKIP 01_CR19880341.pdf: no vector-heavy pages
# SKIP 01_CR19880352.pdf: no vector-heavy pages
# SKIP 01_CR19880376.pdf: no vector-heavy pages
# SKIP 01_CR19880375.pdf: no vector-heavy pages
# SKIP 01_CR19880398.pdf: no vector-heavy pages
# SKIP 01_CR19880397.pdf: no vector-heavy pages
# SKIP 01_CR19880399.pdf: no vector-heavy pages
# SKIP 01_CR19880377.pdf: no vector-heavy pages
# SKIP 01_CR19880430.pdf: no vector-heavy pages
# SKIP 01_CR19880408.pdf: no vector-heavy pages
# SKIP 01_CR19880432.pdf: no vector-heavy pages
# SKIP 01_CR19880485.pdf: no vector-heavy pages
# SKIP 01_CR19880453.pdf: no vector-heavy pages
# SKIP 01_CR19890001.pdf: no vector-heavy pages
# SKIP 01_CR19890002.pdf: no vector-heavy pages
# SKIP 01_CR19880456.pdf: no vector-heavy pages
# SKIP 01_CR19880496.pdf: no vector-heavy pages
# SKIP 01_CR19890014.pdf: no vector-heavy pages
# SKIP 01_CR19890033.pdf: no vector-heavy pages
# SKIP 01_CR19890053.pdf: no vector-heavy pages
# SKIP 01_CR19890052.pdf: no vector-heavy pages
# SKIP 01_CR19890065.pdf: no vector-heavy pages
# SKIP 01_CR19890068.pdf: no vector-heavy pages
# SKIP 01_CR19890072.pdf: no vector-heavy pages
# SKIP 01_CR19890125.pdf: no vector-heavy pages
# SKIP 01_CR19890051.pdf: no vector-heavy pages
# SKIP 01_CR19890138.pdf: no vector-heavy pages
# SKIP 01_CR19890124.pdf: no vector-heavy pages
# SKIP 01_CR19890146.pdf: no vector-heavy pages
# SKIP 01_CR19890147.pdf: no vector-heavy pages
# SKIP 01_CR19890148.pdf: no vector-heavy pages
# SKIP 01_CR19890161.pdf: no vector-heavy pages
# SKIP 01_CR19890166.pdf: no vector-heavy pages
# SKIP 01_CR19890167.pdf: no vector-heavy pages
# SKIP 01_CR19890115.pdf: no vector-heavy pages
# SKIP 01_CR19890195.pdf: no vector-heavy pages
# SKIP 01_CR19890196.pdf: no vector-heavy pages
# SKIP 01_CR19890194.pdf: no vector-heavy pages
# SKIP 01_CR19890197.pdf: no vector-heavy pages
# SKIP 01_CR19890204.pdf: no vector-heavy pages
# SKIP 01_CR19890220.pdf: no vector-heavy pages
# SKIP 01_CR19890213.pdf: no vector-heavy pages
# SKIP 01_CR19890231.pdf: no vector-heavy pages
# SKIP 01_CR19890256.pdf: no vector-heavy pages
# SKIP 01_CR19890244.pdf: no vector-heavy pages
# SKIP 01_CR19890245.pdf: no vector-heavy pages
# SKIP 01_CR19890262.pdf: no vector-heavy pages
# SKIP 01_CR19890268.pdf: no vector-heavy pages
# SKIP 01_CR19890263.pdf: no vector-heavy pages
# SKIP 01_CR19890269.pdf: no vector-heavy pages
# SKIP 01_CR19890270.pdf: no vector-heavy pages
# SKIP 01_CR19890271.pdf: no vector-heavy pages
# SKIP 01_CR19890275.pdf: no vector-heavy pages
# SKIP 01_CR19890277.pdf: no vector-heavy pages
# SKIP 01_CR19890288.pdf: no vector-heavy pages
# SKIP 01_CR19890289.pdf: no vector-heavy pages
# SKIP 01_CR19890294.pdf: no vector-heavy pages
# SKIP 01_CR19890306.pdf: no vector-heavy pages
# SKIP 01_CR19890310.pdf: no vector-heavy pages
# SKIP 01_CR19890309.pdf: no vector-heavy pages
# SKIP 01_CR19890311.pdf: no vector-heavy pages
# SKIP 01_CR19890312.pdf: no vector-heavy pages
# SKIP 01_CR19890320.pdf: no vector-heavy pages
# SKIP 01_CR19890316.pdf: no vector-heavy pages
# SKIP 01_CR19890324.pdf: no vector-heavy pages
# SKIP 01_CR19890313.pdf: no vector-heavy pages
# SKIP 01_CR19890334.pdf: no vector-heavy pages
# SKIP 01_CR19890337.pdf: no vector-heavy pages
# SKIP 01_CR19890350.pdf: no vector-heavy pages
# SKIP 01_CR19890371.pdf: no vector-heavy pages
# SKIP 01_CR19890396.pdf: no vector-heavy pages
# SKIP 01_CR19890397.pdf: no vector-heavy pages
# SKIP 01_CR19890398.pdf: no vector-heavy pages
# SKIP 01_CR19890399.pdf: no vector-heavy pages
# SKIP 01_CR19890385.pdf: no vector-heavy pages
# SKIP 01_CR19890411.pdf: no vector-heavy pages
# SKIP 01_CR19890407.pdf: no vector-heavy pages
# SKIP 01_CR19890418.pdf: no vector-heavy pages
# SKIP 01_CR19890429.pdf: no vector-heavy pages
# SKIP 01_CR19890434.pdf: no vector-heavy pages
# SKIP 01_CR19890435.pdf: no vector-heavy pages
# SKIP 01_CR19890433.pdf: no vector-heavy pages
# SKIP 01_CR19890436.pdf: no vector-heavy pages
# SKIP 01_CR19890437.pdf: no vector-heavy pages
# SKIP 01_CR19890441.pdf: no vector-heavy pages
# SKIP 01_CR19890440.pdf: no vector-heavy pages
# SKIP 01_CR19890445.pdf: no vector-heavy pages
# SKIP 01_CR19890446.pdf: no vector-heavy pages
# SKIP 01_CR19890443.pdf: no vector-heavy pages
# SKIP 01_CR19890447.pdf: no vector-heavy pages
# SKIP 01_CR19890454.pdf: no vector-heavy pages
# SKIP 01_CR19890452.pdf: no vector-heavy pages
# SKIP 01_CR19890457.pdf: no vector-heavy pages
# SKIP 01_CR19890451.pdf: no vector-heavy pages
# SKIP 01_CR19890456.pdf: no vector-heavy pages
# SKIP 01_CR19890458.pdf: no vector-heavy pages
# SKIP 01_CR19890459.pdf: no vector-heavy pages
# SKIP 01_CR19890462.pdf: no vector-heavy pages
# SKIP 01_CR19890463.pdf: no vector-heavy pages
# SKIP 01_CR19890464.pdf: no vector-heavy pages
# OK   01_CR19890460.pdf: 2 vector pages
# SKIP 01_CR19890465.pdf: no vector-heavy pages
# SKIP 01_CR19890466.pdf: no vector-heavy pages
# SKIP 01_CR19890474.pdf: no vector-heavy pages
# SKIP 01_CR19890475.pdf: no vector-heavy pages
# SKIP 01_CR19890468.pdf: no vector-heavy pages
# SKIP 01_CR19890455.pdf: no vector-heavy pages
# SKIP 01_CR19890476.pdf: no vector-heavy pages
# SKIP 01_CR19890481.pdf: no vector-heavy pages
# SKIP 01_CR19890495.pdf: no vector-heavy pages
# SKIP 01_CR19890493.pdf: no vector-heavy pages
# SKIP 01_CR19890507.pdf: no vector-heavy pages
# SKIP 01_CR19890508.pdf: no vector-heavy pages
# SKIP 01_CR19890528.pdf: no vector-heavy pages
# SKIP 01_CR19890530.pdf: no vector-heavy pages
# SKIP 01_CR19890526.pdf: no vector-heavy pages
# SKIP 01_CR19890529.pdf: no vector-heavy pages
# SKIP 01_CR19890531.pdf: no vector-heavy pages
# SKIP 01_CR19890532.pdf: no vector-heavy pages
# SKIP 01_CR19890533.pdf: no vector-heavy pages
# SKIP 01_CR19890535.pdf: no vector-heavy pages
# SKIP 01_CR19890534.pdf: no vector-heavy pages
# SKIP 01_CR19890556.pdf: no vector-heavy pages
# SKIP 01_CR19890538.pdf: no vector-heavy pages
# SKIP 01_CR19890557.pdf: no vector-heavy pages
# SKIP 01_CR19890567.pdf: no vector-heavy pages
# SKIP 01_CR19890559.pdf: no vector-heavy pages
# SKIP 01_CR19890568.pdf: no vector-heavy pages
# SKIP 01_CR19890561.pdf: no vector-heavy pages
# SKIP 01_CR19890569.pdf: no vector-heavy pages
# SKIP 01_CR19890571.pdf: no vector-heavy pages
# SKIP 01_CR19890572.pdf: no vector-heavy pages
# SKIP 01_CR19890570.pdf: no vector-heavy pages
# SKIP 01_CR19890573.pdf: no vector-heavy pages
# SKIP 01_CR19890574.pdf: no vector-heavy pages
# SKIP 01_CR19890610.pdf: no vector-heavy pages
# SKIP 01_CR19890616.pdf: no vector-heavy pages
# SKIP 01_CR19890617.pdf: no vector-heavy pages
# SKIP 01_CR19890620.pdf: no vector-heavy pages
# SKIP 01_CR19890625.pdf: no vector-heavy pages
# SKIP 01_CR19890642.pdf: no vector-heavy pages
# SKIP 01_CR19890658.pdf: no vector-heavy pages
# SKIP 01_CR19890677.pdf: no vector-heavy pages
# SKIP 01_CR19890675.pdf: no vector-heavy pages
# SKIP 01_CR19890684.pdf: no vector-heavy pages
# SKIP 01_CR19890676.pdf: no vector-heavy pages
# SKIP 01_CR19890685.pdf: no vector-heavy pages
# SKIP 01_CR19890690.pdf: no vector-heavy pages
# SKIP 01_CR19890689.pdf: no vector-heavy pages
# SKIP 01_CR19890691.pdf: no vector-heavy pages
# SKIP 01_CR19890692.pdf: no vector-heavy pages
# SKIP 01_CR19890693.pdf: no vector-heavy pages
# SKIP 01_CR19890694.pdf: no vector-heavy pages
# SKIP 01_CR19890713.pdf: no vector-heavy pages
# SKIP 01_CR19890714.pdf: no vector-heavy pages
# SKIP 01_CR19890745.pdf: no vector-heavy pages
# SKIP 01_CR19890767.pdf: no vector-heavy pages
# SKIP 01_CR19890759.pdf: no vector-heavy pages
# SKIP 01_CR19890768.pdf: no vector-heavy pages
# SKIP 01_CR19890769.pdf: no vector-heavy pages
# SKIP 01_CR19890770.pdf: no vector-heavy pages
# SKIP 01_CR19890780.pdf: no vector-heavy pages
# SKIP 01_CR19890756.pdf: no vector-heavy pages
# SKIP 01_CR19890794.pdf: no vector-heavy pages
# SKIP 01_CR19890804.pdf: no vector-heavy pages
# SKIP 01_CR19890812.pdf: no vector-heavy pages
# SKIP 01_CR19890791.pdf: no vector-heavy pages
# SKIP 01_CR19890813.pdf: no vector-heavy pages
# SKIP 01_CR19890843.pdf: no vector-heavy pages
# SKIP 01_CR19890841.pdf: no vector-heavy pages
# SKIP 01_CR19890844.pdf: no vector-heavy pages
# SKIP 01_CR19890845.pdf: no vector-heavy pages
# SKIP 01_CR1990-0557.pdf: no vector-heavy pages
# SKIP 01_CR1990-0435_First_Annual_Report_MCC_907-913.pdf: no vector-heavy pages
# SKIP 01_CR19900003.pdf: no vector-heavy pages
# SKIP 01_CR19900011.pdf: no vector-heavy pages
# SKIP 01_CR19900031.pdf: no vector-heavy pages
# SKIP 01_CR19900064.pdf: no vector-heavy pages
# SKIP 01_CR19900091.pdf: no vector-heavy pages
# SKIP 01_CR19900095.pdf: no vector-heavy pages
# SKIP 01_CR19900092.pdf: no vector-heavy pages
# SKIP 01_CR19900075.pdf: no vector-heavy pages
# SKIP 01_CR19900114.pdf: no vector-heavy pages
# SKIP 01_CR19900115.pdf: no vector-heavy pages
# SKIP 01_CR19900133.pdf: no vector-heavy pages
# SKIP 01_CR19900096.pdf: no vector-heavy pages
# SKIP 01_CR19900119.pdf: no vector-heavy pages
# SKIP 01_CR19900141.pdf: no vector-heavy pages
# SKIP 01_CR19900145.pdf: no vector-heavy pages
# SKIP 01_CR19900144.pdf: no vector-heavy pages
# SKIP 01_CR19900146.pdf: no vector-heavy pages
# SKIP 01_CR19900147.pdf: no vector-heavy pages
# SKIP 01_CR19900148.pdf: no vector-heavy pages
# SKIP 01_CR19900151.pdf: no vector-heavy pages
# SKIP 01_CR19900150.pdf: no vector-heavy pages
# SKIP 01_CR19900149.pdf: no vector-heavy pages
# SKIP 01_CR19900153.pdf: no vector-heavy pages
# SKIP 01_CR19900154.pdf: no vector-heavy pages
# SKIP 01_CR19900156.pdf: no vector-heavy pages
# SKIP 01_CR19900155.pdf: no vector-heavy pages
# SKIP 01_CR19900158.pdf: no vector-heavy pages
# SKIP 01_CR19900159.pdf: no vector-heavy pages
# SKIP 01_CR19900160.pdf: no vector-heavy pages
# SKIP 01_CR19900157.pdf: no vector-heavy pages
# SKIP 01_CR19900176.pdf: no vector-heavy pages
# SKIP 01_CR19900177.pdf: no vector-heavy pages
# SKIP 01_CR19900178.pdf: no vector-heavy pages
# SKIP 01_CR19900181.pdf: no vector-heavy pages
# SKIP 01_CR19900179.pdf: no vector-heavy pages
# SKIP 01_CR19900216.pdf: no vector-heavy pages
# SKIP 01_CR19900190.pdf: no vector-heavy pages
# SKIP 01_CR19900191.pdf: no vector-heavy pages
# SKIP 01_CR19900223.pdf: no vector-heavy pages
# SKIP 01_CR19900225.pdf: no vector-heavy pages
# SKIP 01_CR19900226.pdf: no vector-heavy pages
# SKIP 01_CR19900232.pdf: no vector-heavy pages
# SKIP 01_CR19900231.pdf: no vector-heavy pages
# SKIP 01_CR19900237.pdf: no vector-heavy pages
# SKIP 01_CR19900203.pdf: no vector-heavy pages
# SKIP 01_CR19900264.pdf: no vector-heavy pages
# SKIP 01_CR19900259.pdf: no vector-heavy pages
# SKIP 01_CR19900258.pdf: no vector-heavy pages
# SKIP 01_CR19900292.pdf: no vector-heavy pages
# SKIP 01_CR19900300.pdf: no vector-heavy pages
# SKIP 01_CR19900299.pdf: no vector-heavy pages
# SKIP 01_CR19900301.pdf: no vector-heavy pages
# SKIP 01_CR19900302.pdf: no vector-heavy pages
# SKIP 01_CR19900311.pdf: no vector-heavy pages
# SKIP 01_CR19900320.pdf: no vector-heavy pages
# SKIP 01_CR19900322.pdf: no vector-heavy pages
# SKIP 01_CR19900321.pdf: no vector-heavy pages
# SKIP 01_CR19900352.pdf: no vector-heavy pages
# SKIP 01_CR19900350.pdf: no vector-heavy pages
# SKIP 01_CR19900381.pdf: no vector-heavy pages
# SKIP 01_CR19900405.pdf: no vector-heavy pages
# SKIP 01_CR19900404.pdf: no vector-heavy pages
# SKIP 01_CR19900403.pdf: no vector-heavy pages
# SKIP 01_CR19900407.pdf: no vector-heavy pages
# SKIP 01_CR19900408.pdf: no vector-heavy pages
# SKIP 01_CR19900410.pdf: no vector-heavy pages
# SKIP 01_CR19900412.pdf: no vector-heavy pages
# SKIP 01_CR19900411.pdf: no vector-heavy pages
# SKIP 01_CR19900409.pdf: no vector-heavy pages
# SKIP 01_CR19900420.pdf: no vector-heavy pages
# SKIP 01_CR19900426.pdf: no vector-heavy pages
# SKIP 01_CR19900432.pdf: no vector-heavy pages
# SKIP 01_CR19900439.pdf: no vector-heavy pages
# SKIP 01_CR19900444.pdf: no vector-heavy pages
# SKIP 01_CR19900445.pdf: no vector-heavy pages
# SKIP 01_CR19900446.pdf: no vector-heavy pages
# SKIP 01_CR19900449.pdf: no vector-heavy pages
# SKIP 01_CR19900448.pdf: no vector-heavy pages
# SKIP 01_CR19900462.pdf: no vector-heavy pages
# SKIP 01_CR19900455.pdf: no vector-heavy pages
# SKIP 01_CR19900463.pdf: no vector-heavy pages
# SKIP 01_CR19900465.pdf: no vector-heavy pages
# SKIP 01_CR19900464.pdf: no vector-heavy pages
# SKIP 01_CR19900452.pdf: no vector-heavy pages
# SKIP 01_CR19900475.pdf: no vector-heavy pages
# SKIP 01_CR19900482.pdf: no vector-heavy pages
# SKIP 01_CR19900486.pdf: no vector-heavy pages
# SKIP 01_CR19900487.pdf: no vector-heavy pages
# SKIP 01_CR19900466.pdf: no vector-heavy pages
# SKIP 01_CR19900505.pdf: no vector-heavy pages
# SKIP 01_CR19900512.pdf: no vector-heavy pages
# SKIP 01_CR19900536.pdf: no vector-heavy pages
# SKIP 01_CR19900527.pdf: no vector-heavy pages
# SKIP 01_CR19900526.pdf: no vector-heavy pages
# SKIP 01_CR19900551.pdf: no vector-heavy pages
# SKIP 01_CR19900582.pdf: no vector-heavy pages
# SKIP 01_CR19900590.pdf: no vector-heavy pages
# SKIP 01_CR19900608.pdf: no vector-heavy pages
# SKIP 01_CR19900558.pdf: no vector-heavy pages
# SKIP 01_CR19900647.pdf: no vector-heavy pages
# SKIP 01_CR19900650.pdf: no vector-heavy pages
# SKIP 01_CR19900635.pdf: no vector-heavy pages
# SKIP 01_CR19900666.pdf: no vector-heavy pages
# SKIP 01_CR19900672.pdf: no vector-heavy pages
# SKIP 01_CR19900667.pdf: no vector-heavy pages
# SKIP 01_CR19900674.pdf: no vector-heavy pages
# SKIP 01_CR19900675.pdf: no vector-heavy pages
# SKIP 01_CR19900697.pdf: no vector-heavy pages
# SKIP 01_CR19900688.pdf: no vector-heavy pages
# SKIP 01_CR19900687.pdf: no vector-heavy pages
# SKIP 01_CR19900699.pdf: no vector-heavy pages
# SKIP 01_CR19900698.pdf: no vector-heavy pages
# SKIP 01_CR19900691.pdf: no vector-heavy pages
# SKIP 01_CR19910038.pdf: no vector-heavy pages
# SKIP 01_CR1990432.pdf: no vector-heavy pages
# SKIP 01_CR19910046.pdf: no vector-heavy pages
# SKIP 01_CR19910049.pdf: no vector-heavy pages
# SKIP 01_CR19910064.pdf: no vector-heavy pages
# SKIP 01_CR19910050.pdf: no vector-heavy pages
# SKIP 01_CR19910066.pdf: no vector-heavy pages
# SKIP 01_CR19910099.pdf: no vector-heavy pages
# SKIP 01_CR19910065.pdf: no vector-heavy pages
# SKIP 01_CR19910120.pdf: no vector-heavy pages
# SKIP 01_CR19910146.pdf: no vector-heavy pages
# SKIP 01_CR19910147.pdf: no vector-heavy pages
# SKIP 01_CR19910115.pdf: no vector-heavy pages
# SKIP 01_CR19910152.pdf: no vector-heavy pages
# SKIP 01_CR19910156.pdf: no vector-heavy pages
# SKIP 01_CR19910158.pdf: no vector-heavy pages
# SKIP 01_CR19910157.pdf: no vector-heavy pages
# SKIP 01_CR19910155.pdf: no vector-heavy pages
# SKIP 01_CR19910167.pdf: no vector-heavy pages
# SKIP 01_CR19910159.pdf: no vector-heavy pages
# SKIP 01_CR19910170.pdf: no vector-heavy pages
# SKIP 01_CR19910171.pdf: no vector-heavy pages
# SKIP 01_CR19910173.pdf: no vector-heavy pages
# SKIP 01_CR19910172.pdf: no vector-heavy pages
# SKIP 01_CR19910176.pdf: no vector-heavy pages
# SKIP 01_CR19910175.pdf: no vector-heavy pages
# SKIP 01_CR19910177.pdf: no vector-heavy pages
# SKIP 01_CR19910183.pdf: no vector-heavy pages
# SKIP 01_CR19910178.pdf: no vector-heavy pages
# SKIP 01_CR19910184.pdf: no vector-heavy pages
# SKIP 01_CR19910185.pdf: no vector-heavy pages
# SKIP 01_CR19910192.pdf: no vector-heavy pages
# SKIP 01_CR19910193.pdf: no vector-heavy pages
# SKIP 01_CR19910204.pdf: no vector-heavy pages
# SKIP 01_CR19910210.pdf: no vector-heavy pages
# SKIP 01_CR19910214.pdf: no vector-heavy pages
# SKIP 01_CR19910217.pdf: no vector-heavy pages
# SKIP 01_CR19910218.pdf: no vector-heavy pages
# SKIP 01_CR19910212.pdf: no vector-heavy pages
# SKIP 01_CR19910219.pdf: no vector-heavy pages
# SKIP 01_CR19910220.pdf: no vector-heavy pages
# SKIP 01_CR19910229.pdf: no vector-heavy pages
# SKIP 01_CR19910231.pdf: no vector-heavy pages
# SKIP 01_CR19910232.pdf: no vector-heavy pages
# SKIP 01_CR19910230.pdf: no vector-heavy pages
# SKIP 01_CR19910250.pdf: no vector-heavy pages
# SKIP 01_CR19910248.pdf: no vector-heavy pages
# SKIP 01_CR19910262.pdf: no vector-heavy pages
# SKIP 01_CR19910289.pdf: no vector-heavy pages
# SKIP 01_CR19910298.pdf: no vector-heavy pages
# SKIP 01_CR19910256.pdf: no vector-heavy pages
# SKIP 01_CR19910304.pdf: no vector-heavy pages
# SKIP 01_CR19910316.pdf: no vector-heavy pages
# SKIP 01_CR19910326.pdf: no vector-heavy pages
# SKIP 01_CR19910337.pdf: no vector-heavy pages
# SKIP 01_CR19910374.pdf: no vector-heavy pages
# SKIP 01_CR19910383.pdf: no vector-heavy pages
# SKIP 01_CR19910348.pdf: no vector-heavy pages
# SKIP 01_CR19910393.pdf: no vector-heavy pages
# SKIP 01_CR19910388.pdf: no vector-heavy pages
# SKIP 01_CR19910405.pdf: no vector-heavy pages
# SKIP 01_CR19910423.pdf: no vector-heavy pages
# SKIP 01_CR19910421.pdf: no vector-heavy pages
# SKIP 01_CR19910422.pdf: no vector-heavy pages
# SKIP 01_CR19910455.pdf: no vector-heavy pages
# SKIP 01_CR19910457.pdf: no vector-heavy pages
# SKIP 01_CR19910456.pdf: no vector-heavy pages
# SKIP 01_CR19910469.pdf: no vector-heavy pages
# SKIP 01_CR19910470.pdf: no vector-heavy pages
# SKIP 01_CR19910471.pdf: no vector-heavy pages
# SKIP 01_CR19910472.pdf: no vector-heavy pages
# SKIP 01_CR19910474.pdf: no vector-heavy pages
# SKIP 01_CR19910473.pdf: no vector-heavy pages
# SKIP 01_CR19910476.pdf: no vector-heavy pages
# SKIP 01_CR19910475.pdf: no vector-heavy pages
# SKIP 01_CR19910486.pdf: no vector-heavy pages
# SKIP 01_CR19910493.pdf: no vector-heavy pages
# SKIP 01_CR19910484.pdf: no vector-heavy pages
# SKIP 01_CR19910494.pdf: no vector-heavy pages
# SKIP 01_CR19910509.pdf: no vector-heavy pages
# SKIP 01_CR19910487.pdf: no vector-heavy pages
# SKIP 01_CR19910496.pdf: no vector-heavy pages
# SKIP 01_CR19910517.pdf: no vector-heavy pages
# SKIP 01_CR19910564.pdf: no vector-heavy pages
# SKIP 01_CR19910570.pdf: no vector-heavy pages
# SKIP 01_CR19910593.pdf: no vector-heavy pages
# SKIP 01_CR19910568.pdf: no vector-heavy pages
# SKIP 01_CR19910585.pdf: no vector-heavy pages
# SKIP 01_CR19910597.pdf: no vector-heavy pages
# SKIP 01_CR19920011.pdf: no vector-heavy pages
# SKIP 01_CR19920006.pdf: no vector-heavy pages
# SKIP 01_CR19920010.pdf: no vector-heavy pages
# SKIP 01_CR19920068.pdf: no vector-heavy pages
# SKIP 01_CR19920036.pdf: no vector-heavy pages
# SKIP 01_CR19920014.pdf: no vector-heavy pages
# SKIP 01_CR19920079.pdf: no vector-heavy pages
# SKIP 01_CR19920072.pdf: no vector-heavy pages
# SKIP 01_CR19920063.pdf: no vector-heavy pages
# SKIP 01_CR19920097.pdf: no vector-heavy pages
# SKIP 01_CR19920114.pdf: no vector-heavy pages
# SKIP 01_CR19920110.pdf: no vector-heavy pages
# SKIP 01_CR19920115.pdf: no vector-heavy pages
# SKIP 01_CR19920089.pdf: no vector-heavy pages
# SKIP 01_CR19920158.pdf: no vector-heavy pages
# SKIP 01_CR19920159.pdf: no vector-heavy pages
# SKIP 01_CR19920169.pdf: no vector-heavy pages
# SKIP 01_CR19920146.pdf: no vector-heavy pages
# SKIP 01_CR19920195.pdf: no vector-heavy pages
# SKIP 01_CR19920207.pdf: no vector-heavy pages
# SKIP 01_CR19920187.pdf: no vector-heavy pages
# SKIP 01_CR19920214.pdf: no vector-heavy pages
# SKIP 01_CR19920223.pdf: no vector-heavy pages
# SKIP 01_CR19920196.pdf: no vector-heavy pages
# SKIP 01_CR19920232.pdf: no vector-heavy pages
# SKIP 01_CR19920233.pdf: no vector-heavy pages
# SKIP 01_CR19920253.pdf: no vector-heavy pages
# SKIP 01_CR19920245.pdf: no vector-heavy pages
# SKIP 01_CR19920237.pdf: no vector-heavy pages
# SKIP 01_CR19920269.pdf: no vector-heavy pages
# SKIP 01_CR19920286.pdf: no vector-heavy pages
# SKIP 01_CR19920270.pdf: no vector-heavy pages
# SKIP 01_CR19920287.pdf: no vector-heavy pages
# SKIP 01_CR19920226.pdf: no vector-heavy pages
# SKIP 01_CR19920288.pdf: no vector-heavy pages
# SKIP 01_CR19920294.pdf: no vector-heavy pages
# SKIP 01_CR19920299.pdf: no vector-heavy pages
# SKIP 01_CR19920297.pdf: no vector-heavy pages
# ...
# OK   05_EL29849_2016_P_2_AirborneEM_Report.pdf: 1 vector pages
# OK   05_GR016_2017_GA_BinEx_Geological_Report.pdf: 2 vector pages
# SKIP 05_ELR29627_2018_AS_01.pdf: no vector-heavy pages
# SKIP 05_GR135-09_2012_GAS_09_2012QAQC.pdf: no vector-heavy pages
# SKIP 05_GR097_2010_GA_05_Pet3_rpt.pdf: no vector-heavy pages
# SKIP 05_GR145_2015_GA_01.pdf: no vector-heavy pages
# SKIP 05_GR162_2014_GA_05_Appendix4.pdf: no vector-heavy pages
# OK   05_CR2011-0444_EL25581_2011_P_05_Line10020_BfZ_.pdf: 1 vector pages
# OK   05_GR226-12_2013_GA_06_Appendix_8.pdf: 2 vector pages
# SKIP 05_GR_162_12_2012_A_05_Barrow_Creek_EM_EL26825_CD_Fugro_Data.pdf: no vector-heavy pages
# OK   05_ELR29627_2014_A_05_Appendix4_NOI.pdf: 6 vector pages
# SKIP 05_IGO_LITHCODES.pdf: no vector-heavy pages
# SKIP 05_GR_162_12_2013_GA_05_Appendix4.pdf: no vector-heavy pages
# OK   05_MA74_2012_A_05_Figure4.pdf: 1 vector pages
# OK   05_GR250_2015_GA_05_Figure4.pdf: 1 vector pages
# OK   05_Partial_Relinquishment_EL9976_Feb2004.pdf: 1 vector pages
# SKIP 05_Photos_4.pdf: no vector-heavy pages
# OK   05_MA74_2013_A_05_Figure4.pdf: 1 vector pages
# OK   05_WAp45260.pdf: 1 vector pages
# SKIP 05_USI_EL27651_2013_A_Appdx_D.pdf: no vector-heavy pages
# SKIP 06_CR19730152_F.pdf: no vector-heavy pages
# OK   06_CR2004-0467_Appendix_13.pdf: 1 vector pages
# OK   06_CR20080620_2008_GA_06_Index.pdf: 1 vector pages
# OK   06_CR2012-0204_Fig5_EL27547_Basement_Depth_100KA4.pdf: 1 vector pages
# OK   06_CR2004-0728_EL23545_2004_P_01.pdf: 6 vector pages
# SKIP 06_CR19750164_F.pdf: no vector-heavy pages
# SKIP 06_EL22428_2011_S.pdf: no vector-heavy pages
# OK   06_EL10412_2011_S_06_logging_codes.pdf: 1 vector pages
# OK   06_CR2012-0424_Fig5_Geology_Plan.pdf: 1 vector pages
# SKIP 06_EL22786_2009_AS_02_Attack_Creek_Project_Summary.pdf: no vector-heavy pages
# SKIP 06_EL23392_2005_A_01.pdf: no vector-heavy pages
# OK   06_EL23401_2007_A_06_Figure5.pdf: 1 vector pages
# OK   06_EL23400_2007_A_06_Figure5.pdf: 1 vector pages
# OK   06_EL23409_2007_A_06_Figure5.pdf: 1 vector pages
# SKIP 06_EL24604_2009_AS_06_QA_QC_Rockchip_Samples.pdf: no vector-heavy pages
# SKIP 06_EL24993_2007_A_01.pdf: no vector-heavy pages
# SKIP 06_EL26068_2008_S.pdf: no vector-heavy pages
# OK   06_EL23880_2014_P_06_Plate1.pdf: 1 vector pages
# OK   06_EL25354_2007_A_01.pdf: 4 vector pages
# SKIP 06_EL26589_2011_P_06_graphic_logs.pdf: no vector-heavy pages
# SKIP 06_EL26589_2012_AS_6_graphic_logs.pdf: no vector-heavy pages
# SKIP 06_EL26655_2011_A_02_LogisticsReport.pdf: no vector-heavy pages
# SKIP 06_EL27145_2010_A_06_Figure5.pdf: no vector-heavy pages
# SKIP 06_EL26227_2011_P_01.pdf: no vector-heavy pages
# SKIP 06_EL27546_2012_S_06_Fig5_27546_Relative_Basement_Density.pdf: no vector-heavy pages
# OK   06_EL27891_2012_P_06_Fig6.pdf: 1 vector pages
# OK   06_EL28662_2012_A_06_logging_codes.pdf: 1 vector pages
# OK   06_EL28662_2013_A_06_loggingcodes.pdf: 1 vector pages
# OK   06_EL28521_2015_A_01.pdf: 1 vector pages
# SKIP 06_EL29161_2014_A_03_Appendix2.pdf: no vector-heavy pages
# SKIP 06_EL29841_2017_P_1_Report.pdf: no vector-heavy pages
# SKIP 06_EL29849_2016_P_3_Exploration_Site_Audit_Report.pdf: no vector-heavy pages
# SKIP 06_GR018_2012_GA_01.pdf: no vector-heavy pages
# SKIP 06_GR145_2012_GA_06_LithologyCode.pdf: no vector-heavy pages
# OK   06_GR162_2014_GA_06_Plate1.pdf: 1 vector pages
# OK   06_Figure5.pdf: 1 vector pages
# SKIP 06_GR226_2014_GA_05_Appendix2_PetrographyReport.pdf: no vector-heavy pages
# OK   06_GR226-12_2013_GA_07_Appendix_9.pdf: 2 vector pages
# SKIP 06_GR292_2013_A_01.pdf: no vector-heavy pages
# OK   06_GR250_2015_GA_06_Figure5.pdf: 1 vector pages
# SKIP 06_GR293_2014_A_06_Appendix1.pdf: no vector-heavy pages
# SKIP 06_GR_162_12_2012_A_06_EleanorFieldReport_Vandenberg.pdf: no vector-heavy pages
# SKIP 06_Report_in_support_of_renewal_of_SEL9214.pdf: no vector-heavy pages
# OK   06_CR2011-0444_EL25581_2011_P_06_Line10020_dBZ_.pdf: 1 vector pages
# OK   06_WAp45261.pdf: 1 vector pages
# OK   07_CR2004-0467_Appendix_14.pdf: 1 vector pages
# OK   07_CR20080620_2008_GA_07_Location.pdf: 1 vector pages
# SKIP 07_CR19750164_G.pdf: no vector-heavy pages
# SKIP 07_CR20100883_2010_Emmerson_01.pdf: no vector-heavy pages
# OK   06_GR_162_12_2013_GA_06_Appendix5.pdf: 7 vector pages
# OK   07_CR2012-0204_Fig6_EL27547_Magnetic_Susceptibility_100KA4.pdf: 1 vector pages
# SKIP 07_CR2012-0424_Fig6_Basement_Depth.pdf: no vector-heavy pages
# SKIP 07_EL23392_2005_A_02_work_program.pdf: no vector-heavy pages
# SKIP 07_EL23947_2009_P_01.pdf: no vector-heavy pages
# OK   07_EL23880_2014_P_07_Plate2.pdf: 1 vector pages
# SKIP 07_EL24009_2019_C_07_Photos.pdf: no vector-heavy pages
# SKIP 07_EL24009_2019_S_07_Photos.pdf: no vector-heavy pages
# SKIP 07_EL25354_2007_A_02_Landsat_ETM_Info.pdf: no vector-heavy pages
# SKIP 07_EL26077_2008_S.pdf: no vector-heavy pages
# SKIP 07_EL25578_2008_A_01.pdf: no vector-heavy pages
# OK   07_EL27115_2017_AS_08_Lithology_Code.pdf: 1 vector pages
# OK   07_EL26589_2011_P_08_EM_report.pdf: 1 vector pages
# SKIP 07_EL27145_2010_A_07_Figure6.pdf: no vector-heavy pages
# SKIP 07_EL27546_2012_S_07_Fig6_27546_Relative_Magnetic_Susceptibility.pdf: no vector-heavy pages
# OK   07_EL27196_2011_A_07_App5_PDF_Files_Report_Figures.pdf: 7 vector pages
# OK   07_EL27891_2012_P_07_Fig7.pdf: 1 vector pages
# OK   07_EL27614_2012_P_07_App4_Figures.pdf: 5 vector pages
# OK   07_EL28521_2015_A_02_Appendix2_Airborne_Survey_Interpretation_Report.pdf: 1 vector pages
# OK   06_Elkedra_2003_AnnualRpt.pdf: 7 vector pages
# SKIP 07_EL32297_2023_drilling_cofunding_report.pdf: no vector-heavy pages
# OK   07_EL29841_2017_P_2_AirborneEMReport.pdf: 1 vector pages
# OK   07_GR016_2017_GA_JORC_Report.pdf: 1 vector pages
# SKIP 07_GR226-12_2013_GA_08_Appendix_12.pdf: no vector-heavy pages
# OK   07_Figure6.pdf: 1 vector pages
# OK   07_GR250_2015_GA_07_Figure6.pdf: 1 vector pages
# SKIP 07_GR_162_12_2013_GA_07_Appendix6.pdf: no vector-heavy pages
# OK   07_GR162_2014_GA_07_Plate2.pdf: 1 vector pages
# SKIP 07_MLC624_MLC632_2011_GA_01.pdf: no vector-heavy pages
# SKIP 07_Plate1_QuickBird_Sat_Image.pdf: no vector-heavy pages
# SKIP 07_Plate1_QuickBird_Sat_Image__1.pdf: no vector-heavy pages
# SKIP 08_CR2004-0467_Appendix_15.pdf: no vector-heavy pages
# SKIP 08_CR19930335.pdf: no vector-heavy pages
# SKIP 08_CR19750164_H.pdf: no vector-heavy pages
# SKIP 08_CR20100883_2010_Emmerson_02_Job_849_logistics_report.pdf: no vector-heavy pages
# SKIP 08_CR2012-0424_Fig7_Basement_Density.pdf: no vector-heavy pages
# OK   08_CR2012-0204_Fig7_EL27547_Basement_Density_100KA4.pdf: 1 vector pages
# SKIP 08_EL24604_2009_AS_08_HyVista_Survey_Report.pdf: no vector-heavy pages
# OK   08_EL23880_2014_P_08_Plate3.pdf: 1 vector pages
# OK   08_EL25354_2007_A_03_SkyTEM_Specs_Helen_Springs.pdf: 1 vector pages
# SKIP 08_EL250497_2008_A_01.pdf: no vector-heavy pages
# OK   07_CR2011-0444_EL25581_2011_P_07_Line10010_emf_.pdf: 1 vector pages
# SKIP 08_EL26080_2008_S.pdf: no vector-heavy pages
# SKIP 08_EL26185_2009_A_01.pdf: no vector-heavy pages
# SKIP 08_EL27145_2010_A_08_Figure7.pdf: no vector-heavy pages
# OK   08_EL27115_2014_P_09_Lithology_Code.pdf: 1 vector pages
# SKIP 08_EL27145_2011_P_08_FileListing.pdf: no vector-heavy pages
# SKIP 08_EL27723_2012_P_01.pdf: no vector-heavy pages
# OK   08_EL27196_2012_GAS_08_LogisticsSolution.pdf: 1 vector pages
# SKIP 08_EL27749_2012_P_01.pdf: no vector-heavy pages
# SKIP 08_EL29161_2014_A_05_IP_Profiles.pdf: no vector-heavy pages
# SKIP 08_ELR29627_2018_AS_08_App2_COA.pdf: no vector-heavy pages
# OK   08_GR016_2017_GA_Leaching_Report.pdf: 3 vector pages
# OK   08_Figure7.pdf: 1 vector pages
# OK   08_GR137-09_2012_GAS_07_LogisticsSolution.pdf: 1 vector pages
# OK   08_EL29841_2017_P_4_GroundmagReport.pdf: 12 vector pages
# SKIP 08_GR139-09_2010_GA_08_DatabaseCodes.pdf: no vector-heavy pages
# SKIP 08_Plate2_Aerial_Orthophoto_Image.pdf: no vector-heavy pages
# SKIP 08_Plate2_Aerial_Orthophoto_Image__1.pdf: no vector-heavy pages
# OK   08_GR250_2015_GA_08_Figure7.pdf: 1 vector pages
# SKIP 08_SEL7716_2000_S_01.pdf: no vector-heavy pages
# SKIP 09_CR2004-0467_Appendix_16.pdf: no vector-heavy pages
# OK   08_GR162_2014_GA_08_Plate3.pdf: 1 vector pages
# SKIP 09_CR19750164_I.pdf: no vector-heavy pages
# SKIP 09_CR2012-0424_Fig8_Basement_Magnetic_Susceptibility.pdf: no vector-heavy pages
# SKIP 09_CR20100883_2010_Emmerson_03_Job_876_logistics_report.pdf: no vector-heavy pages
# OK   09_EL23880_2014_P_09_Plate4.pdf: 1 vector pages
# SKIP 09_EL26081_2008_S.pdf: no vector-heavy pages
# SKIP 09_EL27145_2010_A_09_Figure8.pdf: no vector-heavy pages
# OK   09_EL25581_2012_A_19_TargetingReport.pdf: 5 vector pages
# OK   09_EL27196_2012_GAS_09_MiraModelling.pdf: 1 vector pages
# SKIP 09_EL28521_2018_A_09_LabReport_498_0_1804779.pdf: no vector-heavy pages
# SKIP 09_EL8766_2015_P_09_Logging_Codes.pdf: no vector-heavy pages
# OK   09_EL7739_2006_A_01.pdf: 5 vector pages
# OK   09_GR016_2017_GA_Flotation_Report.pdf: 4 vector pages
# SKIP 09_GR134-09_2012_GAS_09_App6_2012QAQC.pdf: no vector-heavy pages
# SKIP 09_MLC624_MLC632_2011_GA_03_rockchipsQAQC.pdf: no vector-heavy pages
# OK   09_GR137-09_2012_GAS_08_MiraModelling.pdf: 1 vector pages
# OK   08_CR2011-0444_EL25581_2011_P_08_Line10020_emf_.pdf: 1 vector pages
# OK   09_GR134-09_2011_GA_09_App5.pdf: 5 vector pages
# SKIP 09_Plate3_WorldView_Sat_Image__1.pdf: no vector-heavy pages
# SKIP 09_Plate3_Worldview_Sat_Image.pdf: no vector-heavy pages
# OK   10_CR2004-0467_Appendix_17.pdf: 1 vector pages
# OK   09_Plate1_AerometrexPhotoImage.pdf: 1 vector pages
# OK   10_EL23284_2011_S_01.pdf: 3 vector pages
# OK   10_EL23495_2008_A_01.pdf: 1 vector pages
# OK   10_EL23880_2014_P_10_Plate5.pdf: 1 vector pages
# OK   10_EL250497_2008_A_03_Verification_Listing.pdf: 1 vector pages
# SKIP 10_EL26018_2010_P_10_AppendixVIIIBarklyProjectFPXRFProcedure.pdf: no vector-heavy pages
# OK   10_EL25581_2012_A_20_StructuralAnalysis.pdf: 4 vector pages
# SKIP 10_EL26082_2008_S.pdf: no vector-heavy pages
# OK   10_CR20080298_2008_GA_01.pdf: 4 vector pages
# SKIP 10_EL26687_2010_A_01.pdf: no vector-heavy pages
# OK   10_CR20100883_2010_Emmerson_04_P2009009_EMMERSON_RESOURCES_Tennant_Creek_Gravity.pdf: 3 vector pages
# SKIP 10_EL26693_2010_A_01.pdf: no vector-heavy pages
# SKIP 10_EL26693_2013_AS_01.pdf: no vector-heavy pages
# OK   11_CR2004-0467_Appendix_18.pdf: 1 vector pages
# SKIP 11_EL24007_2009_P_01.pdf: no vector-heavy pages
# OK   11_CR2008-0341_EL250497_2008_A_04_Plan1_Mapping_Sampling_A1.pdf: 1 vector pages
# OK   10_GR107_2013_GA_10_Westgold_Logging_Codes.pdf: 7 vector pages
# SKIP 11_EL26018_2010_P_11_AppendixIXBarklyProjectLithcodes.pdf: no vector-heavy pages
# SKIP 11_EL26084_2008_S.pdf: no vector-heavy pages
# SKIP 11_EL26907_2011_A_01.pdf: no vector-heavy pages
# OK   11_GR181-11_2012_GAS_12_LogisticsSolution.pdf: 1 vector pages
# SKIP 11_GR182-11_2012_GAS_11_App7_2012QAQC.pdf: no vector-heavy pages
# OK   11_GR016_2017_GA_LoPOx_Report.pdf: 1 vector pages
# OK   12_CR2004-0467_Appendix_19.pdf: 1 vector pages
# OK   11_SEL24032_2008_P_02_Location.pdf: 1 vector pages
# SKIP 12_EL25593_2010_P_01.pdf: no vector-heavy pages
# OK   12_EL24951_2015_P_01.pdf: 2 vector pages
# SKIP 12_EL26018_2010_P_12_AppendixXBarklyProjectRegionalStudiesChrysoarandCSAGloal.pdf: no vector-heavy pages
# SKIP 12_EL26085_2008_S.pdf: no vector-heavy pages
# SKIP 12_EL9978_2006_A.pdf: no vector-heavy pages
# OK   12_EL24471_2013_A_12_Wireline12BH001.pdf: 4 vector pages
# OK   10_SEL24032_2008_P_01.pdf: 7 vector pages
# SKIP 12_GR145-10_2010_GA_01.pdf: no vector-heavy pages
# OK   12_GR181-11_2012_GAS_13_MiraModelling.pdf: 1 vector pages
# OK   12_EL27196_2010_A_01.pdf: 5 vector pages
# OK   12_SEL24032_2008_P_03_Geology.pdf: 1 vector pages
# SKIP 13_EL24471_2009_A_01.pdf: no vector-heavy pages
# OK   13_EL24951_2015_P_02_Figure1.pdf: 1 vector pages
# OK   13_CR20050090_2005_GA_01.pdf: 2 vector pages
# OK   13_EL25593_2010_P_02_logging_codes.pdf: 1 vector pages
# SKIP 13_EL27196_2010_A_02_App1_Lit_Review.pdf: no vector-heavy pages
# SKIP 13_EL26123_2008_S.pdf: no vector-heavy pages
# SKIP 13_GR145-10_2011_GA_01.pdf: no vector-heavy pages
# OK   13_CR2004-0467_Appendix_2.pdf: 6 vector pages
# SKIP 13_GR181-11_2013_GAS_09_DDrillAssays.pdf: no vector-heavy pages
# SKIP 14_EL24951_2015_P_03_Figure2.pdf: no vector-heavy pages
# OK   14_CR2004-0467_Appendix_20.pdf: 1 vector pages
# OK   14_EL23074_2009_A.pdf: 1 vector pages
# SKIP 14_EL26124_2008_S.pdf: no vector-heavy pages
# OK   13_SEL24032_2008_P_04_Index.pdf: 1 vector pages
# SKIP 14_EL27196_2010_A_03_App3_CSIRO_WaterBoreReport.pdf: no vector-heavy pages
# OK   15_EL22240_2011_S_01.pdf: 1 vector pages
# OK   14_EL25593_2010_P_03_EL25993_map_reduction_2010.pdf: 1 vector pages
# OK   15_CR2004-0467_Appendix_21.pdf: 1 vector pages
# OK   14_SEL24032_2008_P_05_Drilling.pdf: 1 vector pages
# SKIP 15_EL26125_2008_S.pdf: no vector-heavy pages
# OK   15_EL24951_2015_P_04_Figure3.pdf: 1 vector pages
# SKIP 15_EL29841_2019_P_1_Report.pdf: no vector-heavy pages
# SKIP 15_EL27115_2013_P_01.pdf: no vector-heavy pages
# OK   16_CR2004-0467_Appendix_22.pdf: 1 vector pages
# SKIP 16_EL26126_2008_S.pdf: no vector-heavy pages
# OK   15_GR145-10_2010_GA_04_tempest_report.pdf: 4 vector pages
# OK   16_EL24951_2015_P_05_Figure4.pdf: 1 vector pages
# OK   16_GR145-10_2010_GA_06_Ingellina_background.pdf: 1 vector pages
# SKIP 17_CR2011-0167_EL25366_2011_S_01_.pdf: no vector-heavy pages
# OK   17_CR2004-0467_Appendix_23.pdf: 1 vector pages
# SKIP 17_EL24951_2015_P_06_Figure5.pdf: no vector-heavy pages
# OK   15_EL24471_2013_A_15_Wireline15BH002.pdf: 4 vector pages
# SKIP 17_EL26332_2008_S.pdf: no vector-heavy pages
# SKIP 17_EL28116_2013_P_01.pdf: no vector-heavy pages
# OK   17_GR145-10_2010_GA_07_Wal_Annin_background.pdf: 1 vector pages
# OK   18_CR2004-0467_Appendix_24.pdf: 1 vector pages
# OK   18_EL24951_2015_P_07_Figure6.pdf: 1 vector pages
# SKIP 18_EL26334_2008_S.pdf: no vector-heavy pages
# OK   19_CR2004-0467_Appendix_25.pdf: 1 vector pages
# OK   19_EL24951_2015_P_08_Figure7.pdf: 1 vector pages
# OK   16_SEL24032_2009_S_01.pdf: 6 vector pages
# OK   19_GR145-10_2011_GA_07_Lithology_Code.pdf: 1 vector pages
# OK   20_EL24951_2015_P_09_Figure8.pdf: 1 vector pages
# SKIP 20_GR_162_12_2013_GA_20_Appendix7.pdf: no vector-heavy pages
# OK   20_CR2004-0467_Appendix_26.pdf: 1 vector pages
# OK   21_CR2004-0467_Appendix_27.pdf: 1 vector pages
# SKIP 21_EL24471_2012_A_01.pdf: no vector-heavy pages
# OK   21_EL27115_2013_P_07_Lithology_Code.pdf: 1 vector pages
# OK   22_CR2004-0467_Appendix_28.pdf: 1 vector pages
# OK   18_EL24471_2013_A_18_Wireline18BH003.pdf: 5 vector pages
# SKIP 23_CR2004-0467_Appendix_29.pdf: no vector-heavy pages
# SKIP 24_CR2004-0467_Appendix_3.pdf: no vector-heavy pages
# SKIP 23_EL29849_2015_P_01.pdf: no vector-heavy pages
# SKIP 24_EL25366_2011_S_08_LithologyCodes.pdf: no vector-heavy pages
# OK   21_EL24471_2013_A_21_Wireline18BH004.pdf: 4 vector pages
# OK   23_EL26825_2021_P_22_Appendix1.pdf: 5 vector pages
# OK   25_CR2004-0467_Appendix_4.pdf: 1 vector pages
# OK   24_EL29849_2015_P_02_AirborneEM_Report.pdf: 1 vector pages
# SKIP 25_EL24471_2012_A_05_CodeList.pdf: no vector-heavy pages
# SKIP 24_EL26825_2021_P_23_Appendix2.pdf: no vector-heavy pages
# OK   26_CR2004-0467_Appendix_5.pdf: 1 vector pages
# SKIP 25_EL29841_2015_P_01.pdf: no vector-heavy pages
# OK   26_EL29841_2015_P_02_AirborneEM_Report.pdf: 1 vector pages
# OK   27_CR2004-0467_Appendix_6.pdf: 1 vector pages
# OK   28_CR2004-0467_Appendix_7.pdf: 1 vector pages
# OK   29_CR2004-0467_Appendix_8.pdf: 1 vector pages
# SKIP 30_CR2004-0467_Appendix_9.pdf: no vector-heavy pages
# OK   27_GR162_2019_GA_26_Appendix_01.pdf: 3 vector pages
# SKIP 31_EL24471_2012_A_15_BIFHillMagModel.pdf: no vector-heavy pages
# SKIP 30_EL24471_2012_A_14_BIFHillInterp.pdf: no vector-heavy pages
# OK   27_EL29841_2015_P_03_GroundMag_Report.pdf: 12 vector pages
# OK   32_EL24471_2012_A_16_BIFHillMagModelRemanence.pdf: 1 vector pages
# OK   33_EL24471_2012_A_17_EMInterp.pdf: 2 vector pages
# SKIP 33_EL29849_2015_P_12_Site_Audit_Report.pdf: no vector-heavy pages
# SKIP 37_EL29841_2015_P_15_Site_Audit_Report.pdf: no vector-heavy pages
# OK   25_EL26825_2021_P_24_Appendix3.pdf: 7 vector pages
#
# Indexed 4007 rendered pages → C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\00_Projects\96_NT-Gold-CaseStudy\Reports-Tenements2\__type___pdf___images\page_index_vector.csv

# %% [markdown]
# ## Step 6: Merge PDFs

# %%
from PyPDF2 import PdfMerger
from PyPDF2.errors import DependencyError


PDF_HEAVY_FOLDER = BASE_FOLDER / "__type___pdf__heavy"
PDF_HEAVY_FOLDER.mkdir(parents=True, exist_ok=True)

def get_pdf_files_with_sizes(folder: Path):
    pdfs = []
    for name in os.listdir(folder):
        if name.lower().endswith(".pdf"):
            full_path = folder / name
            if full_path.is_file():
                pdfs.append((full_path, full_path.stat().st_size))
    pdfs.sort(key=lambda x: x[0].name.lower())
    return pdfs

def make_pdf_batches(pdfs, max_bytes: int):
    batches = []
    current_batch, current_size = [], 0
    for path, size in pdfs:
        if current_batch and current_size + size > max_bytes:
            batches.append(current_batch)
            current_batch, current_size = [], 0
        current_batch.append((path, size))
        current_size += size
    if current_batch:
        batches.append(current_batch)
    return batches

def merge_pdf_batch(batch, output_path: Path):
    """
    Merge one batch of PDFs into a single output PDF.

    - Uses strict=False so PyPDF2 is more tolerant of bad structure
    - Disables outline/bookmark import (import_outline=False)
    - Skips encrypted or otherwise problematic PDFs instead of crashing
    """
    merger = PdfMerger(strict=False)
    try:
        for path, _ in batch:
            try:
                # Do NOT import outlines/bookmarks – they are often broken
                merger.append(str(path), import_outline=False)
            except DependencyError as e:
                # AES-encrypted PDF but pycryptodome not installed
                print(
                    f"  Skipping encrypted PDF (needs PyCryptodome): "
                    f"{path.name} ({e})"
                )
            except Exception as e:
                # Any other weirdness, e.g. broken destinations / outlines
                print(
                    f"  Skipping problematic PDF during merge: "
                    f"{path.name} ({e})"
                )

        with open(output_path, "wb") as f_out:
            merger.write(f_out)
    finally:
        merger.close()



def run_step6_merge_pdfs():
    """
    Step 6:
      - Move PDFs > MAX_BATCH_BYTES to __type___pdf__heavy
      - Batch-merge the rest into <~199 MB PDFs in ___For_NotebookLM
      - Delete the processed PDFs from __type___pdf
    """
    pdfs = get_pdf_files_with_sizes(PDF_FOLDER)
    if not pdfs:
        print("No PDFs found in __type___pdf")
        return

    normal, heavy = [], []
    for path, size in pdfs:
        if size > MAX_BATCH_BYTES:
            heavy.append((path, size))
        else:
            normal.append((path, size))

    # Move heavy ones
    for path, size in heavy:
        dest = PDF_HEAVY_FOLDER / path.name
        print(f"Heavy PDF (>199 MB): {path.name} -> {dest}")
        shutil.move(str(path), str(dest))

    print(f"\nHeavy PDFs moved: {len(heavy)}")
    print(f"Normal PDFs to batch: {len(normal)}")

    if not normal:
        print("No normal PDFs to merge.")
        return

    batches = make_pdf_batches(normal, MAX_BATCH_BYTES)
    print(f"Planned {len(batches)} PDF batch(es).\n")

    for i, batch in enumerate(batches, start=1):
        out_name = f"pdf_batch_{i:03d}.pdf"
        out_path = NOTEBOOKLM_ROOT / out_name
        total_mb = sum(size for _, size in batch) / (1024**2)
        print(f"  Creating {out_name}: {len(batch)} files, sum input ≈ {total_mb:.2f} MB")
        merge_pdf_batch(batch, out_path)

    # Delete processed normal PDFs from __type___pdf
    for path, _ in normal:
        if path.exists():
            path.unlink()

    print("\nStep 6 complete – PDFs batched and heavy ones isolated.\n")

run_step6_merge_pdfs()
# Out:
# Heavy PDFs moved: 0
# Normal PDFs to batch: 5595
# Planned 73 PDF batch(es).
#
#   Creating pdf_batch_001.pdf: 60 files, sum input ≈ 186.86 MB
#   Creating pdf_batch_002.pdf: 40 files, sum input ≈ 184.10 MB
#   Creating pdf_batch_003.pdf: 30 files, sum input ≈ 187.78 MB
#   Creating pdf_batch_004.pdf: 28 files, sum input ≈ 187.62 MB
#   Creating pdf_batch_005.pdf: 26 files, sum input ≈ 184.47 MB
#   Creating pdf_batch_006.pdf: 33 files, sum input ≈ 188.94 MB
#   Creating pdf_batch_007.pdf: 33 files, sum input ≈ 179.22 MB
#   Creating pdf_batch_008.pdf: 38 files, sum input ≈ 184.98 MB
#   Creating pdf_batch_009.pdf: 38 files, sum input ≈ 167.68 MB
#   Creating pdf_batch_010.pdf: 34 files, sum input ≈ 187.65 MB
#   Creating pdf_batch_011.pdf: 42 files, sum input ≈ 188.49 MB
#   Creating pdf_batch_012.pdf: 63 files, sum input ≈ 188.19 MB
#   Creating pdf_batch_013.pdf: 110 files, sum input ≈ 188.16 MB
#   Creating pdf_batch_014.pdf: 119 files, sum input ≈ 179.50 MB
#   Creating pdf_batch_015.pdf: 141 files, sum input ≈ 182.57 MB
#   Creating pdf_batch_016.pdf: 103 files, sum input ≈ 186.37 MB
#   Creating pdf_batch_017.pdf: 81 files, sum input ≈ 187.76 MB
#   Creating pdf_batch_018.pdf: 73 files, sum input ≈ 184.64 MB
#   Creating pdf_batch_019.pdf: 98 files, sum input ≈ 189.95 MB
#   Creating pdf_batch_020.pdf: 79 files, sum input ≈ 188.76 MB
#   Creating pdf_batch_021.pdf: 113 files, sum input ≈ 189.23 MB
#   Creating pdf_batch_022.pdf: 98 files, sum input ≈ 181.88 MB
#   Creating pdf_batch_023.pdf: 99 files, sum input ≈ 189.17 MB
#   Creating pdf_batch_024.pdf: 59 files, sum input ≈ 187.96 MB
#   Creating pdf_batch_025.pdf: 144 files, sum input ≈ 184.31 MB
#   Creating pdf_batch_026.pdf: 128 files, sum input ≈ 189.35 MB
#   Creating pdf_batch_027.pdf: 127 files, sum input ≈ 178.54 MB
#   Creating pdf_batch_028.pdf: 85 files, sum input ≈ 183.73 MB
#   Creating pdf_batch_029.pdf: 33 files, sum input ≈ 181.63 MB
#   Creating pdf_batch_030.pdf: 25 files, sum input ≈ 179.44 MB
#   Creating pdf_batch_031.pdf: 156 files, sum input ≈ 169.71 MB
#   Creating pdf_batch_032.pdf: 60 files, sum input ≈ 167.09 MB
#   Creating pdf_batch_033.pdf: 114 files, sum input ≈ 188.79 MB
#   Creating pdf_batch_034.pdf: 57 files, sum input ≈ 183.06 MB
#   Creating pdf_batch_035.pdf: 135 files, sum input ≈ 189.78 MB
#   Creating pdf_batch_036.pdf: 61 files, sum input ≈ 187.85 MB
#   Creating pdf_batch_037.pdf: 75 files, sum input ≈ 188.73 MB
#   Creating pdf_batch_038.pdf: 18 files, sum input ≈ 189.31 MB
#   Creating pdf_batch_039.pdf: 143 files, sum input ≈ 185.62 MB
#   Creating pdf_batch_040.pdf: 103 files, sum input ≈ 184.99 MB
#   Creating pdf_batch_041.pdf: 95 files, sum input ≈ 189.85 MB
#   Creating pdf_batch_042.pdf: 37 files, sum input ≈ 189.38 MB
#   Creating pdf_batch_043.pdf: 89 files, sum input ≈ 189.58 MB
#   Creating pdf_batch_044.pdf: 88 files, sum input ≈ 184.06 MB
#   Creating pdf_batch_045.pdf: 67 files, sum input ≈ 188.81 MB
#   Creating pdf_batch_046.pdf: 91 files, sum input ≈ 184.79 MB
#   Creating pdf_batch_047.pdf: 59 files, sum input ≈ 187.96 MB
#   Creating pdf_batch_048.pdf: 108 files, sum input ≈ 179.32 MB
#   Creating pdf_batch_049.pdf: 98 files, sum input ≈ 188.45 MB
#   Creating pdf_batch_050.pdf: 72 files, sum input ≈ 189.90 MB
#   Creating pdf_batch_051.pdf: 24 files, sum input ≈ 171.94 MB
#   Creating pdf_batch_052.pdf: 77 files, sum input ≈ 188.87 MB
#   Creating pdf_batch_053.pdf: 81 files, sum input ≈ 189.80 MB
#   Creating pdf_batch_054.pdf: 78 files, sum input ≈ 175.67 MB
#   Creating pdf_batch_055.pdf: 49 files, sum input ≈ 183.50 MB
#   Creating pdf_batch_056.pdf: 38 files, sum input ≈ 189.31 MB
#   Creating pdf_batch_057.pdf: 49 files, sum input ≈ 183.18 MB
# Invalid stream (index 0) within object 537 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 538 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 539 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 540 0: Stream has ended unexpectedly
# Invalid stream (index 0) within object 541 0: Stream has ended unexpectedly
#   Creating pdf_batch_058.pdf: 34 files, sum input ≈ 187.15 MB
#   Creating pdf_batch_059.pdf: 124 files, sum input ≈ 188.04 MB
#   Creating pdf_batch_060.pdf: 119 files, sum input ≈ 174.24 MB
# Invalid stream (index 9) within object 25 0: Stream has ended unexpectedly
#   Creating pdf_batch_061.pdf: 157 files, sum input ≈ 184.59 MB
# Invalid stream (index 2) within object 17 0: Stream has ended unexpectedly
# Invalid stream (index 2) within object 20 0: Stream has ended unexpectedly
#   Creating pdf_batch_062.pdf: 65 files, sum input ≈ 184.79 MB
# incorrect startxref pointer(3)
#   Creating pdf_batch_063.pdf: 28 files, sum input ≈ 178.77 MB
#   Creating pdf_batch_064.pdf: 61 files, sum input ≈ 189.99 MB
#   Creating pdf_batch_065.pdf: 122 files, sum input ≈ 180.36 MB
#   Creating pdf_batch_066.pdf: 74 files, sum input ≈ 174.32 MB
# Object ID 4,0 ref repaired
# Object ID 4,0 ref repaired
#   Creating pdf_batch_067.pdf: 92 files, sum input ≈ 156.77 MB
#   Creating pdf_batch_068.pdf: 58 files, sum input ≈ 189.36 MB
#   Creating pdf_batch_069.pdf: 77 files, sum input ≈ 186.87 MB
# Object ID 4,0 ref repaired
#   Creating pdf_batch_070.pdf: 70 files, sum input ≈ 189.54 MB
# Object ID 4,0 ref repaired
#   Creating pdf_batch_071.pdf: 56 files, sum input ≈ 186.81 MB
#   Creating pdf_batch_072.pdf: 102 files, sum input ≈ 187.16 MB
#   Creating pdf_batch_073.pdf: 54 files, sum input ≈ 87.98 MB
#
# Step 6 complete – PDFs batched and heavy ones isolated.

# %% [markdown]
# ## Step 7: Merge DOCs

# %%
from docx import Document

DOCX_FOLDER      = BASE_FOLDER / "__type___docx"
DOCX_TXT_FOLDER  = BASE_FOLDER / "__type___docx__TXT__"
DOCX_TXT_FOLDER.mkdir(parents=True, exist_ok=True)

def docx_to_txt_single(docx_path: Path, out_txt: Path):
    doc = Document(str(docx_path))
    lines = []
    for para in doc.paragraphs:
        lines.append(para.text)
    out_txt.parent.mkdir(parents=True, exist_ok=True)
    with open(out_txt, "w", encoding="utf-8") as f:
        f.write("\n".join(lines))



def run_step7_docx_to_txt_and_merge():
    """
    Step 7:
      - Convert all .docx in __type___docx → .txt in __type___docx__TXT__
      - Delete the working .docx
      - Batch-merge those txt into ___For_NotebookLM/docx_batch_XXX.txt

    If no .docx remain (e.g. from a previous run), it will still merge any
    existing .txt files in __type___docx__TXT__ into batches.
    """
    # --- 1. Convert any remaining DOCX to TXT ---
    docx_files = []
    if DOCX_FOLDER.exists():
        docx_files = sorted(DOCX_FOLDER.glob("*.docx"))

    n = len(docx_files)
    if n > 0:
        print(f"Found {n} DOCX files in {DOCX_FOLDER}")

        for i, docx in enumerate(docx_files, start=1):
            print(f"[{i}/{n}] Converting {docx.name} -> txt")
            out_txt = DOCX_TXT_FOLDER / f"{docx.stem}.txt"
            docx_to_txt_single(docx, out_txt)
            try:
                docx.unlink()
            except Exception as e:
                print(f"  Could not delete {docx}: {e}")
    else:
        print(f"No .docx files found in {DOCX_FOLDER} – skipping conversion step.")

    # --- 2. Always try to merge any TXT in DOCX_TXT_FOLDER ---
    txt_files = list(DOCX_TXT_FOLDER.glob("*.txt"))
    if not txt_files:
        print(f"No .txt files found in {DOCX_TXT_FOLDER}, nothing to merge.")
        return

    batch_merge_text_files(
        source_folder=DOCX_TXT_FOLDER,
        batch_prefix="docx",
        dest_root=NOTEBOOKLM_ROOT,
        max_bytes=MAX_BATCH_BYTES,
    )

    print("Step 7 complete – DOCX → TXT → batches.\n")

run_step7_docx_to_txt_and_merge()
# Out:
# No .docx files found in C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\00_Projects\96_NT-Gold-CaseStudy\Reports-Tenements2\__type___docx – skipping conversion step.
# No .txt files found in C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\00_Projects\96_NT-Gold-CaseStudy\Reports-Tenements2\__type___docx__TXT__, nothing to merge.

# %% [markdown]
# ## Step 8 – Merge raw .txt into batches

# %%
TXT_FOLDER = BASE_FOLDER / "__type___txt"

def run_step8_merge_txt_batches():
    """
    Step 8:
      - Batch-merge all .txt in __type___txt into ___For_NotebookLM/txt_batch_XXX.txt
      - Delete the processed .txt files
    """
    if not TXT_FOLDER.exists():
        print(f"No TXT folder found: {TXT_FOLDER}")
        return

    txt_files = list(TXT_FOLDER.glob("*.txt"))
    if not txt_files:
        print(f"No .txt files found in {TXT_FOLDER}")
        return

    batch_merge_text_files(
        source_folder=TXT_FOLDER,
        batch_prefix="txt",
        dest_root=NOTEBOOKLM_ROOT,
        max_bytes=MAX_BATCH_BYTES,
    )

    # Delete processed txt files
    for path in txt_files:
        if path.exists():
            path.unlink()

    print("Step 8 complete – raw TXT batched.\n")

run_step8_merge_txt_batches()
# Out:
# Merging 1050 text files from C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\00_Projects\96_NT-Gold-CaseStudy\Reports-Tenements2\__type___txt
#   -> Creating txt_batch_003.txt
# WARNING: single file 01_ALTJ2005_GroundMag.txt (with header) has 1393464 characters (> 490000). Writing alone in this batch.
#   -> Creating txt_batch_004.txt
#   -> Creating txt_batch_005.txt
#   -> Creating txt_batch_006.txt
#   -> Creating txt_batch_007.txt
#   -> Creating txt_batch_008.txt
#   -> Creating txt_batch_009.txt
#   -> Creating txt_batch_010.txt
#   -> Creating txt_batch_011.txt
#   -> Creating txt_batch_012.txt
#   -> Creating txt_batch_013.txt
#   -> Creating txt_batch_014.txt
#   -> Creating txt_batch_015.txt
#   -> Creating txt_batch_016.txt
#   -> Creating txt_batch_017.txt
#   -> Creating txt_batch_018.txt
#   -> Creating txt_batch_019.txt
#   -> Creating txt_batch_020.txt
#   -> Creating txt_batch_021.txt
#   -> Creating txt_batch_022.txt
#   -> Creating txt_batch_023.txt
#   -> Creating txt_batch_024.txt
#   -> Creating txt_batch_025.txt
#   -> Creating txt_batch_026.txt
#   -> Creating txt_batch_027.txt
#   -> Creating txt_batch_028.txt
#   -> Creating txt_batch_029.txt
#   -> Creating txt_batch_030.txt
#   -> Creating txt_batch_031.txt
# WARNING: single file 03_SEL24980_2011_S_03_DownholeGeochem.txt (with header) has 1336682 characters (> 490000). Writing alone in this batch.
#   -> Creating txt_batch_032.txt
#   -> Creating txt_batch_033.txt
#   -> Creating txt_batch_034.txt
#   -> Creating txt_batch_035.txt
#   -> Creating txt_batch_036.txt
#   -> Creating txt_batch_037.txt
#   -> Creating txt_batch_038.txt
#   -> Creating txt_batch_039.txt
#   -> Creating txt_batch_040.txt
#   -> Creating txt_batch_041.txt
#   -> Creating txt_batch_042.txt
#   -> Creating txt_batch_043.txt
#   -> Creating txt_batch_044.txt
#   -> Creating txt_batch_045.txt
# WARNING: single file 04_MLC324_2011_A_03_Geology.txt (with header) has 1028523 characters (> 490000). Writing alone in this batch.
#   -> Creating txt_batch_046.txt
#   -> Creating txt_batch_047.txt
# WARNING: single file 04_SEL24980_2011_S_04_Geology.txt (with header) has 2136882 characters (> 490000). Writing alone in this batch.
#   -> Creating txt_batch_048.txt
#   -> Creating txt_batch_049.txt
#   -> Creating txt_batch_050.txt
#   -> Creating txt_batch_051.txt
#   -> Creating txt_batch_052.txt
# WARNING: single file 05_GR145_2012_GA_05_DHRadiometrics.txt (with header) has 2608008 characters (> 490000). Writing alone in this batch.
#   -> Creating txt_batch_053.txt
#   -> Creating txt_batch_054.txt
#   -> Creating txt_batch_055.txt
#   -> Creating txt_batch_056.txt
# WARNING: single file 06_EL27115_2017_AS_07_DHRadiometrics.txt (with header) has 1887786 characters (> 490000). Writing alone in this batch.
#   -> Creating txt_batch_057.txt
#   -> Creating txt_batch_058.txt
#   -> Creating txt_batch_059.txt
#   -> Creating txt_batch_060.txt
# WARNING: single file 07_EL27115_2014_P_08_DHRadiometrics.txt (with header) has 1656104 characters (> 490000). Writing alone in this batch.
#   -> Creating txt_batch_061.txt
#   -> Creating txt_batch_062.txt
# WARNING: single file 07_EL28521_2018_A_07_AMRBC_NTDG4_ASS2017A.txt (with header) has 1205814 characters (> 490000). Writing alone in this batch.
#   -> Creating txt_batch_063.txt
#   -> Creating txt_batch_064.txt
#   -> Creating txt_batch_065.txt
#   -> Creating txt_batch_066.txt
# WARNING: single file 08_GR_162_12_2013_GA_08_Surfacegeochem.txt (with header) has 549889 characters (> 490000). Writing alone in this batch.
#   -> Creating txt_batch_067.txt
#   -> Creating txt_batch_068.txt
#   -> Creating txt_batch_069.txt
#   -> Creating txt_batch_070.txt
#   -> Creating txt_batch_071.txt
# WARNING: single file 12_GR162_2019_GA_11_DHXRF.txt (with header) has 717913 characters (> 490000). Writing alone in this batch.
#   -> Creating txt_batch_072.txt
#   -> Creating txt_batch_073.txt
# WARNING: single file 13_EL23284_2011_S_04_Geology.txt (with header) has 1075368 characters (> 490000). Writing alone in this batch.
#   -> Creating txt_batch_074.txt
#   -> Creating txt_batch_075.txt
#   -> Creating txt_batch_076.txt
#   -> Creating txt_batch_077.txt
#   -> Creating txt_batch_078.txt
# WARNING: single file 18_GR145-10_2011_GA_06_DHGamma.txt (with header) has 717474 characters (> 490000). Writing alone in this batch.
#   -> Creating txt_batch_079.txt
#   -> Creating txt_batch_080.txt
#   -> Creating txt_batch_081.txt
# Done. Created 81 batch file(s) for prefix 'txt'.
#
# Step 8 complete – raw TXT batched.

# %% [markdown]
# ## Step 9: Final cleanup – delete empty __type___docx/txt/tif/pdf folders

# %%
def cleanup_empty_type_folders():
    for name in ["__type___docx", "__type___txt", "__type___tif", "__type___pdf"]:
        folder = BASE_FOLDER / name
        if folder.exists():
            if any(folder.iterdir()):
                print(f"Not empty (skipping delete): {folder}")
            else:
                try:
                    folder.rmdir()
                    print(f"Deleted empty folder: {folder}")
                except OSError as e:
                    print(f"Could not delete {folder}: {e}")

cleanup_empty_type_folders()
# Out:
# Could not delete C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\00_Projects\96_NT-Gold-CaseStudy\Reports-Tenements2\__type___txt: [WinError 5] Access is denied: 'C:\\Users\\Julian.Diaz\\OneDrive - XENITH CONSULTING PTY LTD\\Documents\\00_Projects\\96_NT-Gold-CaseStudy\\Reports-Tenements2\\__type___txt'
# Could not delete C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\00_Projects\96_NT-Gold-CaseStudy\Reports-Tenements2\__type___tif: [WinError 5] Access is denied: 'C:\\Users\\Julian.Diaz\\OneDrive - XENITH CONSULTING PTY LTD\\Documents\\00_Projects\\96_NT-Gold-CaseStudy\\Reports-Tenements2\\__type___tif'
# Could not delete C:\Users\Julian.Diaz\OneDrive - XENITH CONSULTING PTY LTD\Documents\00_Projects\96_NT-Gold-CaseStudy\Reports-Tenements2\__type___pdf: [WinError 5] Access is denied: 'C:\\Users\\Julian.Diaz\\OneDrive - XENITH CONSULTING PTY LTD\\Documents\\00_Projects\\96_NT-Gold-CaseStudy\\Reports-Tenements2\\__type___pdf'

# %% [markdown]
# ## Step 10: chunk large NotebookLM text files

# %%
def run_step9_chunk_large_notebooklm_txt_files():
    """
    Step 9:
      - Scan ___For_NotebookLM for .txt files
      - For any file with more than MAX_BATCH_CHARS characters,
        split into smaller parts (<= MAX_BATCH_CHARS) and delete the original.

    This cleans up cases where a single source file is larger than the limit
    and ended up alone in one batch.
    """
    CHUNK_CHARS = MAX_BATCH_CHARS  # currently 490_000
    txt_files = sorted(NOTEBOOKLM_ROOT.glob("*.txt"))
    if not txt_files:
        print(f"No .txt files found in {NOTEBOOKLM_ROOT}")
        return

    print(f"Checking {len(txt_files)} NotebookLM .txt files for oversize chunks...")
    chunked_count = 0

    for path in txt_files:
        # We wrote these ourselves as UTF-8 in batch_merge_text_files
        try:
            text = path.read_text(encoding="utf-8")
        except UnicodeDecodeError:
            # Extremely unlikely here, but be defensive
            text = path.read_text(encoding="latin-1", errors="replace")

        length = len(text)
        if length <= CHUNK_CHARS:
            continue

        # Need to split this file into smaller pieces
        base = path.stem        # e.g. "txt_batch_002"
        suffix = path.suffix    # ".txt"

        n_parts = (length + CHUNK_CHARS - 1) // CHUNK_CHARS
        print(f"  Chunking {path.name} ({length} chars) into {n_parts} part(s).")

        for i in range(n_parts):
            start = i * CHUNK_CHARS
            end = min((i + 1) * CHUNK_CHARS, length)
            chunk = text[start:end]

            part_name = f"{base}_part{i+1:02d}{suffix}"
            part_path = path.with_name(part_name)
            part_path.write_text(chunk, encoding="utf-8")

        # Remove the oversized original
        path.unlink()
        chunked_count += 1

    if chunked_count == 0:
        print("No oversized NotebookLM .txt files needed chunking.")
    else:
        print(f"Step 9 complete – chunked {chunked_count} oversized .txt file(s).")

# %%
run_step9_chunk_large_notebooklm_txt_files()
# Out:
# Checking 82 NotebookLM .txt files for oversize chunks...
#   Chunking txt_batch_001.txt (1393464 chars) into 3 part(s).
#   Chunking txt_batch_003.txt (1393464 chars) into 3 part(s).
#   Chunking txt_batch_031.txt (1336682 chars) into 3 part(s).
#   Chunking txt_batch_045.txt (1028523 chars) into 3 part(s).
#   Chunking txt_batch_047.txt (2136882 chars) into 5 part(s).
#   Chunking txt_batch_052.txt (2608008 chars) into 6 part(s).
#   Chunking txt_batch_056.txt (1887786 chars) into 4 part(s).
#   Chunking txt_batch_060.txt (1656104 chars) into 4 part(s).
#   Chunking txt_batch_062.txt (1205814 chars) into 3 part(s).
#   Chunking txt_batch_066.txt (549889 chars) into 2 part(s).
#   Chunking txt_batch_071.txt (717913 chars) into 2 part(s).
#   Chunking txt_batch_073.txt (1075368 chars) into 3 part(s).
#   Chunking txt_batch_078.txt (717474 chars) into 2 part(s).
# Step 9 complete – chunked 13 oversized .txt file(s).
